# %%
# %load_ext autoreload
# %autoreload 2
    
import os
import cv2
import sys
import copy
import json
import random
import rasterio
import numpy as np
import tifffile as tiff
from skimage.transform import rescale, resize

import matplotlib.pyplot as plt

from keras import backend as K
from keras.models import Model, model_from_json

from keras.optimizers import SGD, Adam, RMSprop
from keras.backend import categorical_crossentropy, binary_crossentropy
from segmentation_models import Unet, FPN

from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger, Callback

os.environ['CUDA_VISIBLE_DEVICES'] = "1"
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Segmentation Models: using `keras` framework.

# %%
sys.path.insert(0, '../')
from species_classification_scripts.individual_stands_classification import Generator

# %% [markdown]
# ### Check some distribution

# %%
for sp_class in ['conifer', 'decidious']:
    pix_num = 0
    for img_ind in range(2): 
        imgpath = '/home/user/data/projects/research-project/notebooks/Illarionova/Forestry_inventory/wv_inference/krasnoborsk/{}_{}.tif'.format(img_ind, sp_class)
        with rasterio.open(imgpath) as src:
            mask = src.read(1)
        pix_num += np.sum(mask)
    print(sp_class, pix_num)
# Out:
# conifer 2069467.0
# decidious 3282717.0

# %% [markdown]
# ### Set generator

# %%
class_0=['conifer']
class_1=['decidious']
folders = ['0', '1']
num_channels = 9
batch_size = 32

generator = Generator(batch_size=batch_size,class_0=class_0,class_1=class_1,
                      num_channels=num_channels)
generator.IMG_ROW = 128
generator.IMG_COL = 128
generator.sup_materials = True
generator.sup_name = '_height.tif'
generator.sup_normalization = 40.
generator.wv = True
generator.channels_name = ['_channel_0', '_channel_1', '_channel_2', '_channel_3',
                          '_channel_4', '_channel_5', '_channel_6', '_channel_7']
weights_list = [ 1., 1.]
loss =  generator.weighted_categorical_crossentropy(weights_list)  

generator.load_dataset(folders)
generator.set_normalize_channel()

# %% [markdown]
# ### Check generated output

# %%
imgpath = '/home/user/data/projects/research-project/notebooks/Illarionova/Forestry_inventory/wv_inference/krasnoborsk/1'
upper_left_x = 11902
upper_left_y = 5681
pol_width = 893
pol_height = 345

img_tmp, mask_tmp = generator.get_img_mask_array(imgpath, upper_left_x, upper_left_y, pol_width, pol_height)

# %%
img_tmp[:,:,-1]
# Out:
# array([[0.45, 0.45, 0.45, ..., 0.45, 0.45, 0.45],
#        [0.45, 0.45, 0.45, ..., 0.45, 0.45, 0.45],
#        [0.45, 0.45, 0.45, ..., 0.45, 0.45, 0.45],
#        ...,
#        [0.45, 0.45, 0.45, ..., 0.45, 0.45, 0.45],
#        [0.45, 0.45, 0.45, ..., 0.45, 0.45, 0.45],
#        [0.45, 0.45, 0.45, ..., 0.45, 0.45, 0.45]])

# %%
fig = plt.figure(figsize = (10,10))
for i in range(4):
    a = fig.add_subplot(1, 4, i+1)
    imgplot = plt.imshow(img_tmp[:,:,i])
    a.set_title('band '+str(i))

for i in range(4):
    a = fig.add_subplot(2, 4, i+1)
    imgplot = plt.imshow(img_tmp[:,:,4+i])
    a.set_title('band '+str(i+4))

fig = plt.figure(figsize = (6,6))
a = fig.add_subplot(2, 3, 1)
imgplot = plt.imshow(mask_tmp[:,:,0]>0.5)
a.set_title('class_0')
a = fig.add_subplot(2, 3, 2)
imgplot = plt.imshow(mask_tmp[:,:,1]>0.5)
a.set_title('class_1')
a = fig.add_subplot(2, 3, 3)
imgplot = plt.imshow(img_tmp[:,:,-1])
a.set_title('height')
# Out:
# Text(0.5,1,'height')

# %%
#labels_dict = {'0': 192, '1': 368}
#class_weight, weights_list = create_class_weight(labels_dict, mu=0.8)
#weights_list

# %%
for img, mask in generator.train_gen():
    break

# %%
img.shape, mask.shape
# Out:
# ((32, 128, 128, 9), (32, 128, 128, 2))

# %% [markdown]
# ##  Set model

# %%
model = Unet(backbone_name='resnet34', input_shape=(None, None, num_channels), classes=2,
                  encoder_weights=None, activation='softmax')
opt = RMSprop(lr=0.001)
metrics=[loss]
model.compile(optimizer=opt, loss=loss, metrics=metrics)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras.callbacks import Callback

# %%
model_name = 'multispectral_inventory'
save_dir = '/home/user/data/example/data/Forestry_inventory/usgs_species_classification/'

# csv logger
log_filename = os.path.join(save_dir, '{}.csv'.format(model_name))
csv_logger = CSVLogger(log_filename, separator=',', append='True')

callbacks=[
    ReduceLROnPlateau(patience=5,min_lr=1e-9,verbose=1,mode='min'), #pat 7
    ModelCheckpoint(save_dir + '{}.h5'.format(model_name),save_best_only=True,verbose=1),
    ModelCheckpoint(save_dir + '{}.hdf5'.format(model_name),save_best_only=True,verbose=1, save_weights_only=True),
    csv_logger
]

# %%
history=model.fit_generator(generator.train_gen(),epochs=25, #35, 25 20
                           steps_per_epoch=200,#200,
                           validation_data=generator.val_gen(),  #(valid_imgarr,valid_maskarr),
                           callbacks=callbacks, validation_steps=100)#30
# Out:
# Epoch 1/25
# 200/200 [==============================] - 357s 2s/step - loss: 0.4705 - loss_1: 0.4705 - val_loss: 1.7286 - val_loss_1: 1.7286
#
# Epoch 00001: val_loss improved from inf to 1.72855, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.h5
#
# Epoch 00001: val_loss improved from inf to 1.72855, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.hdf5
# Epoch 2/25
# 200/200 [==============================] - 343s 2s/step - loss: 0.4181 - loss_1: 0.4181 - val_loss: 0.6230 - val_loss_1: 0.6230
#
# Epoch 00002: val_loss improved from 1.72855 to 0.62300, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.h5
#
# Epoch 00002: val_loss improved from 1.72855 to 0.62300, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.hdf5
# Epoch 3/25
# 200/200 [==============================] - 344s 2s/step - loss: 0.4097 - loss_1: 0.4097 - val_loss: 0.5542 - val_loss_1: 0.5542
#
# Epoch 00003: val_loss improved from 0.62300 to 0.55419, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.h5
#
# Epoch 00003: val_loss improved from 0.62300 to 0.55419, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.hdf5
# Epoch 4/25
# 200/200 [==============================] - 345s 2s/step - loss: 0.3903 - loss_1: 0.3903 - val_loss: 0.5717 - val_loss_1: 0.5717
#
# Epoch 00004: val_loss did not improve from 0.55419
#
# Epoch 00004: val_loss did not improve from 0.55419
# Epoch 5/25
# 200/200 [==============================] - 344s 2s/step - loss: 0.3897 - loss_1: 0.3897 - val_loss: 0.4492 - val_loss_1: 0.4492
#
# Epoch 00005: val_loss improved from 0.55419 to 0.44925, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.h5
#
# Epoch 00005: val_loss improved from 0.55419 to 0.44925, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.hdf5
# Epoch 6/25
# 200/200 [==============================] - 342s 2s/step - loss: 0.3847 - loss_1: 0.3847 - val_loss: 0.4551 - val_loss_1: 0.4551
#
# Epoch 00006: val_loss did not improve from 0.44925
#
# Epoch 00006: val_loss did not improve from 0.44925
# Epoch 7/25
# 200/200 [==============================] - 343s 2s/step - loss: 0.3723 - loss_1: 0.3723 - val_loss: 0.3943 - val_loss_1: 0.3943
#
# Epoch 00007: val_loss improved from 0.44925 to 0.39430, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.h5
#
# Epoch 00007: val_loss improved from 0.44925 to 0.39430, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.hdf5
# Epoch 8/25
# 200/200 [==============================] - 342s 2s/step - loss: 0.3678 - loss_1: 0.3678 - val_loss: 0.3773 - val_loss_1: 0.3773
#
# Epoch 00008: val_loss improved from 0.39430 to 0.37730, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.h5
#
# Epoch 00008: val_loss improved from 0.39430 to 0.37730, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.hdf5
# Epoch 9/25
# 200/200 [==============================] - 343s 2s/step - loss: 0.3658 - loss_1: 0.3658 - val_loss: 0.4741 - val_loss_1: 0.4741
#
# Epoch 00009: val_loss did not improve from 0.37730
#
# Epoch 00009: val_loss did not improve from 0.37730
# Epoch 10/25
# 200/200 [==============================] - 343s 2s/step - loss: 0.3626 - loss_1: 0.3626 - val_loss: 0.3832 - val_loss_1: 0.3832
#
# Epoch 00010: val_loss did not improve from 0.37730
#
# Epoch 00010: val_loss did not improve from 0.37730
# Epoch 11/25
# 200/200 [==============================] - 343s 2s/step - loss: 0.3559 - loss_1: 0.3559 - val_loss: 0.3617 - val_loss_1: 0.3617
#
# Epoch 00011: val_loss improved from 0.37730 to 0.36175, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.h5
#
# Epoch 00011: val_loss improved from 0.37730 to 0.36175, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.hdf5
# Epoch 12/25
# 200/200 [==============================] - 343s 2s/step - loss: 0.3463 - loss_1: 0.3463 - val_loss: 0.3827 - val_loss_1: 0.3827
#
# Epoch 00012: val_loss did not improve from 0.36175
#
# Epoch 00012: val_loss did not improve from 0.36175
# Epoch 13/25
# 200/200 [==============================] - 341s 2s/step - loss: 0.3472 - loss_1: 0.3472 - val_loss: 0.3837 - val_loss_1: 0.3837
#
# Epoch 00013: val_loss did not improve from 0.36175
#
# Epoch 00013: val_loss did not improve from 0.36175
# Epoch 14/25
# 200/200 [==============================] - 340s 2s/step - loss: 0.3434 - loss_1: 0.3434 - val_loss: 0.3616 - val_loss_1: 0.3616
#
# Epoch 00014: val_loss improved from 0.36175 to 0.36158, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.h5
#
# Epoch 00014: val_loss improved from 0.36175 to 0.36158, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.hdf5
# Epoch 15/25
# 200/200 [==============================] - 341s 2s/step - loss: 0.3412 - loss_1: 0.3412 - val_loss: 0.4234 - val_loss_1: 0.4234
#
# Epoch 00015: val_loss did not improve from 0.36158
#
# Epoch 00015: val_loss did not improve from 0.36158
# Epoch 16/25
# 200/200 [==============================] - 342s 2s/step - loss: 0.3362 - loss_1: 0.3362 - val_loss: 0.3500 - val_loss_1: 0.3500
#
# Epoch 00016: val_loss improved from 0.36158 to 0.35005, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.h5
#
# Epoch 00016: val_loss improved from 0.36158 to 0.35005, saving model to /home/user/data/example/data/Forestry_inventory/usgs_species_classification/multispectral_inventory.hdf5
# Epoch 17/25
# 200/200 [==============================] - 341s 2s/step - loss: 0.3425 - loss_1: 0.3425 - val_loss: 0.4447 - val_loss_1: 0.4447
#
# Epoch 00017: val_loss did not improve from 0.35005
#
# Epoch 00017: val_loss did not improve from 0.35005
# Epoch 18/25
# 200/200 [==============================] - 315s 2s/step - loss: 0.3431 - loss_1: 0.3431 - val_loss: 0.3506 - val_loss_1: 0.3506
#
# Epoch 00018: val_loss did not improve from 0.35005
#
# Epoch 00018: val_loss did not improve from 0.35005
# Epoch 19/25
# 200/200 [==============================] - 315s 2s/step - loss: 0.3373 - loss_1: 0.3373 - val_loss: 0.3845 - val_loss_1: 0.3845
#
# Epoch 00019: val_loss did not improve from 0.35005
#
# Epoch 00019: val_loss did not improve from 0.35005
# Epoch 20/25
#  13/200 [>.............................] - ETA: 39s - loss: 0.3427 - loss_1: 0.3427
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7eb5dcb2eecf> in <module>()
#       2                            steps_per_epoch=200,#200,
#       3                            validation_data=generator.val_gen(),  #(valid_imgarr,valid_maskarr),
# ----> 4                            callbacks=callbacks, validation_steps=100)#30
#
# /opt/conda/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/conda/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /opt/conda/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# /opt/conda/lib/python3.6/site-packages/keras/utils/data_utils.py in get(self)
#     683         try:
#     684             while self.is_running():
# --> 685                 inputs = self.queue.get(block=True).get()
#     686                 self.queue.task_done()
#     687                 if inputs is not None:
#
# /opt/conda/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# /opt/conda/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# /opt/conda/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /opt/conda/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
# serialize model to JSON without height
model_json = model.to_json()
with open(save_dir+"{}.json".format(model_name), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights(save_dir+"{}.h5".format(model_name))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
json_file = open(save_dir+"{}.json".format(model_name), 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights(save_dir+"{}.h5".format(model_name))

# %%
model.load_weights(save_dir+"{}.h5".format(model_name))

# %% [markdown]
# ### Check intersection between train and val samples

# %%
samples_val = []
for key in generator.json_file_linden_val.keys():
    sample = generator.json_file_linden_val[key]
    samples_val.append([key.split('_')[0], sample['upper_left_x'], sample['upper_left_y'], sample['pol_width'], sample['pol_height']])
    
samples_train = []
for key in generator.json_file_linden_train.keys():
    sample = generator.json_file_linden_train[key]
    samples_train.append([key.split('_')[0], sample['upper_left_x'], sample['upper_left_y'], sample['pol_width'], sample['pol_height']])

# %%
len(set(tuple(i) for i in samples_val+samples_train))
# Out:
# 1368

# %%
k = 0
for sample in samples_val:
    if sample in samples_train:
        k += 1
k
# Out:
# 0

# %% [markdown]
# ## write geojson for validation

# %%
import tifffile as tiff
import numpy as np
import rasterio
import matplotlib
import matplotlib.pyplot as plt

import geojson
from rasterio.mask import mask
from osgeo import gdal, osr
from rasterio.plot import plotting_extent

from rasterio import features
from shapely import geometry
from shapely.geometry import Polygon, MultiPolygon

import pandas as pd
import json
import re
import subprocess
from os import listdir
from pyproj import Proj, transform

import scipy
import cv2
from glob import glob

# %%
for item in generator.json_file_linden_val.items():
    print(item)
# Out:
# ('0_172', {'upper_left_x': 1188, 'upper_left_y': 13459, 'pol_width': 208, 'pol_height': 114, 'pix_area': 3.3445048389717847e-06})
# ('1_456', {'upper_left_x': 18462, 'upper_left_y': 10195, 'pol_width': 257, 'pol_height': 196, 'pix_area': 9.641727058646588e-06})
# ('0_227', {'upper_left_x': 929, 'upper_left_y': 14082, 'pol_width': 397, 'pol_height': 248, 'pix_area': 1.6518897890642724e-05})
# ('1_902', {'upper_left_x': 16716, 'upper_left_y': 13921, 'pol_width': 135, 'pol_height': 95, 'pix_area': 2.688672846741086e-06})
# ('1_785', {'upper_left_x': 12101, 'upper_left_y': 14388, 'pol_width': 103, 'pol_height': 70, 'pix_area': 1.0827473282763923e-06})
# ('1_858', {'upper_left_x': 12365, 'upper_left_y': 13659, 'pol_width': 575, 'pol_height': 224, 'pix_area': 1.493255089686909e-05})
# ('1_825', {'upper_left_x': 13698, 'upper_left_y': 13876, 'pol_width': 242, 'pol_height': 160, 'pix_area': 7.4139463424565356e-06})
# ('1_154', {'upper_left_x': 10581, 'upper_left_y': 6045, 'pol_width': 282, 'pol_height': 201, 'pix_area': 6.572421364643278e-06})
# ('0_62', {'upper_left_x': 855, 'upper_left_y': 10210, 'pol_width': 218, 'pol_height': 139, 'pix_area': 2.5066445598582843e-06})
# ('1_310', {'upper_left_x': 0, 'upper_left_y': 2450, 'pol_width': 956, 'pol_height': 356, 'pix_area': 5.599566665175272e-05})
# ('1_322', {'upper_left_x': 12931, 'upper_left_y': 9782, 'pol_width': 285, 'pol_height': 60, 'pix_area': 2.935757729182357e-06})
# ('1_468', {'upper_left_x': 15359, 'upper_left_y': 11519, 'pol_width': 370, 'pol_height': 64, 'pix_area': 4.7630770919247645e-06})
# ('1_506', {'upper_left_x': 4308, 'upper_left_y': 6551, 'pol_width': 376, 'pol_height': 142, 'pix_area': 8.444783224006592e-06})
# ('1_577', {'upper_left_x': 19156, 'upper_left_y': 9886, 'pol_width': 622, 'pol_height': 193, 'pix_area': 1.8850381898450605e-05})
# ('1_903', {'upper_left_x': 17197, 'upper_left_y': 14057, 'pol_width': 189, 'pol_height': 221, 'pix_area': 6.025612286644729e-06})
# ('1_646', {'upper_left_x': 6010, 'upper_left_y': 6566, 'pol_width': 433, 'pol_height': 234, 'pix_area': 1.553196930068398e-05})
# ('1_817', {'upper_left_x': 17002, 'upper_left_y': 13505, 'pol_width': 526, 'pol_height': 189, 'pix_area': 1.784818229230909e-05})
# ('1_942', {'upper_left_x': 18058, 'upper_left_y': 12530, 'pol_width': 297, 'pol_height': 192, 'pix_area': 8.71136439019543e-06})
# ('1_466', {'upper_left_x': 10831, 'upper_left_y': 12749, 'pol_width': 122, 'pol_height': 128, 'pix_area': 2.1385080191163577e-06})
# ('1_240', {'upper_left_x': 11828, 'upper_left_y': 8472, 'pol_width': 666, 'pol_height': 337, 'pix_area': 3.288623347485214e-05})
# ('1_443', {'upper_left_x': 10991, 'upper_left_y': 12520, 'pol_width': 577, 'pol_height': 431, 'pix_area': 4.303691574656061e-05})
# ('0_207', {'upper_left_x': 0, 'upper_left_y': 13492, 'pol_width': 1490, 'pol_height': 628, 'pix_area': 5.489818339908876e-06})
# ('1_198', {'upper_left_x': 13293, 'upper_left_y': 7003, 'pol_width': 481, 'pol_height': 199, 'pix_area': 1.5321064653040162e-05})
# ('0_9', {'upper_left_x': 0, 'upper_left_y': 7950, 'pol_width': 189, 'pol_height': 125, 'pix_area': 2.441742547099398e-06})
# ('1_467', {'upper_left_x': 12256, 'upper_left_y': 9524, 'pol_width': 193, 'pol_height': 206, 'pix_area': 6.588912361625235e-06})
# ('1_455', {'upper_left_x': 15644, 'upper_left_y': 10198, 'pol_width': 478, 'pol_height': 485, 'pix_area': 1.4106942027593286e-05})
# ('0_119', {'upper_left_x': 3017, 'upper_left_y': 10336, 'pol_width': 653, 'pol_height': 100, 'pix_area': 8.387267919443226e-06})
# ('1_668', {'upper_left_x': 6887, 'upper_left_y': 5737, 'pol_width': 151, 'pol_height': 129, 'pix_area': 3.6810114274110994e-06})
# ('1_607', {'upper_left_x': 10486, 'upper_left_y': 12686, 'pol_width': 349, 'pol_height': 487, 'pix_area': 2.472925874353489e-05})
# ('0_150', {'upper_left_x': 1038, 'upper_left_y': 13986, 'pol_width': 368, 'pol_height': 114, 'pix_area': 7.2477202662807005e-06})
# ('1_51', {'upper_left_x': 11365, 'upper_left_y': 5467, 'pol_width': 437, 'pol_height': 510, 'pix_area': 1.7991696337464013e-05})
# ('1_197', {'upper_left_x': 13186, 'upper_left_y': 6868, 'pol_width': 523, 'pol_height': 225, 'pix_area': 8.410171126973016e-06})
# ('1_919', {'upper_left_x': 16454, 'upper_left_y': 13805, 'pol_width': 381, 'pol_height': 348, 'pix_area': 8.576436396963566e-06})
# ('0_209', {'upper_left_x': 325, 'upper_left_y': 13540, 'pol_width': 515, 'pol_height': 441, 'pix_area': 4.555059758082957e-05})
# ('0_147', {'upper_left_x': 2366, 'upper_left_y': 11907, 'pol_width': 796, 'pol_height': 285, 'pix_area': 3.313709560532702e-05})
# ('1_350', {'upper_left_x': 16793, 'upper_left_y': 10262, 'pol_width': 578, 'pol_height': 152, 'pix_area': 1.3130528208509356e-05})
# ('1_531', {'upper_left_x': 11321, 'upper_left_y': 11020, 'pol_width': 311, 'pol_height': 262, 'pix_area': 1.7489759768802818e-05})
# ('0_132', {'upper_left_x': 553, 'upper_left_y': 12367, 'pol_width': 234, 'pol_height': 117, 'pix_area': 3.750976408294222e-06})
# ('1_143', {'upper_left_x': 10689, 'upper_left_y': 6364, 'pol_width': 811, 'pol_height': 251, 'pix_area': 1.60175781785294e-05})
# ('1_815', {'upper_left_x': 17507, 'upper_left_y': 12903, 'pol_width': 509, 'pol_height': 308, 'pix_area': 2.2234035374870335e-05})
# ('0_251', {'upper_left_x': 1422, 'upper_left_y': 12970, 'pol_width': 104, 'pol_height': 73, 'pix_area': 1.8892261294790226e-06})
# ('1_522', {'upper_left_x': 12445, 'upper_left_y': 9296, 'pol_width': 462, 'pol_height': 144, 'pix_area': 1.5672426117113977e-05})
# ('1_801', {'upper_left_x': 18654, 'upper_left_y': 13623, 'pol_width': 465, 'pol_height': 292, 'pix_area': 1.8922137468524658e-05})
# ('1_636', {'upper_left_x': 7057, 'upper_left_y': 5512, 'pol_width': 556, 'pol_height': 322, 'pix_area': 3.9492293315317144e-05})
# ('0_128', {'upper_left_x': 2121, 'upper_left_y': 9559, 'pol_width': 369, 'pol_height': 84, 'pix_area': 2.882969412664232e-06})
# ('1_556', {'upper_left_x': 13477, 'upper_left_y': 9819, 'pol_width': 750, 'pol_height': 241, 'pix_area': 3.2336787452411915e-05})
# ('1_715', {'upper_left_x': 1122, 'upper_left_y': 4410, 'pol_width': 1961, 'pol_height': 145, 'pix_area': 6.616846541402579e-06})
# ('0_198', {'upper_left_x': 1496, 'upper_left_y': 13587, 'pol_width': 584, 'pol_height': 254, 'pix_area': 3.2811353573120246e-05})
# ('1_690', {'upper_left_x': 4877, 'upper_left_y': 4704, 'pol_width': 248, 'pol_height': 381, 'pix_area': 1.5604865261081854e-05})
# ('1_783', {'upper_left_x': 9911, 'upper_left_y': 14222, 'pol_width': 308, 'pol_height': 112, 'pix_area': 6.526966953297714e-06})
# ('1_744', {'upper_left_x': 0, 'upper_left_y': 5591, 'pol_width': 231, 'pol_height': 128, 'pix_area': 4.055241376673432e-06})
# ('1_229', {'upper_left_x': 11038, 'upper_left_y': 7391, 'pol_width': 301, 'pol_height': 97, 'pix_area': 6.768301707975779e-06})
# ('0_18', {'upper_left_x': 2306, 'upper_left_y': 8363, 'pol_width': 85, 'pol_height': 94, 'pix_area': 1.0532375721728782e-06})
# ('1_793', {'upper_left_x': 17418, 'upper_left_y': 14265, 'pol_width': 603, 'pol_height': 260, 'pix_area': 2.441749610441794e-05})
# ('1_193', {'upper_left_x': 11685, 'upper_left_y': 6561, 'pol_width': 351, 'pol_height': 124, 'pix_area': 8.370752963214832e-06})
# ('1_408', {'upper_left_x': 19188, 'upper_left_y': 10272, 'pol_width': 335, 'pol_height': 116, 'pix_area': 8.688300807958394e-06})
# ('1_28', {'upper_left_x': 12718, 'upper_left_y': 7130, 'pol_width': 858, 'pol_height': 176, 'pix_area': 1.7513727119655623e-05})
# ('0_48', {'upper_left_x': 548, 'upper_left_y': 11429, 'pol_width': 499, 'pol_height': 509, 'pix_area': 3.955420694812425e-05})
# ('1_687', {'upper_left_x': 5728, 'upper_left_y': 6966, 'pol_width': 1226, 'pol_height': 325, 'pix_area': 5.3623819503271265e-05})
# ('1_191', {'upper_left_x': 12740, 'upper_left_y': 7033, 'pol_width': 339, 'pol_height': 137, 'pix_area': 8.359376242772144e-06})
# ('1_724', {'upper_left_x': 872, 'upper_left_y': 5709, 'pol_width': 523, 'pol_height': 358, 'pix_area': 3.5416145718775704e-05})
# ('1_107', {'upper_left_x': 19434, 'upper_left_y': 8273, 'pol_width': 368, 'pol_height': 153, 'pix_area': 8.088959979879272e-06})
# ('1_262', {'upper_left_x': 15296, 'upper_left_y': 7641, 'pol_width': 444, 'pol_height': 202, 'pix_area': 1.4125944360859795e-05})
# ('1_590', {'upper_left_x': 19456, 'upper_left_y': 10593, 'pol_width': 652, 'pol_height': 100, 'pix_area': 8.387267919443226e-06})
# ('0_226', {'upper_left_x': 1060, 'upper_left_y': 13898, 'pol_width': 317, 'pol_height': 101, 'pix_area': 7.036894573287844e-06})
# ('1_513', {'upper_left_x': 4872, 'upper_left_y': 6292, 'pol_width': 143, 'pol_height': 242, 'pix_area': 5.751687550511749e-06})
# ('0_33', {'upper_left_x': 733, 'upper_left_y': 10970, 'pol_width': 338, 'pol_height': 115, 'pix_area': 6.182577058901917e-06})
# ('1_909', {'upper_left_x': 16776, 'upper_left_y': 14400, 'pol_width': 639, 'pol_height': 313, 'pix_area': 1.673984505897097e-05})
# ('1_360', {'upper_left_x': 11023, 'upper_left_y': 13021, 'pol_width': 147, 'pol_height': 128, 'pix_area': 3.3212711362295313e-06})
# ('1_548', {'upper_left_x': 13758, 'upper_left_y': 9383, 'pol_width': 999, 'pol_height': 447, 'pix_area': 8.001176770313348e-05})
# ('1_125', {'upper_left_x': 15444, 'upper_left_y': 8030, 'pol_width': 362, 'pol_height': 152, 'pix_area': 3.853613190139224e-06})
# ('1_241', {'upper_left_x': 12808, 'upper_left_y': 8082, 'pol_width': 164, 'pol_height': 125, 'pix_area': 5.201356792751026e-06})
# ('1_347', {'upper_left_x': 15810, 'upper_left_y': 9966, 'pol_width': 394, 'pol_height': 232, 'pix_area': 1.8160782546073984e-05})
# ('1_961', {'upper_left_x': 18544, 'upper_left_y': 11707, 'pol_width': 97, 'pol_height': 145, 'pix_area': 2.085730448859158e-06})
# ('1_88', {'upper_left_x': 12298, 'upper_left_y': 6532, 'pol_width': 720, 'pol_height': 380, 'pix_area': 2.7910714275554826e-05})
# ('1_1005', {'upper_left_x': 1182, 'upper_left_y': 10132, 'pol_width': 645, 'pol_height': 147, 'pix_area': 2.117770628829853e-05})
# ('1_46', {'upper_left_x': 16838, 'upper_left_y': 7590, 'pol_width': 179, 'pol_height': 94, 'pix_area': 1.9564609032819624e-06})
# ('0_163', {'upper_left_x': 889, 'upper_left_y': 11852, 'pol_width': 348, 'pol_height': 212, 'pix_area': 1.243963333947607e-05})
# ('1_181', {'upper_left_x': 12404, 'upper_left_y': 6410, 'pol_width': 265, 'pol_height': 46, 'pix_area': 2.3847153009665915e-06})
# ('1_58', {'upper_left_x': 11762, 'upper_left_y': 6322, 'pol_width': 558, 'pol_height': 146, 'pix_area': 1.6107401835255446e-05})
# ('1_349', {'upper_left_x': 17585, 'upper_left_y': 9705, 'pol_width': 354, 'pol_height': 100, 'pix_area': 6.5898465819189396e-06})
# ('1_774', {'upper_left_x': 3838, 'upper_left_y': 3082, 'pol_width': 347, 'pol_height': 189, 'pix_area': 8.451895875449065e-06})
# ('0_19', {'upper_left_x': 2239, 'upper_left_y': 8411, 'pol_width': 335, 'pol_height': 138, 'pix_area': 7.370734429147827e-06})
# ('1_298', {'upper_left_x': 13184, 'upper_left_y': 7665, 'pol_width': 490, 'pol_height': 203, 'pix_area': 1.786260619206527e-05})
# ('1_1039', {'upper_left_x': 3345, 'upper_left_y': 10256, 'pol_width': 646, 'pol_height': 223, 'pix_area': 1.5472288099870634e-05})
# ('1_615', {'upper_left_x': 16588, 'upper_left_y': 12550, 'pol_width': 643, 'pol_height': 180, 'pix_area': 1.9667566762235596e-05})
# ('1_494', {'upper_left_x': 4883, 'upper_left_y': 2619, 'pol_width': 654, 'pol_height': 274, 'pix_area': 2.8542799475715138e-05})
# ('1_358', {'upper_left_x': 10400, 'upper_left_y': 12463, 'pol_width': 325, 'pol_height': 357, 'pix_area': 1.9129028045072188e-05})
# ('0_140', {'upper_left_x': 0, 'upper_left_y': 12515, 'pol_width': 135, 'pol_height': 92, 'pix_area': 3.2111397669163623e-06})
# ('0_214', {'upper_left_x': 0, 'upper_left_y': 13493, 'pol_width': 159, 'pol_height': 82, 'pix_area': 2.1261782107860097e-06})
# ('1_505', {'upper_left_x': 4042, 'upper_left_y': 6529, 'pol_width': 186, 'pol_height': 138, 'pix_area': 4.7788124273573515e-06})
# ('1_13', {'upper_left_x': 10928, 'upper_left_y': 5590, 'pol_width': 366, 'pol_height': 298, 'pix_area': 1.3001427228472512e-05})
# ('1_856', {'upper_left_x': 17100, 'upper_left_y': 12998, 'pol_width': 264, 'pol_height': 98, 'pix_area': 4.628526849606739e-06})
# ('1_93', {'upper_left_x': 15984, 'upper_left_y': 8874, 'pol_width': 386, 'pol_height': 402, 'pix_area': 1.2485237553887231e-05})
# ('1_1046', {'upper_left_x': 267, 'upper_left_y': 8460, 'pol_width': 406, 'pol_height': 365, 'pix_area': 3.226580465241351e-05})
# ('1_111', {'upper_left_x': 9911, 'upper_left_y': 5445, 'pol_width': 275, 'pol_height': 86, 'pix_area': 3.533197792824412e-06})
# ('1_319', {'upper_left_x': 17916, 'upper_left_y': 9733, 'pol_width': 137, 'pol_height': 164, 'pix_area': 2.819357873211331e-06})
# ('1_780', {'upper_left_x': 11765, 'upper_left_y': 13339, 'pol_width': 152, 'pol_height': 65, 'pix_area': 2.298591219076818e-06})
# ('1_753', {'upper_left_x': 1552, 'upper_left_y': 3044, 'pol_width': 179, 'pol_height': 147, 'pix_area': 6.215088959013768e-06})
# ('1_277', {'upper_left_x': 16084, 'upper_left_y': 8186, 'pol_width': 75, 'pol_height': 120, 'pix_area': 1.2396485888912174e-06})
# ('0_190', {'upper_left_x': 835, 'upper_left_y': 13797, 'pol_width': 625, 'pol_height': 255, 'pix_area': 1.9631933712232842e-05})
# ('0_260', {'upper_left_x': 2508, 'upper_left_y': 13377, 'pol_width': 235, 'pol_height': 217, 'pix_area': 9.94553481617876e-06})
# ('0_27', {'upper_left_x': 717, 'upper_left_y': 9407, 'pol_width': 521, 'pol_height': 248, 'pix_area': 2.3808078414295693e-05})
# ('1_776', {'upper_left_x': 3772, 'upper_left_y': 2360, 'pol_width': 691, 'pol_height': 395, 'pix_area': 6.30575914526645e-05})
# ('1_196', {'upper_left_x': 13667, 'upper_left_y': 6899, 'pol_width': 256, 'pol_height': 195, 'pix_area': 1.1383029256306512e-05})
# ('1_366', {'upper_left_x': 13028, 'upper_left_y': 11915, 'pol_width': 437, 'pol_height': 165, 'pix_area': 1.1685848609923865e-05})
# ('1_689', {'upper_left_x': 5047, 'upper_left_y': 4961, 'pol_width': 343, 'pol_height': 167, 'pix_area': 1.3116960436164968e-05})
# ('1_635', {'upper_left_x': 7198, 'upper_left_y': 5317, 'pol_width': 415, 'pol_height': 242, 'pix_area': 1.4779276980276719e-05})
# ('1_256', {'upper_left_x': 13899, 'upper_left_y': 7964, 'pol_width': 86, 'pol_height': 93, 'pix_area': 1.276412890801621e-06})
# ('1_717', {'upper_left_x': 1199, 'upper_left_y': 6382, 'pol_width': 139, 'pol_height': 93, 'pix_area': 2.857739414978901e-06})
# ('1_105', {'upper_left_x': 16921, 'upper_left_y': 7327, 'pol_width': 299, 'pol_height': 154, 'pix_area': 6.28679938154979e-06})
# ('0_244', {'upper_left_x': 538, 'upper_left_y': 13329, 'pol_width': 546, 'pol_height': 123, 'pix_area': 7.071059765023489e-06})
# ('1_676', {'upper_left_x': 5757, 'upper_left_y': 6931, 'pol_width': 361, 'pol_height': 145, 'pix_area': 5.948543530848368e-06})
# ('0_187', {'upper_left_x': 775, 'upper_left_y': 12538, 'pol_width': 426, 'pol_height': 157, 'pix_area': 1.2663186801242166e-05})
# ('0_130', {'upper_left_x': 2763, 'upper_left_y': 9611, 'pol_width': 586, 'pol_height': 161, 'pix_area': 3.744033716328547e-06})
# ('1_448', {'upper_left_x': 12770, 'upper_left_y': 12569, 'pol_width': 195, 'pol_height': 124, 'pix_area': 5.2737834447307945e-06})
# ('0_194', {'upper_left_x': 2006, 'upper_left_y': 14080, 'pol_width': 240, 'pol_height': 122, 'pix_area': 7.62265804738971e-06})
# ('1_1090', {'upper_left_x': 434, 'upper_left_y': 8179, 'pol_width': 514, 'pol_height': 262, 'pix_area': 2.8560864571055682e-05})
# ('1_935', {'upper_left_x': 18284, 'upper_left_y': 14252, 'pol_width': 691, 'pol_height': 155, 'pix_area': 1.8195743943921983e-05})
# ('1_31', {'upper_left_x': 13031, 'upper_left_y': 6764, 'pol_width': 175, 'pol_height': 65, 'pix_area': 2.2050430184528086e-06})
# ('1_657', {'upper_left_x': 7003, 'upper_left_y': 5053, 'pol_width': 348, 'pol_height': 316, 'pix_area': 2.0635849417270216e-05})
# ('1_312', {'upper_left_x': 0, 'upper_left_y': 779, 'pol_width': 466, 'pol_height': 1167, 'pix_area': 7.135138313446225e-06})
# ('0_141', {'upper_left_x': 212, 'upper_left_y': 13183, 'pol_width': 312, 'pol_height': 117, 'pix_area': 8.195129435671286e-06})
# ('1_219', {'upper_left_x': 10459, 'upper_left_y': 7934, 'pol_width': 542, 'pol_height': 68, 'pix_area': 6.2392882039359835e-06})
# ('0_217', {'upper_left_x': 471, 'upper_left_y': 13996, 'pol_width': 259, 'pol_height': 133, 'pix_area': 6.205021806511793e-06})
# ('1_528', {'upper_left_x': 12032, 'upper_left_y': 10651, 'pol_width': 294, 'pol_height': 300, 'pix_area': 9.581016381265226e-06})
# ('1_498', {'upper_left_x': 3984, 'upper_left_y': 4855, 'pol_width': 688, 'pol_height': 280, 'pix_area': 2.5706113604007567e-05})
# ('1_906', {'upper_left_x': 15996, 'upper_left_y': 13688, 'pol_width': 894, 'pol_height': 236, 'pix_area': 1.6291366713599937e-05})
# ('1_1', {'upper_left_x': 11902, 'upper_left_y': 5681, 'pol_width': 893, 'pol_height': 345, 'pix_area': 6.827370632822096e-05})
# ('0_102', {'upper_left_x': 1687, 'upper_left_y': 9620, 'pol_width': 185, 'pol_height': 210, 'pix_area': 7.393268653215491e-06})
# ('1_65', {'upper_left_x': 13511, 'upper_left_y': 7073, 'pol_width': 365, 'pol_height': 188, 'pix_area': 6.3322917184454616e-06})
# ('0_125', {'upper_left_x': 2656, 'upper_left_y': 10333, 'pol_width': 347, 'pol_height': 123, 'pix_area': 9.674865984304723e-06})
# ('1_1042', {'upper_left_x': 667, 'upper_left_y': 8543, 'pol_width': 1331, 'pol_height': 471, 'pix_area': 5.7756252292176524e-05})
# ('1_357', {'upper_left_x': 11144, 'upper_left_y': 12376, 'pol_width': 433, 'pol_height': 109, 'pix_area': 8.323373973941714e-06})
# ('1_558', {'upper_left_x': 15078, 'upper_left_y': 9607, 'pol_width': 232, 'pol_height': 257, 'pix_area': 9.455892778552073e-06})
# ('1_121', {'upper_left_x': 11354, 'upper_left_y': 6558, 'pol_width': 361, 'pol_height': 145, 'pix_area': 6.971325120837824e-06})
# ('1_212', {'upper_left_x': 10164, 'upper_left_y': 8116, 'pol_width': 168, 'pol_height': 104, 'pix_area': 4.4807445379831726e-06})
# ('1_561', {'upper_left_x': 15558, 'upper_left_y': 10528, 'pol_width': 135, 'pol_height': 116, 'pix_area': 2.377724785611235e-06})
# ('1_980', {'upper_left_x': 0, 'upper_left_y': 7580, 'pol_width': 271, 'pol_height': 236, 'pix_area': 1.5254569718893108e-05})
# ('1_114', {'upper_left_x': 10677, 'upper_left_y': 7011, 'pol_width': 301, 'pol_height': 129, 'pix_area': 4.7244516205684435e-06})
# ('1_552', {'upper_left_x': 13686, 'upper_left_y': 9512, 'pol_width': 547, 'pol_height': 519, 'pix_area': 8.06009544654249e-06})
# ('1_1011', {'upper_left_x': 1521, 'upper_left_y': 9271, 'pol_width': 128, 'pol_height': 189, 'pix_area': 4.967350827850728e-06})
# ('1_656', {'upper_left_x': 6406, 'upper_left_y': 5189, 'pol_width': 95, 'pol_height': 75, 'pix_area': 1.615600958810628e-06})
# ('1_1033', {'upper_left_x': 3710, 'upper_left_y': 9141, 'pol_width': 567, 'pol_height': 359, 'pix_area': 2.2204487440429755e-05})
# ('1_515', {'upper_left_x': 4501, 'upper_left_y': 6116, 'pol_width': 277, 'pol_height': 106, 'pix_area': 5.529106118005014e-06})
# ('1_991', {'upper_left_x': 0, 'upper_left_y': 7086, 'pol_width': 530, 'pol_height': 299, 'pix_area': 2.6059909964943676e-05})
# ('1_586', {'upper_left_x': 18012, 'upper_left_y': 11449, 'pol_width': 921, 'pol_height': 260, 'pix_area': 2.944588096155935e-05})
# ('0_21', {'upper_left_x': 3054, 'upper_left_y': 8198, 'pol_width': 649, 'pol_height': 216, 'pix_area': 2.3571341871723783e-05})
# ('1_852', {'upper_left_x': 10449, 'upper_left_y': 14285, 'pol_width': 188, 'pol_height': 96, 'pix_area': 1.9238178007777015e-06})
# ('1_536', {'upper_left_x': 12415, 'upper_left_y': 11021, 'pol_width': 450, 'pol_height': 175, 'pix_area': 1.8254179840341073e-05})
# ('1_788', {'upper_left_x': 12881, 'upper_left_y': 13513, 'pol_width': 467, 'pol_height': 288, 'pix_area': 2.7149059887640783e-05})
# ('1_998', {'upper_left_x': 1454, 'upper_left_y': 8783, 'pol_width': 569, 'pol_height': 323, 'pix_area': 2.0609750697409033e-05})
# ('0_193', {'upper_left_x': 1161, 'upper_left_y': 11397, 'pol_width': 454, 'pol_height': 651, 'pix_area': 2.5166289169634743e-05})
# ('1_415', {'upper_left_x': 6287, 'upper_left_y': 7054, 'pol_width': 108, 'pol_height': 62, 'pix_area': 1.0917019979988958e-06})
# ('1_323', {'upper_left_x': 11847, 'upper_left_y': 9923, 'pol_width': 581, 'pol_height': 246, 'pix_area': 2.411917749200814e-05})
# ('1_685', {'upper_left_x': 5475, 'upper_left_y': 8286, 'pol_width': 1136, 'pol_height': 396, 'pix_area': 8.105695001746365e-05})
# ('1_829', {'upper_left_x': 19229, 'upper_left_y': 11744, 'pol_width': 529, 'pol_height': 369, 'pix_area': 2.8789538800920775e-05})
# ('1_54', {'upper_left_x': 11957, 'upper_left_y': 6028, 'pol_width': 577, 'pol_height': 253, 'pix_area': 1.816350334785808e-05})
# ('1_411', {'upper_left_x': 19037, 'upper_left_y': 10312, 'pol_width': 190, 'pol_height': 88, 'pix_area': 3.3828088654627044e-06})
# ('1_830', {'upper_left_x': 17187, 'upper_left_y': 11921, 'pol_width': 2526, 'pol_height': 936, 'pix_area': 8.331442548932713e-06})
# ('1_729', {'upper_left_x': 2064, 'upper_left_y': 4958, 'pol_width': 857, 'pol_height': 567, 'pix_area': 6.127593876919436e-05})
# ('0_205', {'upper_left_x': 0, 'upper_left_y': 13575, 'pol_width': 128, 'pol_height': 144, 'pix_area': 2.226126297142909e-06})
# ('1_109', {'upper_left_x': 18540, 'upper_left_y': 8487, 'pol_width': 161, 'pol_height': 106, 'pix_area': 1.7493644408950888e-06})
# ('1_1092', {'upper_left_x': 154, 'upper_left_y': 7523, 'pol_width': 1711, 'pol_height': 719, 'pix_area': 0.00010124314013992354})
# ('1_728', {'upper_left_x': 1868, 'upper_left_y': 5767, 'pol_width': 591, 'pol_height': 504, 'pix_area': 3.853342865349421e-05})
# ('1_67', {'upper_left_x': 11163, 'upper_left_y': 5229, 'pol_width': 1009, 'pol_height': 241, 'pix_area': 2.035627247957529e-05})
# ('1_879', {'upper_left_x': 13089, 'upper_left_y': 14312, 'pol_width': 282, 'pol_height': 249, 'pix_area': 1.06100453385824e-05})
# ('1_928', {'upper_left_x': 17569, 'upper_left_y': 14778, 'pol_width': 248, 'pol_height': 78, 'pix_area': 3.2210229387998627e-06})
# ('1_896', {'upper_left_x': 18535, 'upper_left_y': 14205, 'pol_width': 284, 'pol_height': 77, 'pix_area': 5.406681257355339e-06})
# ('1_771', {'upper_left_x': 1480, 'upper_left_y': 2886, 'pol_width': 161, 'pol_height': 144, 'pix_area': 5.2418815249069724e-06})
# ('1_971', {'upper_left_x': 17800, 'upper_left_y': 11923, 'pol_width': 714, 'pol_height': 222, 'pix_area': 3.605436630379244e-05})
# ('1_696', {'upper_left_x': 3281, 'upper_left_y': 6015, 'pol_width': 1779, 'pol_height': 375, 'pix_area': 6.807242462414301e-05})
# ('1_826', {'upper_left_x': 12093, 'upper_left_y': 13972, 'pol_width': 362, 'pol_height': 322, 'pix_area': 1.1135083740897845e-05})
# ('1_796', {'upper_left_x': 16537, 'upper_left_y': 14214, 'pol_width': 318, 'pol_height': 126, 'pix_area': 6.1887380038297726e-06})
# ('1_784', {'upper_left_x': 9941, 'upper_left_y': 14190, 'pol_width': 324, 'pol_height': 153, 'pix_area': 5.519051164940559e-06})
# ('1_922', {'upper_left_x': 17285, 'upper_left_y': 13900, 'pol_width': 536, 'pol_height': 231, 'pix_area': 1.4881863199362815e-05})
# ('1_272', {'upper_left_x': 14812, 'upper_left_y': 7575, 'pol_width': 244, 'pol_height': 211, 'pix_area': 1.0911815795797876e-05})
# ('1_215', {'upper_left_x': 10144, 'upper_left_y': 8067, 'pol_width': 1044, 'pol_height': 299, 'pix_area': 2.3205652761823275e-05})
# ('1_16', {'upper_left_x': 12641, 'upper_left_y': 5684, 'pol_width': 300, 'pol_height': 96, 'pix_area': 4.243977842904106e-06})
# ('0_216', {'upper_left_x': 599, 'upper_left_y': 14061, 'pol_width': 200, 'pol_height': 134, 'pix_area': 5.321421302049583e-06})
# ('0_177', {'upper_left_x': 1368, 'upper_left_y': 11408, 'pol_width': 775, 'pol_height': 294, 'pix_area': 6.0306496027403174e-05})
# ('1_616', {'upper_left_x': 16607, 'upper_left_y': 12519, 'pol_width': 239, 'pol_height': 83, 'pix_area': 3.506703420778876e-06})
# ('1_1009', {'upper_left_x': 1532, 'upper_left_y': 9391, 'pol_width': 555, 'pol_height': 277, 'pix_area': 1.9673895066461726e-05})
# ('1_932', {'upper_left_x': 17749, 'upper_left_y': 14186, 'pol_width': 136, 'pol_height': 83, 'pix_area': 2.5614076747668073e-06})
# ('1_1013', {'upper_left_x': 3118, 'upper_left_y': 10263, 'pol_width': 88, 'pol_height': 225, 'pix_area': 2.8793675627959727e-06})
# ('1_612', {'upper_left_x': 16241, 'upper_left_y': 12841, 'pol_width': 310, 'pol_height': 92, 'pix_area': 5.920968386015575e-06})
# ('1_383', {'upper_left_x': 5491, 'upper_left_y': 6580, 'pol_width': 167, 'pol_height': 74, 'pix_area': 2.3340349361177123e-06})
# ('1_588', {'upper_left_x': 19347, 'upper_left_y': 10904, 'pol_width': 626, 'pol_height': 160, 'pix_area': 1.9755818345375422e-05})
# ('1_437', {'upper_left_x': 10774, 'upper_left_y': 12928, 'pol_width': 200, 'pol_height': 229, 'pix_area': 6.550006629573928e-06})
# ('1_539', {'upper_left_x': 12126, 'upper_left_y': 10443, 'pol_width': 425, 'pol_height': 236, 'pix_area': 2.3447411641881248e-05})
# ('1_401', {'upper_left_x': 4895, 'upper_left_y': 6601, 'pol_width': 248, 'pol_height': 125, 'pix_area': 6.07576617264169e-06})
# ('1_7', {'upper_left_x': 10081, 'upper_left_y': 6774, 'pol_width': 123, 'pol_height': 145, 'pix_area': 2.3801502696275773e-06})
# ('1_600', {'upper_left_x': 18940, 'upper_left_y': 9866, 'pol_width': 267, 'pol_height': 35, 'pix_area': 1.8260573288371718e-06})
# ('1_843', {'upper_left_x': 19122, 'upper_left_y': 12100, 'pol_width': 287, 'pol_height': 72, 'pix_area': 3.369246303917753e-06})
# ('1_160', {'upper_left_x': 11047, 'upper_left_y': 6911, 'pol_width': 542, 'pol_height': 162, 'pix_area': 1.493017165833721e-05})
# ('1_695', {'upper_left_x': 3816, 'upper_left_y': 6520, 'pol_width': 325, 'pol_height': 144, 'pix_area': 8.30529454187072e-06})
# ('1_608', {'upper_left_x': 10981, 'upper_left_y': 13059, 'pol_width': 105, 'pol_height': 185, 'pix_area': 2.6373699200527677e-06})
# ('1_491', {'upper_left_x': 1125, 'upper_left_y': 4213, 'pol_width': 343, 'pol_height': 219, 'pix_area': 1.902866041215063e-05})
# ('1_102', {'upper_left_x': 13547, 'upper_left_y': 7775, 'pol_width': 437, 'pol_height': 325, 'pix_area': 2.4520976923938378e-05})
# ('1_725', {'upper_left_x': 1311, 'upper_left_y': 6264, 'pol_width': 1084, 'pol_height': 283, 'pix_area': 4.880143817950449e-05})
# ('0_96', {'upper_left_x': 892, 'upper_left_y': 10547, 'pol_width': 310, 'pol_height': 307, 'pix_area': 1.4600411199108621e-05})
# ('1_805', {'upper_left_x': 19499, 'upper_left_y': 11824, 'pol_width': 232, 'pol_height': 110, 'pix_area': 4.954032892476746e-06})
# ('1_631', {'upper_left_x': 6648, 'upper_left_y': 4890, 'pol_width': 199, 'pol_height': 101, 'pix_area': 4.270755465258528e-06})
# ('1_84', {'upper_left_x': 13585, 'upper_left_y': 5945, 'pol_width': 635, 'pol_height': 162, 'pix_area': 1.2228487638522126e-05})
# ('1_61', {'upper_left_x': 12159, 'upper_left_y': 6889, 'pol_width': 241, 'pol_height': 76, 'pix_area': 2.789955963428796e-06})
# ('1_19', {'upper_left_x': 12987, 'upper_left_y': 5981, 'pol_width': 258, 'pol_height': 299, 'pix_area': 1.594398421845665e-05})
# ('1_842', {'upper_left_x': 17217, 'upper_left_y': 12792, 'pol_width': 425, 'pol_height': 157, 'pix_area': 1.2663186801242166e-05})
# ('1_315', {'upper_left_x': 15873, 'upper_left_y': 9711, 'pol_width': 584, 'pol_height': 276, 'pix_area': 3.320151899908764e-05})
# ('1_3', {'upper_left_x': 10270, 'upper_left_y': 5506, 'pol_width': 415, 'pol_height': 223, 'pix_area': 1.3875842174031908e-05})
# ('1_343', {'upper_left_x': 16042, 'upper_left_y': 10996, 'pol_width': 495, 'pol_height': 137, 'pix_area': 1.1132982715112503e-05})
# ('1_660', {'upper_left_x': 6696, 'upper_left_y': 6205, 'pol_width': 337, 'pol_height': 281, 'pix_area': 1.338628126118375e-05})
# ('1_671', {'upper_left_x': 5339, 'upper_left_y': 6280, 'pol_width': 422, 'pol_height': 229, 'pix_area': 8.56814122345057e-06})
# ('1_253', {'upper_left_x': 12911, 'upper_left_y': 9067, 'pol_width': 282, 'pol_height': 271, 'pix_area': 1.736525696146791e-05})
# ('1_281', {'upper_left_x': 13193, 'upper_left_y': 9014, 'pol_width': 285, 'pol_height': 176, 'pix_area': 6.514951284269742e-06})
# ('1_18', {'upper_left_x': 12604, 'upper_left_y': 6010, 'pol_width': 193, 'pol_height': 108, 'pix_area': 3.469909972107801e-06})
# ('0_31', {'upper_left_x': 959, 'upper_left_y': 11123, 'pol_width': 204, 'pol_height': 103, 'pix_area': 3.7956000105199503e-06})
# ('1_649', {'upper_left_x': 6216, 'upper_left_y': 6484, 'pol_width': 480, 'pol_height': 60, 'pix_area': 3.051448474605786e-06})
# ('1_954', {'upper_left_x': 17269, 'upper_left_y': 12893, 'pol_width': 1395, 'pol_height': 626, 'pix_area': 6.286454543002872e-05})
# ('0_247', {'upper_left_x': 827, 'upper_left_y': 12640, 'pol_width': 1397, 'pol_height': 627, 'pix_area': 6.286454543002872e-05})
# ('1_1065', {'upper_left_x': 2206, 'upper_left_y': 6635, 'pol_width': 2210, 'pol_height': 593, 'pix_area': 0.00015398960903379095})
# ('1_626', {'upper_left_x': 5993, 'upper_left_y': 5525, 'pol_width': 937, 'pol_height': 317, 'pix_area': 2.7535727076098597e-05})
# ('1_1026', {'upper_left_x': 3789, 'upper_left_y': 9632, 'pol_width': 359, 'pol_height': 249, 'pix_area': 1.3906976404033432e-05})
# ('1_52', {'upper_left_x': 13269, 'upper_left_y': 5282, 'pol_width': 1099, 'pol_height': 331, 'pix_area': 3.8156821457898e-06})
# ('1_639', {'upper_left_x': 6975, 'upper_left_y': 5890, 'pol_width': 382, 'pol_height': 147, 'pix_area': 8.187417099814188e-06})
# ('1_883', {'upper_left_x': 11397, 'upper_left_y': 13797, 'pol_width': 201, 'pol_height': 205, 'pix_area': 5.935134094852195e-06})
# ('1_497', {'upper_left_x': 3872, 'upper_left_y': 4639, 'pol_width': 491, 'pol_height': 519, 'pix_area': 2.030865465339767e-05})
# ('1_405', {'upper_left_x': 5825, 'upper_left_y': 5356, 'pol_width': 268, 'pol_height': 272, 'pix_area': 4.651799359834859e-06})
# ('1_535', {'upper_left_x': 12978, 'upper_left_y': 10770, 'pol_width': 268, 'pol_height': 275, 'pix_area': 1.1379342428343572e-05})
# ('1_754', {'upper_left_x': 1697, 'upper_left_y': 2574, 'pol_width': 376, 'pol_height': 176, 'pix_area': 9.274961774211497e-06})
# ('1_307', {'upper_left_x': 0, 'upper_left_y': 3774, 'pol_width': 1136, 'pol_height': 307, 'pix_area': 2.8980522841061397e-05})
# ('1_86', {'upper_left_x': 11630, 'upper_left_y': 7188, 'pol_width': 1425, 'pol_height': 184, 'pix_area': 2.1003348984729145e-05})
# ('1_186', {'upper_left_x': 11960, 'upper_left_y': 6590, 'pol_width': 367, 'pol_height': 115, 'pix_area': 7.364271821955394e-06})
# ('1_297', {'upper_left_x': 13625, 'upper_left_y': 7580, 'pol_width': 202, 'pol_height': 228, 'pix_area': 5.821613269811897e-06})
# ('1_534', {'upper_left_x': 12583, 'upper_left_y': 10919, 'pol_width': 529, 'pol_height': 132, 'pix_area': 8.613355342429118e-06})
# ('0_134', {'upper_left_x': 0, 'upper_left_y': 12596, 'pol_width': 109, 'pol_height': 83, 'pix_area': 2.38631130849146e-06})
# ('1_431', {'upper_left_x': 19271, 'upper_left_y': 11094, 'pol_width': 377, 'pol_height': 95, 'pix_area': 4.798118619019348e-06})
# ('1_514', {'upper_left_x': 4722, 'upper_left_y': 6390, 'pol_width': 224, 'pol_height': 204, 'pix_area': 5.892268748177778e-06})
# ('1_4', {'upper_left_x': 9984, 'upper_left_y': 6549, 'pol_width': 457, 'pol_height': 102, 'pix_area': 5.525553706154241e-06})
# ('1_508', {'upper_left_x': 592, 'upper_left_y': 6180, 'pol_width': 515, 'pol_height': 278, 'pix_area': 2.0303797925403223e-05})
# ('1_1093', {'upper_left_x': 1847, 'upper_left_y': 7980, 'pol_width': 507, 'pol_height': 287, 'pix_area': 2.979784234744797e-05})
# ('1_511', {'upper_left_x': 4616, 'upper_left_y': 6117, 'pol_width': 409, 'pol_height': 179, 'pix_area': 8.025538188976639e-06})
# ('1_545', {'upper_left_x': 13164, 'upper_left_y': 10771, 'pol_width': 340, 'pol_height': 350, 'pix_area': 2.2457249945273397e-05})
# ('0_15', {'upper_left_x': 2392, 'upper_left_y': 8408, 'pol_width': 207, 'pol_height': 95, 'pix_area': 1.901943330819708e-06})
# ('1_94', {'upper_left_x': 15190, 'upper_left_y': 7774, 'pol_width': 263, 'pol_height': 181, 'pix_area': 5.798127539643218e-06})
# ('0_118', {'upper_left_x': 2941, 'upper_left_y': 10392, 'pol_width': 715, 'pol_height': 300, 'pix_area': 5.234868669958443e-05})
# ('1_429', {'upper_left_x': 19484, 'upper_left_y': 11173, 'pol_width': 324, 'pol_height': 236, 'pix_area': 8.175055350237062e-06})
# ('1_841', {'upper_left_x': 16466, 'upper_left_y': 13775, 'pol_width': 176, 'pol_height': 49, 'pix_area': 1.3500300472811817e-06})
# ('1_35', {'upper_left_x': 12268, 'upper_left_y': 7847, 'pol_width': 293, 'pol_height': 139, 'pix_area': 7.3015417271773684e-06})
# ('0_101', {'upper_left_x': 0, 'upper_left_y': 10320, 'pol_width': 293, 'pol_height': 518, 'pix_area': 2.9157504003624817e-05})
# ('1_1023', {'upper_left_x': 3039, 'upper_left_y': 9774, 'pol_width': 829, 'pol_height': 193, 'pix_area': 1.1192308808001277e-05})
# ('0_240', {'upper_left_x': 2080, 'upper_left_y': 13463, 'pol_width': 301, 'pol_height': 191, 'pix_area': 1.3515156205932333e-05})
# ('1_412', {'upper_left_x': 19511, 'upper_left_y': 10269, 'pol_width': 696, 'pol_height': 202, 'pix_area': 2.5364831901542644e-05})
# ('1_723', {'upper_left_x': 893, 'upper_left_y': 4986, 'pol_width': 703, 'pol_height': 456, 'pix_area': 4.991388472397279e-05})
# ('1_37', {'upper_left_x': 12309, 'upper_left_y': 7350, 'pol_width': 302, 'pol_height': 81, 'pix_area': 3.754092243095388e-06})
# ('1_218', {'upper_left_x': 10437, 'upper_left_y': 7978, 'pol_width': 558, 'pol_height': 120, 'pix_area': 1.491268137857177e-05})
# ('1_248', {'upper_left_x': 11443, 'upper_left_y': 7754, 'pol_width': 404, 'pol_height': 342, 'pix_area': 2.4021284177423776e-05})
# ('1_885', {'upper_left_x': 12292, 'upper_left_y': 13582, 'pol_width': 153, 'pol_height': 77, 'pix_area': 2.142135217980053e-06})
# ('1_795', {'upper_left_x': 17480, 'upper_left_y': 14237, 'pol_width': 367, 'pol_height': 114, 'pix_area': 7.2477202662807005e-06})
# ('1_674', {'upper_left_x': 6129, 'upper_left_y': 6809, 'pol_width': 956, 'pol_height': 440, 'pix_area': 7.838179771315261e-05})
# ('0_85', {'upper_left_x': 1164, 'upper_left_y': 10882, 'pol_width': 532, 'pol_height': 273, 'pix_area': 2.4361129996514353e-05})
# ('0_234', {'upper_left_x': 2224, 'upper_left_y': 11513, 'pol_width': 501, 'pol_height': 395, 'pix_area': 2.1660841155342522e-05})
# ('1_352', {'upper_left_x': 16460, 'upper_left_y': 10607, 'pol_width': 898, 'pol_height': 1000, 'pix_area': 4.194456291964404e-05})
# ('1_1058', {'upper_left_x': 37, 'upper_left_y': 10011, 'pol_width': 321, 'pol_height': 223, 'pix_area': 6.505243439088147e-06})
# ('1_379', {'upper_left_x': 4481, 'upper_left_y': 8127, 'pol_width': 1012, 'pol_height': 462, 'pix_area': 6.135059877158075e-05})
# ('0_100', {'upper_left_x': 343, 'upper_left_y': 10135, 'pol_width': 276, 'pol_height': 68, 'pix_area': 2.624473237523979e-06})
# ('1_132', {'upper_left_x': 11385, 'upper_left_y': 6652, 'pol_width': 204, 'pol_height': 54, 'pix_area': 1.7153531784514892e-06})
# ('1_6', {'upper_left_x': 9587, 'upper_left_y': 6350, 'pol_width': 500, 'pol_height': 352, 'pix_area': 2.154056085526503e-05})
# ('0_156', {'upper_left_x': 2708, 'upper_left_y': 12160, 'pol_width': 389, 'pol_height': 487, 'pix_area': 3.517690998531959e-05})
# ('0_49', {'upper_left_x': 737, 'upper_left_y': 11370, 'pol_width': 350, 'pol_height': 176, 'pix_area': 9.108833367418563e-06})
# ('1_650', {'upper_left_x': 5139, 'upper_left_y': 5691, 'pol_width': 745, 'pol_height': 224, 'pix_area': 2.6710022548472685e-05})
# ('1_708', {'upper_left_x': 3324, 'upper_left_y': 5235, 'pol_width': 1178, 'pol_height': 396, 'pix_area': 6.042126549004175e-05})
# ('0_24', {'upper_left_x': 0, 'upper_left_y': 9464, 'pol_width': 15, 'pol_height': 24, 'pix_area': 5.367525729063199e-08})
# ('1_778', {'upper_left_x': 18182, 'upper_left_y': 13461, 'pol_width': 492, 'pol_height': 198, 'pix_area': 2.3339160528547023e-05})
# ('1_833', {'upper_left_x': 12839, 'upper_left_y': 13466, 'pol_width': 541, 'pol_height': 186, 'pix_area': 1.1336987451563145e-05})
# ('1_269', {'upper_left_x': 13816, 'upper_left_y': 7988, 'pol_width': 146, 'pol_height': 97, 'pix_area': 2.1840873981350613e-06})
# ('0_223', {'upper_left_x': 1817, 'upper_left_y': 14106, 'pol_width': 605, 'pol_height': 297, 'pix_area': 1.3576638520163225e-05})
# ('0_68', {'upper_left_x': 3441, 'upper_left_y': 10886, 'pol_width': 73, 'pol_height': 86, 'pix_area': 1.3142386967394587e-06})
# ('1_584', {'upper_left_x': 18219, 'upper_left_y': 10734, 'pol_width': 425, 'pol_height': 335, 'pix_area': 2.6673476503604898e-05})
# ('1_173', {'upper_left_x': 10735, 'upper_left_y': 5719, 'pol_width': 594, 'pol_height': 791, 'pix_area': 3.1204068338832255e-05})
# ('1_512', {'upper_left_x': 4672, 'upper_left_y': 6468, 'pol_width': 257, 'pol_height': 126, 'pix_area': 4.872515437705465e-06})
# ('0_69', {'upper_left_x': 3046, 'upper_left_y': 10917, 'pol_width': 324, 'pol_height': 236, 'pix_area': 8.175055350237062e-06})
# ('1_940', {'upper_left_x': 18628, 'upper_left_y': 11966, 'pol_width': 248, 'pol_height': 59, 'pix_area': 3.082427479777825e-06})
# ('0_92', {'upper_left_x': 0, 'upper_left_y': 9625, 'pol_width': 304, 'pol_height': 245, 'pix_area': 1.1727097928210088e-05})
# ('1_853', {'upper_left_x': 11794, 'upper_left_y': 13953, 'pol_width': 2772, 'pol_height': 510, 'pix_area': 8.280340710940103e-06})
# ('0_76', {'upper_left_x': 3374, 'upper_left_y': 9702, 'pol_width': 462, 'pol_height': 227, 'pix_area': 9.37379198328595e-06})
# ('1_440', {'upper_left_x': 10779, 'upper_left_y': 12741, 'pol_width': 91, 'pol_height': 168, 'pix_area': 2.5919833925554798e-06})
# ('1_760', {'upper_left_x': 3297, 'upper_left_y': 2202, 'pol_width': 640, 'pol_height': 491, 'pix_area': 5.884565218533972e-05})
# ('1_1076', {'upper_left_x': 279, 'upper_left_y': 6536, 'pol_width': 867, 'pol_height': 117, 'pix_area': 1.2268658205176904e-05})
# ('1_568', {'upper_left_x': 17501, 'upper_left_y': 10762, 'pol_width': 296, 'pol_height': 509, 'pix_area': 1.990917592196386e-05})
# ('1_732', {'upper_left_x': 1152, 'upper_left_y': 6286, 'pol_width': 229, 'pol_height': 183, 'pix_area': 5.8365151963293954e-06})
# ('1_866', {'upper_left_x': 11895, 'upper_left_y': 13484, 'pol_width': 148, 'pol_height': 152, 'pix_area': 3.2932210571384434e-06})
# ('1_138', {'upper_left_x': 10171, 'upper_left_y': 5741, 'pol_width': 525, 'pol_height': 476, 'pix_area': 1.8743408736903668e-05})
# ('1_158', {'upper_left_x': 11502, 'upper_left_y': 5550, 'pol_width': 463, 'pol_height': 279, 'pix_area': 3.0967590977796136e-05})
# ('1_1028', {'upper_left_x': 3498, 'upper_left_y': 9315, 'pol_width': 406, 'pol_height': 118, 'pix_area': 9.61652341841448e-06})
# ('1_519', {'upper_left_x': 12373, 'upper_left_y': 11186, 'pol_width': 299, 'pol_height': 160, 'pix_area': 1.0244553193977494e-05})
# ('1_488', {'upper_left_x': 4840, 'upper_left_y': 4687, 'pol_width': 285, 'pol_height': 161, 'pix_area': 6.799817247298226e-06})
# ('0_51', {'upper_left_x': 379, 'upper_left_y': 11352, 'pol_width': 103, 'pol_height': 205, 'pix_area': 3.2950701634228197e-06})
# ('1_565', {'upper_left_x': 16565, 'upper_left_y': 9892, 'pol_width': 236, 'pol_height': 258, 'pix_area': 8.006662091902565e-06})
# ('1_551', {'upper_left_x': 13717, 'upper_left_y': 9433, 'pol_width': 665, 'pol_height': 650, 'pix_area': 1.7506311153973634e-05})
# ('0_61', {'upper_left_x': 319, 'upper_left_y': 10157, 'pol_width': 590, 'pol_height': 93, 'pix_area': 6.250458329059713e-06})
# ('1_293', {'upper_left_x': 18678, 'upper_left_y': 8671, 'pol_width': 335, 'pol_height': 137, 'pix_area': 7.370734429147827e-06})
# ('1_700', {'upper_left_x': 4180, 'upper_left_y': 6387, 'pol_width': 232, 'pol_height': 146, 'pix_area': 5.249697178758575e-06})
# ('1_464', {'upper_left_x': 16757, 'upper_left_y': 12431, 'pol_width': 523, 'pol_height': 177, 'pix_area': 1.8280870393167027e-05})
# ('1_939', {'upper_left_x': 18008, 'upper_left_y': 14093, 'pol_width': 588, 'pol_height': 430, 'pix_area': 3.2562301100183345e-05})
# ('1_713', {'upper_left_x': 2807, 'upper_left_y': 4969, 'pol_width': 363, 'pol_height': 384, 'pix_area': 2.6298953706081862e-05})
# ('1_89', {'upper_left_x': 13359, 'upper_left_y': 7864, 'pol_width': 245, 'pol_height': 216, 'pix_area': 9.246553604667414e-06})
# ('1_1060', {'upper_left_x': 0, 'upper_left_y': 9931, 'pol_width': 90, 'pol_height': 388, 'pix_area': 4.810874145859501e-06})
# ('1_691', {'upper_left_x': 2879, 'upper_left_y': 5951, 'pol_width': 522, 'pol_height': 161, 'pix_area': 1.3781865298521167e-05})
# ('1_364', {'upper_left_x': 10787, 'upper_left_y': 13079, 'pol_width': 287, 'pol_height': 194, 'pix_area': 8.585205613091267e-06})
# ('0_1', {'upper_left_x': 0, 'upper_left_y': 8118, 'pol_width': 123, 'pol_height': 9, 'pix_area': 3.05044472088386e-07})
# ('1_1022', {'upper_left_x': 2881, 'upper_left_y': 9552, 'pol_width': 854, 'pol_height': 373, 'pix_area': 2.2550072674707373e-05})
# ('0_40', {'upper_left_x': 350, 'upper_left_y': 10004, 'pol_width': 578, 'pol_height': 153, 'pix_area': 1.3130528208509356e-05})
# ('1_812', {'upper_left_x': 18712, 'upper_left_y': 11714, 'pol_width': 351, 'pol_height': 120, 'pix_area': 7.475739858535924e-06})
# ('1_359', {'upper_left_x': 10511, 'upper_left_y': 12383, 'pol_width': 268, 'pol_height': 239, 'pix_area': 6.128243169272924e-06})
# ('0_200', {'upper_left_x': 238, 'upper_left_y': 13551, 'pol_width': 208, 'pol_height': 139, 'pix_area': 6.341243699940028e-06})
# ('1_453', {'upper_left_x': 11084, 'upper_left_y': 10732, 'pol_width': 213, 'pol_height': 110, 'pix_area': 2.511093001512087e-06})
# ('1_342', {'upper_left_x': 15497, 'upper_left_y': 10942, 'pol_width': 454, 'pol_height': 247, 'pix_area': 2.2237752017593113e-05})
# ('1_57', {'upper_left_x': 12296, 'upper_left_y': 7108, 'pol_width': 201, 'pol_height': 86, 'pix_area': 3.7829431521047382e-06})
# ('1_478', {'upper_left_x': 16915, 'upper_left_y': 11974, 'pol_width': 350, 'pol_height': 238, 'pix_area': 1.3035822448572257e-05})
# ('0_29', {'upper_left_x': 967, 'upper_left_y': 10232, 'pol_width': 383, 'pol_height': 319, 'pix_area': 1.827581164164259e-05})
# ('1_737', {'upper_left_x': 1526, 'upper_left_y': 4764, 'pol_width': 935, 'pol_height': 759, 'pix_area': 0.0001039502188280921})
# ('1_540', {'upper_left_x': 11968, 'upper_left_y': 9259, 'pol_width': 377, 'pol_height': 286, 'pix_area': 1.030063284533996e-05})
# ('1_32', {'upper_left_x': 12931, 'upper_left_y': 6851, 'pol_width': 311, 'pol_height': 215, 'pix_area': 4.785676823862298e-06})
# ('1_1063', {'upper_left_x': 0, 'upper_left_y': 8034, 'pol_width': 161, 'pol_height': 420, 'pix_area': 6.333258249380568e-06})
# ('0_114', {'upper_left_x': 1915, 'upper_left_y': 10282, 'pol_width': 497, 'pol_height': 302, 'pix_area': 2.2864983045214994e-05})
# ('1_1059', {'upper_left_x': 0, 'upper_left_y': 10268, 'pol_width': 686, 'pol_height': 313, 'pix_area': 3.524970257135731e-05})
# ('1_369', {'upper_left_x': 15586, 'upper_left_y': 11799, 'pol_width': 338, 'pol_height': 200, 'pix_area': 1.2707298894202044e-05})
# ('1_974', {'upper_left_x': 18375, 'upper_left_y': 12538, 'pol_width': 354, 'pol_height': 302, 'pix_area': 3.3248588424460286e-06})
# ('1_148', {'upper_left_x': 10041, 'upper_left_y': 6319, 'pol_width': 378, 'pol_height': 109, 'pix_area': 3.6388894221201965e-06})
# ('1_1094', {'upper_left_x': 16915, 'upper_left_y': 14509, 'pol_width': 934, 'pol_height': 316, 'pix_area': 3.330599329486768e-05})
# ('0_253', {'upper_left_x': 1516, 'upper_left_y': 12134, 'pol_width': 430, 'pol_height': 138, 'pix_area': 6.905031207677698e-06})
# ('1_1070', {'upper_left_x': 1779, 'upper_left_y': 7992, 'pol_width': 139, 'pol_height': 183, 'pix_area': 5.65300894708243e-06})
# ('1_652', {'upper_left_x': 5769, 'upper_left_y': 5776, 'pol_width': 317, 'pol_height': 148, 'pix_area': 5.842389391475295e-06})
# ('1_423', {'upper_left_x': 17835, 'upper_left_y': 10364, 'pol_width': 84, 'pol_height': 137, 'pix_area': 1.499399831844637e-06})
# ('0_225', {'upper_left_x': 1308, 'upper_left_y': 13934, 'pol_width': 136, 'pol_height': 83, 'pix_area': 2.5614076747668073e-06})
# ('0_4', {'upper_left_x': 449, 'upper_left_y': 7093, 'pol_width': 428, 'pol_height': 220, 'pix_area': 1.1587165591625789e-05})
# ('1_1014', {'upper_left_x': 2811, 'upper_left_y': 10114, 'pol_width': 374, 'pol_height': 432, 'pix_area': 2.326137525347227e-05})
# ('1_70', {'upper_left_x': 11798, 'upper_left_y': 6130, 'pol_width': 301, 'pol_height': 259, 'pix_area': 1.3735894208846704e-05})
# ('1_182', {'upper_left_x': 12820, 'upper_left_y': 6303, 'pol_width': 308, 'pol_height': 170, 'pix_area': 5.467612978997137e-06})
# ('1_56', {'upper_left_x': 13619, 'upper_left_y': 6553, 'pol_width': 409, 'pol_height': 113, 'pix_area': 6.641851177976972e-06})
# ('1_263', {'upper_left_x': 15753, 'upper_left_y': 8861, 'pol_width': 599, 'pol_height': 404, 'pix_area': 2.806236349092697e-05})
# ('1_340', {'upper_left_x': 17175, 'upper_left_y': 11226, 'pol_width': 338, 'pol_height': 115, 'pix_area': 6.182577058901917e-06})
# ('1_678', {'upper_left_x': 4868, 'upper_left_y': 6715, 'pol_width': 788, 'pol_height': 300, 'pix_area': 3.074583639878543e-05})
# ('1_712', {'upper_left_x': 2949, 'upper_left_y': 4575, 'pol_width': 1266, 'pol_height': 656, 'pix_area': 0.0001160290313666353})
# ('1_247', {'upper_left_x': 11659, 'upper_left_y': 7978, 'pol_width': 485, 'pol_height': 208, 'pix_area': 1.4583401496154107e-05})
# ('1_884', {'upper_left_x': 12609, 'upper_left_y': 13589, 'pol_width': 361, 'pol_height': 194, 'pix_area': 7.467907450569465e-06})
# ('1_710', {'upper_left_x': 2814, 'upper_left_y': 5679, 'pol_width': 572, 'pol_height': 105, 'pix_area': 1.1976738336582501e-05})
# ('1_1038', {'upper_left_x': 4116, 'upper_left_y': 9251, 'pol_width': 138, 'pol_height': 102, 'pix_area': 3.92056843180103e-06})
# ('1_118', {'upper_left_x': 11568, 'upper_left_y': 7023, 'pol_width': 549, 'pol_height': 171, 'pix_area': 1.0775605086059568e-05})
# ('1_562', {'upper_left_x': 16350, 'upper_left_y': 10443, 'pol_width': 1094, 'pol_height': 1149, 'pix_area': 0.00010324122248335839})
# ('1_76', {'upper_left_x': 10877, 'upper_left_y': 8764, 'pol_width': 101, 'pol_height': 124, 'pix_area': 2.11863836743547e-06})
# ('1_458', {'upper_left_x': 16645, 'upper_left_y': 10695, 'pol_width': 952, 'pol_height': 901, 'pix_area': 6.227095184831249e-05})
# ('1_890', {'upper_left_x': 10336, 'upper_left_y': 13911, 'pol_width': 223, 'pol_height': 149, 'pix_area': 5.940853383900169e-06})
# ('1_622', {'upper_left_x': 15704, 'upper_left_y': 12230, 'pol_width': 1538, 'pol_height': 1515, 'pix_area': 8.030647489417757e-06})
# ('0_164', {'upper_left_x': 1309, 'upper_left_y': 12104, 'pol_width': 259, 'pol_height': 105, 'pix_area': 4.358638447446659e-06})
# ('1_920', {'upper_left_x': 16328, 'upper_left_y': 13741, 'pol_width': 274, 'pol_height': 107, 'pix_area': 3.85002505976439e-06})
# ('0_116', {'upper_left_x': 2482, 'upper_left_y': 11272, 'pol_width': 539, 'pol_height': 227, 'pix_area': 1.8379526376060647e-05})
# ('1_49', {'upper_left_x': 15027, 'upper_left_y': 8633, 'pol_width': 189, 'pol_height': 536, 'pix_area': 1.0447116045078428e-05})
# ('1_1067', {'upper_left_x': 533, 'upper_left_y': 8343, 'pol_width': 723, 'pol_height': 170, 'pix_area': 1.922589874037288e-05})
# ('1_79', {'upper_left_x': 12127, 'upper_left_y': 7249, 'pol_width': 753, 'pol_height': 202, 'pix_area': 1.7371041062868855e-05})
# ('1_750', {'upper_left_x': 2044, 'upper_left_y': 3088, 'pol_width': 986, 'pol_height': 246, 'pix_area': 1.7524105712631516e-05})
# ('1_180', {'upper_left_x': 11883, 'upper_left_y': 5230, 'pol_width': 245, 'pol_height': 63, 'pix_area': 1.5284289367597667e-06})
# ('1_765', {'upper_left_x': 1914, 'upper_left_y': 3334, 'pol_width': 303, 'pol_height': 428, 'pix_area': 1.0123963520739593e-05})
# ('1_575', {'upper_left_x': 18918, 'upper_left_y': 9886, 'pol_width': 283, 'pol_height': 142, 'pix_area': 9.369323494398123e-06})
# ('0_161', {'upper_left_x': 950, 'upper_left_y': 11480, 'pol_width': 393, 'pol_height': 430, 'pix_area': 2.9067189075279672e-05})
# ('1_167', {'upper_left_x': 11428, 'upper_left_y': 5302, 'pol_width': 720, 'pol_height': 323, 'pix_area': 2.7383840910208933e-05})
# ('1_773', {'upper_left_x': 3896, 'upper_left_y': 2348, 'pol_width': 2158, 'pol_height': 484, 'pix_area': 1.1306284472232927e-05})
# ('1_990', {'upper_left_x': 2722, 'upper_left_y': 8637, 'pol_width': 828, 'pol_height': 285, 'pix_area': 3.191515492903755e-05})
# ('1_1086', {'upper_left_x': 0, 'upper_left_y': 8442, 'pol_width': 529, 'pol_height': 170, 'pix_area': 1.5906489267445507e-06})
# ('0_110', {'upper_left_x': 2059, 'upper_left_y': 9884, 'pol_width': 365, 'pol_height': 220, 'pix_area': 1.0498592549992231e-05})
# ('1_645', {'upper_left_x': 5549, 'upper_left_y': 6126, 'pol_width': 327, 'pol_height': 135, 'pix_area': 5.057641927620539e-06})
# ('1_898', {'upper_left_x': 18661, 'upper_left_y': 14171, 'pol_width': 234, 'pol_height': 53, 'pix_area': 2.381247215316693e-06})
# ('0_104', {'upper_left_x': 2479, 'upper_left_y': 9628, 'pol_width': 284, 'pol_height': 142, 'pix_area': 9.369323494398123e-06})
# ('0_250', {'upper_left_x': 1135, 'upper_left_y': 12960, 'pol_width': 378, 'pol_height': 123, 'pix_area': 1.1189660781400035e-05})
# ('1_460', {'upper_left_x': 15850, 'upper_left_y': 11088, 'pol_width': 673, 'pol_height': 473, 'pix_area': 7.276184901061973e-05})
# ('0_232', {'upper_left_x': 1568, 'upper_left_y': 13842, 'pol_width': 589, 'pol_height': 430, 'pix_area': 3.2562301100183345e-05})
# ('1_517', {'upper_left_x': 4974, 'upper_left_y': 6053, 'pol_width': 1019, 'pol_height': 459, 'pix_area': 7.276333220301276e-05})
# ('0_82', {'upper_left_x': 0, 'upper_left_y': 10871, 'pol_width': 81, 'pol_height': 211, 'pix_area': 2.7074690601102124e-06})
# ('1_563', {'upper_left_x': 16123, 'upper_left_y': 9884, 'pol_width': 624, 'pol_height': 372, 'pix_area': 1.815892325648026e-05})
# ('1_994', {'upper_left_x': 537, 'upper_left_y': 8469, 'pol_width': 316, 'pol_height': 224, 'pix_area': 1.0675831187205825e-05})
# ('1_694', {'upper_left_x': 3392, 'upper_left_y': 6343, 'pol_width': 568, 'pol_height': 270, 'pix_area': 1.733826206497751e-05})
# ('1_482', {'upper_left_x': 3105, 'upper_left_y': 5310, 'pol_width': 462, 'pol_height': 138, 'pix_area': 4.121277180766384e-06})
# ('1_356', {'upper_left_x': 12564, 'upper_left_y': 11348, 'pol_width': 253, 'pol_height': 74, 'pix_area': 3.986809658638974e-06})
# ('1_260', {'upper_left_x': 15431, 'upper_left_y': 7839, 'pol_width': 186, 'pol_height': 79, 'pix_area': 2.5013056571552478e-06})
# ('0_103', {'upper_left_x': 2127, 'upper_left_y': 9586, 'pol_width': 368, 'pol_height': 157, 'pix_area': 1.139178550470765e-05})
# ('1_923', {'upper_left_x': 17041, 'upper_left_y': 14312, 'pol_width': 200, 'pol_height': 133, 'pix_area': 5.321421302049583e-06})
# ('0_144', {'upper_left_x': 0, 'upper_left_y': 12223, 'pol_width': 801, 'pol_height': 1270, 'pix_area': 5.598202460404194e-06})
# ('1_874', {'upper_left_x': 10753, 'upper_left_y': 13998, 'pol_width': 401, 'pol_height': 100, 'pix_area': 5.642658494458627e-06})
# ('1_244', {'upper_left_x': 11216, 'upper_left_y': 7405, 'pol_width': 894, 'pol_height': 690, 'pix_area': 8.393999214730451e-05})
# ('0_74', {'upper_left_x': 3421, 'upper_left_y': 10676, 'pol_width': 161, 'pol_height': 151, 'pix_area': 3.044342838532804e-06})
# ('1_328', {'upper_left_x': 12851, 'upper_left_y': 10485, 'pol_width': 453, 'pol_height': 123, 'pix_area': 7.885656281430138e-06})
# ('0_17', {'upper_left_x': 1475, 'upper_left_y': 8401, 'pol_width': 817, 'pol_height': 256, 'pix_area': 3.473344599970632e-05})
# ('1_823', {'upper_left_x': 14444, 'upper_left_y': 13728, 'pol_width': 194, 'pol_height': 232, 'pix_area': 6.569968891574897e-06})
# ('1_1044', {'upper_left_x': 1332, 'upper_left_y': 8248, 'pol_width': 510, 'pol_height': 152, 'pix_area': 8.049466480055318e-06})
# ('1_216', {'upper_left_x': 10014, 'upper_left_y': 7948, 'pol_width': 453, 'pol_height': 166, 'pix_area': 2.551552696823239e-06})
# ('1_956', {'upper_left_x': 17070, 'upper_left_y': 13153, 'pol_width': 571, 'pol_height': 62, 'pix_area': 3.926936925146087e-06})
# ('0_133', {'upper_left_x': 0, 'upper_left_y': 12659, 'pol_width': 656, 'pol_height': 246, 'pix_area': 2.151623238367831e-05})
# ('1_1045', {'upper_left_x': 0, 'upper_left_y': 8536, 'pol_width': 325, 'pol_height': 288, 'pix_area': 2.257067677858525e-05})
# ('1_59', {'upper_left_x': 12307, 'upper_left_y': 6107, 'pol_width': 311, 'pol_height': 365, 'pix_area': 7.735939542482351e-06})
# ('1_446', {'upper_left_x': 12351, 'upper_left_y': 11418, 'pol_width': 676, 'pol_height': 231, 'pix_area': 2.0120635510991556e-05})
# ('1_367', {'upper_left_x': 13274, 'upper_left_y': 11821, 'pol_width': 222, 'pol_height': 122, 'pix_area': 6.5043847271771266e-06})
# ('1_908', {'upper_left_x': 16396, 'upper_left_y': 13827, 'pol_width': 174, 'pol_height': 144, 'pix_area': 2.7599955930147547e-06})
# ('0_152', {'upper_left_x': 381, 'upper_left_y': 13662, 'pol_width': 200, 'pol_height': 183, 'pix_area': 7.743259164744131e-06})
# ('1_436', {'upper_left_x': 19812, 'upper_left_y': 9960, 'pol_width': 461, 'pol_height': 227, 'pix_area': 9.37379198328595e-06})
# ('1_854', {'upper_left_x': 12565, 'upper_left_y': 14188, 'pol_width': 361, 'pol_height': 71, 'pix_area': 2.3497578819175357e-06})
# ('1_82', {'upper_left_x': 12509, 'upper_left_y': 6848, 'pol_width': 392, 'pol_height': 176, 'pix_area': 8.35477190820169e-06})
# ('1_472', {'upper_left_x': 14308, 'upper_left_y': 10634, 'pol_width': 377, 'pol_height': 291, 'pix_area': 1.3399839959740329e-05})
# ('0_208', {'upper_left_x': 0, 'upper_left_y': 13579, 'pol_width': 14, 'pol_height': 12, 'pix_area': 2.3379313888784516e-08})
# ('1_344', {'upper_left_x': 15720, 'upper_left_y': 10165, 'pol_width': 288, 'pol_height': 283, 'pix_area': 1.1860315802545865e-05})
# ('1_220', {'upper_left_x': 10471, 'upper_left_y': 7824, 'pol_width': 563, 'pol_height': 144, 'pix_area': 1.8210903397209504e-05})
# ('0_149', {'upper_left_x': 1940, 'upper_left_y': 13632, 'pol_width': 346, 'pol_height': 137, 'pix_area': 8.528339834300876e-06})
# ('0_139', {'upper_left_x': 74, 'upper_left_y': 12358, 'pol_width': 677, 'pol_height': 445, 'pix_area': 5.843715613984332e-05})
# ('1_740', {'upper_left_x': 0, 'upper_left_y': 4845, 'pol_width': 245, 'pol_height': 261, 'pix_area': 1.2262602093332503e-05})
# ('1_677', {'upper_left_x': 5512, 'upper_left_y': 7076, 'pol_width': 245, 'pol_height': 85, 'pix_area': 4.070566851613008e-06})
# ('1_1034', {'upper_left_x': 3566, 'upper_left_y': 9062, 'pol_width': 632, 'pol_height': 109, 'pix_area': 1.8681108001321753e-05})
# ('1_81', {'upper_left_x': 14803, 'upper_left_y': 9243, 'pol_width': 590, 'pol_height': 256, 'pix_area': 3.236058829963938e-05})
# ('1_406', {'upper_left_x': 16618, 'upper_left_y': 12380, 'pol_width': 684, 'pol_height': 134, 'pix_area': 8.275872461352627e-06})
# ('1_1053', {'upper_left_x': 0, 'upper_left_y': 10566, 'pol_width': 273, 'pol_height': 420, 'pix_area': 1.7111570145209547e-05})
# ('1_610', {'upper_left_x': 16995, 'upper_left_y': 12621, 'pol_width': 234, 'pol_height': 117, 'pix_area': 3.750976408294222e-06})
# ('0_179', {'upper_left_x': 745, 'upper_left_y': 11666, 'pol_width': 2530, 'pol_height': 938, 'pix_area': 8.331442548932713e-06})
# ('1_959', {'upper_left_x': 17465, 'upper_left_y': 12829, 'pol_width': 899, 'pol_height': 566, 'pix_area': 4.218197878208356e-05})
# ('1_787', {'upper_left_x': 12976, 'upper_left_y': 13856, 'pol_width': 325, 'pol_height': 164, 'pix_area': 5.0730426150346806e-06})
# ('0_47', {'upper_left_x': 525, 'upper_left_y': 11363, 'pol_width': 313, 'pol_height': 356, 'pix_area': 1.9011909741494165e-05})
# ('1_767', {'upper_left_x': 1565, 'upper_left_y': 2491, 'pol_width': 190, 'pol_height': 248, 'pix_area': 9.251986169194786e-06})

# %%
item[1]
# Out:
# {'upper_left_x': 1565,
#  'upper_left_y': 2491,
#  'pol_width': 190,
#  'pol_height': 248,
#  'pix_area': 9.251986169194786e-06}

# %%
upper_left_x + pol_width, upper_left_y - pol_height

# %%
from shapely.geometry import box
print(box(upper_left_x, upper_left_y, upper_left_x + pol_width, upper_left_y - pol_height))
# Out:
# POLYGON ((2570 904, 2570 889, 2556 889, 2556 904, 2570 904))

# %%
from shapely.geometry import Polygon, mapping
mapping(sh_polygon)

# %%
from shapely.geometry import Polygon, mapping

extention_list = []
for item in generator.json_file_linden_val.items():
    geom = box(upper_left_x, upper_left_y, upper_left_x + pol_width, upper_left_y - pol_height)
    geom = mapping(geom)['coordinates']
    extention_list.append({'geometry':{'type': 'Polygon', 
                                                'coordinates':geom}})

crs = {
        "type": "name",
        "properties": {
            "name": "EPSG:32639"
        }
    }      
feature_collection = geojson.FeatureCollection(extention_list, crs=crs)
geojson_file = 'validation_linden.geojson'.format(folder, folder)
with open(geojson_file, 'w') as f:
    geojson.dump(feature_collection, f)

# %%
feature_collection
# Out:
# {"crs": {"properties": {"name": "EPSG:32639"}, "type": "name"}, "features": [{"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[[2570.0, 904.0], [2570.0, 889.0], [2556.0, 889.0], [2556.0, 904.0], [2570.0, 904.0]]], "type": "Polygon"}}, {"geometry": {"coordinates": [[ ...

# %%
extention_list = []
for item in generator.json_file_oak_val.items():
    geom = box(upper_left_x, upper_left_y, upper_left_x + pol_width, upper_left_y - pol_height)
    geom = mapping(geom)['coordinates']
    extention_list.append(geom)

crs = {
        "type": "name",
        "properties": {
            "name": "EPSG:32639"
        }
    }      
feature_collection = geojson.FeatureCollection(extention_list, crs=crs)
geojson_file = 'validation_oak.geojson'.format(folder, folder)
with open(geojson_file, 'w') as f:
    geojson.dump(feature_collection, f)

# %% [markdown]
# ## All val predict

# %%
generator.json_file_linden_val
# Out:
# {'bugulminskoe_323': {'upper_left_x': 4601,
#   'upper_left_y': 6356,
#   'pol_width': 10,
#   'pol_height': 12,
#   'pix_area': 92},
#  'kamskoe_998': {'upper_left_x': 1083,
#   'upper_left_y': 4869,
#   'pol_width': 21,
#   'pol_height': 21,
#   'pix_area': 276},
#  'bugulminskoe_276': {'upper_left_x': 4992,
#   'upper_left_y': 6333,
#   'pol_width': 29,
#   'pol_height': 46,
#   'pix_area': 644},
#  'kamskoe_1702': {'upper_left_x': 1901,
#   'upper_left_y': 3913,
#   'pol_width': 23,
#   'pol_height': 7,
#   'pix_area': 89},
#  'menzelinskoe_720': {'upper_left_x': 5840,
#   'upper_left_y': 6185,
#   'pol_width': 37,
#   'pol_height': 34,
#   'pix_area': 242},
#  'bugulminskoe_213': {'upper_left_x': 4961,
#   'upper_left_y': 6272,
#   'pol_width': 23,
#   'pol_height': 34,
#   'pix_area': 433},
#  'agryzskoe_555': {'upper_left_x': 3174,
#   'upper_left_y': 4553,
#   'pol_width': 35,
#   'pol_height': 22,
#   'pix_area': 439},
#  'kaleykinskoe_7': {'upper_left_x': 4420,
#   'upper_left_y': 2837,
#   'pol_width': 29,
#   'pol_height': 23,
#   'pix_area': 386},
#  'kaleykinskoe_304': {'upper_left_x': 4528,
#   'upper_left_y': 1766,
#   'pol_width': 15,
#   'pol_height': 28,
#   'pix_area': 215},
#  'bavlinskoe_26': {'upper_left_x': 644,
#   'upper_left_y': 740,
#   'pol_width': 11,
#   'pol_height': 10,
#   'pix_area': 86},
#  'bavlinskoe_406': {'upper_left_x': 1002,
#   'upper_left_y': 2677,
#   'pol_width': 16,
#   'pol_height': 18,
#   'pix_area': 215},
#  'bavlinskoe_6': {'upper_left_x': 64,
#   'upper_left_y': 225,
#   'pol_width': 19,
#   'pol_height': 8,
#   'pix_area': 120},
#  'menzelinskoe_4309': {'upper_left_x': 2369,
#   'upper_left_y': 2366,
#   'pol_width': 20,
#   'pol_height': 17,
#   'pix_area': 190},
#  'kyzyl-yulduzskoe_3111': {'upper_left_x': 6220,
#   'upper_left_y': 290,
#   'pol_width': 34,
#   'pol_height': 22,
#   'pix_area': 315},
#  'kamskoe_761': {'upper_left_x': 1906,
#   'upper_left_y': 3889,
#   'pol_width': 23,
#   'pol_height': 7,
#   'pix_area': 98},
#  'menzelinskoe_694': {'upper_left_x': 5551,
#   'upper_left_y': 5225,
#   'pol_width': 82,
#   'pol_height': 65,
#   'pix_area': 1585},
#  'kaleykinskoe_18': {'upper_left_x': 4497,
#   'upper_left_y': 2223,
#   'pol_width': 14,
#   'pol_height': 19,
#   'pix_area': 167},
#  'aksubaevskoe_2': {'upper_left_x': 1598,
#   'upper_left_y': 1543,
#   'pol_width': 12,
#   'pol_height': 8,
#   'pix_area': 42},
#  'bolgarskoe_21': {'upper_left_x': 572,
#   'upper_left_y': 2803,
#   'pol_width': 25,
#   'pol_height': 15,
#   'pix_area': 291},
#  'agryzskoe_441': {'upper_left_x': 4690,
#   'upper_left_y': 6160,
#   'pol_width': 19,
#   'pol_height': 105,
#   'pix_area': 953},
#  'bolgarskoe_365': {'upper_left_x': 4672,
#   'upper_left_y': 509,
#   'pol_width': 16,
#   'pol_height': 37,
#   'pix_area': 277},
#  'kamskoe_3405': {'upper_left_x': 4650,
#   'upper_left_y': 4853,
#   'pol_width': 10,
#   'pol_height': 13,
#   'pix_area': 100},
#  'kaleykinskoe_402': {'upper_left_x': 5183,
#   'upper_left_y': 2870,
#   'pol_width': 10,
#   'pol_height': 30,
#   'pix_area': 251},
#  'kamskoe_68': {'upper_left_x': 1885,
#   'upper_left_y': 3349,
#   'pol_width': 10,
#   'pol_height': 7,
#   'pix_area': 42},
#  'menzelinskoe_793': {'upper_left_x': 5926,
#   'upper_left_y': 6296,
#   'pol_width': 16,
#   'pol_height': 14,
#   'pix_area': 147},
#  'menzelinskoe_3869': {'upper_left_x': 5478,
#   'upper_left_y': 7055,
#   'pol_width': 21,
#   'pol_height': 21,
#   'pix_area': 254},
#  'elabuzhskoe_402': {'upper_left_x': 5462,
#   'upper_left_y': 3035,
#   'pol_width': 13,
#   'pol_height': 15,
#   'pix_area': 120},
#  'mamadyshskoe_1339': {'upper_left_x': 250,
#   'upper_left_y': 3357,
#   'pol_width': 8,
#   'pol_height': 27,
#   'pix_area': 192},
#  'bavlinskoe_96': {'upper_left_x': 2843,
#   'upper_left_y': 146,
#   'pol_width': 51,
#   'pol_height': 25,
#   'pix_area': 630},
#  'bugulminskoe_212': {'upper_left_x': 4520,
#   'upper_left_y': 6048,
#   'pol_width': 19,
#   'pol_height': 14,
#   'pix_area': 186},
#  'kamskoe_3319': {'upper_left_x': 1670,
#   'upper_left_y': 2934,
#   'pol_width': 13,
#   'pol_height': 17,
#   'pix_area': 114},
#  'menzelinskoe_895': {'upper_left_x': 6478,
#   'upper_left_y': 7712,
#   'pol_width': 47,
#   'pol_height': 30,
#   'pix_area': 688},
#  'bolgarskoe_19': {'upper_left_x': 715,
#   'upper_left_y': 2300,
#   'pol_width': 10,
#   'pol_height': 19,
#   'pix_area': 120},
#  'bolgarskoe_413': {'upper_left_x': 4547,
#   'upper_left_y': 543,
#   'pol_width': 22,
#   'pol_height': 19,
#   'pix_area': 157},
#  'kamskoe_565': {'upper_left_x': 2852,
#   'upper_left_y': 4544,
#   'pol_width': 35,
#   'pol_height': 40,
#   'pix_area': 475},
#  'menzelinskoe_2': {'upper_left_x': 5066,
#   'upper_left_y': 7560,
#   'pol_width': 25,
#   'pol_height': 39,
#   'pix_area': 602},
#  'mamadyshskoe_181': {'upper_left_x': 2630,
#   'upper_left_y': 2153,
#   'pol_width': 13,
#   'pol_height': 16,
#   'pix_area': 149},
#  'kamskoe_3150': {'upper_left_x': 3126,
#   'upper_left_y': 1680,
#   'pol_width': 47,
#   'pol_height': 37,
#   'pix_area': 472},
#  'mamadyshskoe_0': {'upper_left_x': 1213,
#   'upper_left_y': 3317,
#   'pol_width': 11,
#   'pol_height': 11,
#   'pix_area': 74},
#  'kamskoe_228': {'upper_left_x': 1846,
#   'upper_left_y': 3537,
#   'pol_width': 54,
#   'pol_height': 10,
#   'pix_area': 441},
#  'mamadyshskoe_872': {'upper_left_x': 5156,
#   'upper_left_y': 3101,
#   'pol_width': 2,
#   'pol_height': 36,
#   'pix_area': 52},
#  'bolgarskoe_328': {'upper_left_x': 4560,
#   'upper_left_y': 528,
#   'pol_width': 54,
#   'pol_height': 57,
#   'pix_area': 1592},
#  'aksubaevskoe_499': {'upper_left_x': 1709,
#   'upper_left_y': 3991,
#   'pol_width': 13,
#   'pol_height': 5,
#   'pix_area': 34},
#  'bavlinskoe_197': {'upper_left_x': 2508,
#   'upper_left_y': 683,
#   'pol_width': 16,
#   'pol_height': 12,
#   'pix_area': 69},
#  'kyzyl-yulduzskoe_2028': {'upper_left_x': 4865,
#   'upper_left_y': 4929,
#   'pol_width': 10,
#   'pol_height': 39,
#   'pix_area': 219},
#  'menzelinskoe_599': {'upper_left_x': 3691,
#   'upper_left_y': 3477,
#   'pol_width': 4,
#   'pol_height': 13,
#   'pix_area': 17},
#  'bugulminskoe_250': {'upper_left_x': 4637,
#   'upper_left_y': 6181,
#   'pol_width': 31,
#   'pol_height': 18,
#   'pix_area': 384},
#  'menzelinskoe_722': {'upper_left_x': 5745,
#   'upper_left_y': 6434,
#   'pol_width': 15,
#   'pol_height': 13,
#   'pix_area': 127},
#  'mamadyshskoe_34': {'upper_left_x': 2332,
#   'upper_left_y': 4501,
#   'pol_width': 8,
#   'pol_height': 16,
#   'pix_area': 96},
#  'kyzyl-yulduzskoe_3099': {'upper_left_x': 6163,
#   'upper_left_y': 260,
#   'pol_width': 12,
#   'pol_height': 31,
#   'pix_area': 162},
#  'mamadyshskoe_4': {'upper_left_x': 2359,
#   'upper_left_y': 4282,
#   'pol_width': 37,
#   'pol_height': 42,
#   'pix_area': 929},
#  'menzelinskoe_2076': {'upper_left_x': 5259,
#   'upper_left_y': 7539,
#   'pol_width': 9,
#   'pol_height': 18,
#   'pix_area': 98},
#  'bugulminskoe_278': {'upper_left_x': 4745,
#   'upper_left_y': 6228,
#   'pol_width': 37,
#   'pol_height': 56,
#   'pix_area': 1277},
#  'bugulminskoe_161': {'upper_left_x': 4854,
#   'upper_left_y': 5270,
#   'pol_width': 15,
#   'pol_height': 5,
#   'pix_area': 26},
#  'menzelinskoe_860': {'upper_left_x': 5314,
#   'upper_left_y': 5047,
#   'pol_width': 15,
#   'pol_height': 10,
#   'pix_area': 102},
#  'menzelinskoe_4204': {'upper_left_x': 3209,
#   'upper_left_y': 5867,
#   'pol_width': 14,
#   'pol_height': 26,
#   'pix_area': 292},
#  'aksubaevskoe_572': {'upper_left_x': 2627,
#   'upper_left_y': 2650,
#   'pol_width': 136,
#   'pol_height': 90,
#   'pix_area': 1287},
#  'menzelinskoe_4116': {'upper_left_x': 3838,
#   'upper_left_y': 6296,
#   'pol_width': 12,
#   'pol_height': 23,
#   'pix_area': 152},
#  'aksubaevskoe_75': {'upper_left_x': 1581,
#   'upper_left_y': 1533,
#   'pol_width': 5,
#   'pol_height': 4,
#   'pix_area': 9},
#  'kaleykinskoe_492': {'upper_left_x': 4639,
#   'upper_left_y': 2986,
#   'pol_width': 8,
#   'pol_height': 9,
#   'pix_area': 54},
#  'menzelinskoe_4287': {'upper_left_x': 2469,
#   'upper_left_y': 2227,
#   'pol_width': 17,
#   'pol_height': 14,
#   'pix_area': 192},
#  'kyzyl-yulduzskoe_1591': {'upper_left_x': 4889,
#   'upper_left_y': 4836,
#   'pol_width': 7,
#   'pol_height': 11,
#   'pix_area': 74},
#  'agryzskoe_346': {'upper_left_x': 1548,
#   'upper_left_y': 3223,
#   'pol_width': 30,
#   'pol_height': 64,
#   'pix_area': 597},
#  'kyzyl-yulduzskoe_3046': {'upper_left_x': 5100,
#   'upper_left_y': 5114,
#   'pol_width': 16,
#   'pol_height': 25,
#   'pix_area': 61},
#  'aksubaevskoe_605': {'upper_left_x': 1876,
#   'upper_left_y': 1206,
#   'pol_width': 7,
#   'pol_height': 79,
#   'pix_area': 108},
#  'kamskoe_2488': {'upper_left_x': 1812,
#   'upper_left_y': 3502,
#   'pol_width': 22,
#   'pol_height': 15,
#   'pix_area': 245},
#  'menzelinskoe_4193': {'upper_left_x': 4716,
#   'upper_left_y': 6316,
#   'pol_width': 71,
#   'pol_height': 87,
#   'pix_area': 4701},
#  'mamadyshskoe_42': {'upper_left_x': 1782,
#   'upper_left_y': 2950,
#   'pol_width': 6,
#   'pol_height': 6,
#   'pix_area': 30},
#  'aksubaevskoe_304': {'upper_left_x': 1530,
#   'upper_left_y': 1564,
#   'pol_width': 23,
#   'pol_height': 6,
#   'pix_area': 63},
#  'kamskoe_2387': {'upper_left_x': 2413,
#   'upper_left_y': 5370,
#   'pol_width': 12,
#   'pol_height': 13,
#   'pix_area': 114},
#  'bavlinskoe_207': {'upper_left_x': 2671,
#   'upper_left_y': 1051,
#   'pol_width': 31,
#   'pol_height': 18,
#   'pix_area': 384},
#  'bugulminskoe_268': {'upper_left_x': 4685,
#   'upper_left_y': 6130,
#   'pol_width': 12,
#   'pol_height': 26,
#   'pix_area': 211},
#  'menzelinskoe_1917': {'upper_left_x': 5134,
#   'upper_left_y': 7454,
#   'pol_width': 74,
#   'pol_height': 122,
#   'pix_area': 4697},
#  'elabuzhskoe_415': {'upper_left_x': 1667,
#   'upper_left_y': 3890,
#   'pol_width': 43,
#   'pol_height': 43,
#   'pix_area': 1005},
#  'menzelinskoe_620': {'upper_left_x': 3996,
#   'upper_left_y': 2940,
#   'pol_width': 19,
#   'pol_height': 8,
#   'pix_area': 105},
#  'kyzyl-yulduzskoe_795': {'upper_left_x': 5201,
#   'upper_left_y': 5446,
#   'pol_width': 17,
#   'pol_height': 15,
#   'pix_area': 135},
#  'bugulminskoe_202': {'upper_left_x': 4702,
#   'upper_left_y': 6211,
#   'pol_width': 29,
#   'pol_height': 23,
#   'pix_area': 473},
#  'elabuzhskoe_617': {'upper_left_x': 5358,
#   'upper_left_y': 3121,
#   'pol_width': 17,
#   'pol_height': 6,
#   'pix_area': 68},
#  'menzelinskoe_2805': {'upper_left_x': 5465,
#   'upper_left_y': 6655,
#   'pol_width': 11,
#   'pol_height': 13,
#   'pix_area': 93},
#  'menzelinskoe_703': {'upper_left_x': 5733,
#   'upper_left_y': 6199,
#   'pol_width': 40,
#   'pol_height': 63,
#   'pix_area': 1121},
#  'kyzyl-yulduzskoe_825': {'upper_left_x': 4994,
#   'upper_left_y': 4859,
#   'pol_width': 72,
#   'pol_height': 48,
#   'pix_area': 1190},
#  'menzelinskoe_3269': {'upper_left_x': 5070,
#   'upper_left_y': 6061,
#   'pol_width': 11,
#   'pol_height': 15,
#   'pix_area': 99},
#  'bugulminskoe_285': {'upper_left_x': 4746,
#   'upper_left_y': 6181,
#   'pol_width': 19,
#   'pol_height': 13,
#   'pix_area': 174},
#  'menzelinskoe_790': {'upper_left_x': 5717,
#   'upper_left_y': 6158,
#   'pol_width': 33,
#   'pol_height': 28,
#   'pix_area': 441},
#  'aksubaevskoe_507': {'upper_left_x': 2293,
#   'upper_left_y': 3195,
#   'pol_width': 22,
#   'pol_height': 15,
#   'pix_area': 191},
#  'kaleykinskoe_833': {'upper_left_x': 4847,
#   'upper_left_y': 2854,
#   'pol_width': 6,
#   'pol_height': 8,
#   'pix_area': 41},
#  'menzelinskoe_4269': {'upper_left_x': 3512,
#   'upper_left_y': 5986,
#   'pol_width': 15,
#   'pol_height': 12,
#   'pix_area': 142},
#  'menzelinskoe_829': {'upper_left_x': 5429,
#   'upper_left_y': 5136,
#   'pol_width': 98,
#   'pol_height': 103,
#   'pix_area': 4455},
#  'menzelinskoe_2412': {'upper_left_x': 4894,
#   'upper_left_y': 6363,
#   'pol_width': 11,
#   'pol_height': 16,
#   'pix_area': 109},
#  'kamskoe_15': {'upper_left_x': 5624,
#   'upper_left_y': 1119,
#   'pol_width': 9,
#   'pol_height': 8,
#   'pix_area': 27},
#  'kamskoe_21': {'upper_left_x': 5791,
#   'upper_left_y': 1383,
#   'pol_width': 10,
#   'pol_height': 15,
#   'pix_area': 110},
#  'kaleykinskoe_410': {'upper_left_x': 4465,
#   'upper_left_y': 1591,
#   'pol_width': 36,
#   'pol_height': 22,
#   'pix_area': 389},
#  'mamadyshskoe_613': {'upper_left_x': 3516,
#   'upper_left_y': 910,
#   'pol_width': 9,
#   'pol_height': 10,
#   'pix_area': 65},
#  'menzelinskoe_1905': {'upper_left_x': 5328,
#   'upper_left_y': 7139,
#   'pol_width': 155,
#   'pol_height': 81,
#   'pix_area': 3072},
#  'elabuzhskoe_86': {'upper_left_x': 5532,
#   'upper_left_y': 3270,
#   'pol_width': 24,
#   'pol_height': 47,
#   'pix_area': 537},
#  'menzelinskoe_2984': {'upper_left_x': 3733,
#   'upper_left_y': 2996,
#   'pol_width': 6,
#   'pol_height': 15,
#   'pix_area': 45},
#  'bavlinskoe_232': {'upper_left_x': 2575,
#   'upper_left_y': 725,
#   'pol_width': 28,
#   'pol_height': 16,
#   'pix_area': 209},
#  'mamadyshskoe_1012': {'upper_left_x': 889,
#   'upper_left_y': 5763,
#   'pol_width': 24,
#   'pol_height': 58,
#   'pix_area': 755},
#  'menzelinskoe_68': {'upper_left_x': 5040,
#   'upper_left_y': 6827,
#   'pol_width': 6,
#   'pol_height': 7,
#   'pix_area': 38},
#  'bugulminskoe_215': {'upper_left_x': 5012,
#   'upper_left_y': 6369,
#   'pol_width': 23,
#   'pol_height': 18,
#   'pix_area': 197},
#  'kaleykinskoe_431': {'upper_left_x': 4580,
#   'upper_left_y': 2647,
#   'pol_width': 9,
#   'pol_height': 7,
#   'pix_area': 36},
#  'menzelinskoe_1236': {'upper_left_x': 5291,
#   'upper_left_y': 7317,
#   'pol_width': 12,
#   'pol_height': 16,
#   'pix_area': 108},
#  'kaleykinskoe_856': {'upper_left_x': 4448,
#   'upper_left_y': 2846,
#   'pol_width': 21,
#   'pol_height': 74,
#   'pix_area': 939},
#  'mamadyshskoe_145': {'upper_left_x': 1650,
#   'upper_left_y': 2930,
#   'pol_width': 26,
#   'pol_height': 60,
#   'pix_area': 86},
#  'kaleykinskoe_176': {'upper_left_x': 4748,
#   'upper_left_y': 2029,
#   'pol_width': 10,
#   'pol_height': 28,
#   'pix_area': 121},
#  'agryzskoe_525': {'upper_left_x': 3266,
#   'upper_left_y': 5510,
#   'pol_width': 6,
#   'pol_height': 5,
#   'pix_area': 19},
#  'menzelinskoe_4128': {'upper_left_x': 4455,
#   'upper_left_y': 6291,
#   'pol_width': 15,
#   'pol_height': 7,
#   'pix_area': 53},
#  'kyzyl-yulduzskoe_3720': {'upper_left_x': 1860,
#   'upper_left_y': 3273,
#   'pol_width': 15,
#   'pol_height': 4,
#   'pix_area': 37},
#  'bavlinskoe_105': {'upper_left_x': 2958,
#   'upper_left_y': 186,
#   'pol_width': 8,
#   'pol_height': 9,
#   'pix_area': 46},
#  'kamskoe_2414': {'upper_left_x': 4173,
#   'upper_left_y': 2268,
#   'pol_width': 18,
#   'pol_height': 23,
#   'pix_area': 293},
#  'kyzyl-yulduzskoe_1917': {'upper_left_x': 5313,
#   'upper_left_y': 4950,
#   'pol_width': 18,
#   'pol_height': 11,
#   'pix_area': 121},
#  'bolgarskoe_264': {'upper_left_x': 3204,
#   'upper_left_y': 2859,
#   'pol_width': 24,
#   'pol_height': 14,
#   'pix_area': 138},
#  'kamskoe_2613': {'upper_left_x': 1904,
#   'upper_left_y': 3528,
#   'pol_width': 26,
#   'pol_height': 39,
#   'pix_area': 447},
#  'mamadyshskoe_825': {'upper_left_x': 3123,
#   'upper_left_y': 872,
#   'pol_width': 15,
#   'pol_height': 4,
#   'pix_area': 36},
#  'kyzyl-yulduzskoe_2480': {'upper_left_x': 5094,
#   'upper_left_y': 4350,
#   'pol_width': 53,
#   'pol_height': 46,
#   'pix_area': 1731},
#  'bavlinskoe_178': {'upper_left_x': 2646,
#   'upper_left_y': 1076,
#   'pol_width': 13,
#   'pol_height': 9,
#   'pix_area': 64},
#  'kamskoe_1255': {'upper_left_x': 4295,
#   'upper_left_y': 4148,
#   'pol_width': 16,
#   'pol_height': 22,
#   'pix_area': 199},
#  'menzelinskoe_764': {'upper_left_x': 5870,
#   'upper_left_y': 6321,
#   'pol_width': 55,
#   'pol_height': 70,
#   'pix_area': 1345},
#  'bugulminskoe_67': {'upper_left_x': 2155,
#   'upper_left_y': 6121,
#   'pol_width': 18,
#   'pol_height': 27,
#   'pix_area': 182},
#  'bugulminskoe_308': {'upper_left_x': 4522,
#   'upper_left_y': 6031,
#   'pol_width': 14,
#   'pol_height': 16,
#   'pix_area': 98},
#  'menzelinskoe_4250': {'upper_left_x': 3618,
#   'upper_left_y': 6091,
#   'pol_width': 11,
#   'pol_height': 14,
#   'pix_area': 75},
#  'bugulminskoe_307': {'upper_left_x': 4568,
#   'upper_left_y': 6198,
#   'pol_width': 34,
#   'pol_height': 18,
#   'pix_area': 360},
#  'bavlinskoe_270': {'upper_left_x': 2908,
#   'upper_left_y': 1179,
#   'pol_width': 14,
#   'pol_height': 32,
#   'pix_area': 217},
#  'elabuzhskoe_234': {'upper_left_x': 6894,
#   'upper_left_y': 5126,
#   'pol_width': 44,
#   'pol_height': 69,
#   'pix_area': 1587},
#  'menzelinskoe_4262': {'upper_left_x': 4663,
#   'upper_left_y': 6100,
#   'pol_width': 9,
#   'pol_height': 5,
#   'pix_area': 28},
#  'menzelinskoe_4154': {'upper_left_x': 4578,
#   'upper_left_y': 6066,
#   'pol_width': 45,
#   'pol_height': 29,
#   'pix_area': 817},
#  'aksubaevskoe_573': {'upper_left_x': 2947,
#   'upper_left_y': 2906,
#   'pol_width': 28,
#   'pol_height': 38,
#   'pix_area': 301},
#  'kaleykinskoe_910': {'upper_left_x': 4141,
#   'upper_left_y': 1746,
#   'pol_width': 29,
#   'pol_height': 61,
#   'pix_area': 950},
#  'aksubaevskoe_498': {'upper_left_x': 2080,
#   'upper_left_y': 4105,
#   'pol_width': 10,
#   'pol_height': 10,
#   'pix_area': 69},
#  'menzelinskoe_809': {'upper_left_x': 7063,
#   'upper_left_y': 6517,
#   'pol_width': 20,
#   'pol_height': 8,
#   'pix_area': 87},
#  'bolgarskoe_58': {'upper_left_x': 223,
#   'upper_left_y': 3344,
#   'pol_width': 36,
#   'pol_height': 121,
#   'pix_area': 1579},
#  'menzelinskoe_757': {'upper_left_x': 5560,
#   'upper_left_y': 6315,
#   'pol_width': 63,
#   'pol_height': 87,
#   'pix_area': 2562},
#  'mamadyshskoe_20': {'upper_left_x': 2416,
#   'upper_left_y': 4280,
#   'pol_width': 20,
#   'pol_height': 19,
#   'pix_area': 195},
#  'agryzskoe_30': {'upper_left_x': 1540,
#   'upper_left_y': 3268,
#   'pol_width': 18,
#   'pol_height': 27,
#   'pix_area': 330},
#  'menzelinskoe_4272': {'upper_left_x': 598,
#   'upper_left_y': 1743,
#   'pol_width': 10,
#   'pol_height': 11,
#   'pix_area': 32},
#  'bolgarskoe_29': {'upper_left_x': 728,
#   'upper_left_y': 2699,
#   'pol_width': 23,
#   'pol_height': 36,
#   'pix_area': 401},
#  'kyzyl-yulduzskoe_1677': {'upper_left_x': 4778,
#   'upper_left_y': 4997,
#   'pol_width': 14,
#   'pol_height': 20,
#   'pix_area': 164},
#  'menzelinskoe_851': {'upper_left_x': 5532,
#   'upper_left_y': 6217,
#   'pol_width': 13,
#   'pol_height': 12,
#   'pix_area': 84},
#  'mamadyshskoe_289': {'upper_left_x': 321,
#   'upper_left_y': 6334,
#   'pol_width': 8,
#   'pol_height': 7,
#   'pix_area': 40},
#  'kyzyl-yulduzskoe_1513': {'upper_left_x': 1860,
#   'upper_left_y': 3274,
#   'pol_width': 53,
#   'pol_height': 13,
#   'pix_area': 430},
#  'kamskoe_816': {'upper_left_x': 3001,
#   'upper_left_y': 3189,
#   'pol_width': 35,
#   'pol_height': 29,
#   'pix_area': 319},
#  'agryzskoe_217': {'upper_left_x': 719,
#   'upper_left_y': 6497,
#   'pol_width': 32,
#   'pol_height': 36,
#   'pix_area': 610},
#  'bugulminskoe_321': {'upper_left_x': 4516,
#   'upper_left_y': 5890,
#   'pol_width': 9,
#   'pol_height': 12,
#   'pix_area': 67},
#  'kamskoe_28': {'upper_left_x': 5729,
#   'upper_left_y': 1093,
#   'pol_width': 11,
#   'pol_height': 18,
#   'pix_area': 109},
#  'aksubaevskoe_484': {'upper_left_x': 1917,
#   'upper_left_y': 3493,
#   'pol_width': 20,
#   'pol_height': 39,
#   'pix_area': 465},
#  'mamadyshskoe_1135': {'upper_left_x': 1779,
#   'upper_left_y': 2963,
#   'pol_width': 7,
#   'pol_height': 12,
#   'pix_area': 65},
#  'agryzskoe_553': {'upper_left_x': 3375,
#   'upper_left_y': 5391,
#   'pol_width': 19,
#   'pol_height': 17,
#   'pix_area': 159},
#  'menzelinskoe_2102': {'upper_left_x': 7470,
#   'upper_left_y': 3411,
#   'pol_width': 10,
#   'pol_height': 9,
#   'pix_area': 44},
#  'menzelinskoe_811': {'upper_left_x': 5942,
#   'upper_left_y': 6358,
#   'pol_width': 13,
#   'pol_height': 16,
#   'pix_area': 95},
#  'bugulminskoe_416': {'upper_left_x': 2163,
#   'upper_left_y': 6047,
#   'pol_width': 20,
#   'pol_height': 27,
#   'pix_area': 335},
#  'menzelinskoe_4442': {'upper_left_x': 4702,
#   'upper_left_y': 8418,
#   'pol_width': 19,
#   'pol_height': 11,
#   'pix_area': 147},
#  'kyzyl-yulduzskoe_528': {'upper_left_x': 4400,
#   'upper_left_y': 6478,
#   'pol_width': 21,
#   'pol_height': 21,
#   'pix_area': 276},
#  'menzelinskoe_99': {'upper_left_x': 5126,
#   'upper_left_y': 6582,
#   'pol_width': 22,
#   'pol_height': 30,
#   'pix_area': 278},
#  'kyzyl-yulduzskoe_3109': {'upper_left_x': 6553,
#   'upper_left_y': 383,
#   'pol_width': 8,
#   'pol_height': 8,
#   'pix_area': 36},
#  'kaleykinskoe_346': {'upper_left_x': 4276,
#   'upper_left_y': 2853,
#   'pol_width': 25,
#   'pol_height': 53,
#   'pix_area': 486},
#  'bolgarskoe_219': {'upper_left_x': 4879,
#   'upper_left_y': 3007,
#   'pol_width': 29,
#   'pol_height': 63,
#   'pix_area': 858},
#  'menzelinskoe_3743': {'upper_left_x': 3148,
#   'upper_left_y': 3019,
#   'pol_width': 8,
#   'pol_height': 26,
#   'pix_area': 161},
#  'elabuzhskoe_411': {'upper_left_x': 1567,
#   'upper_left_y': 2965,
#   'pol_width': 18,
#   'pol_height': 33,
#   'pix_area': 46},
#  'bolgarskoe_107': {'upper_left_x': 154,
#   'upper_left_y': 2989,
#   'pol_width': 19,
#   'pol_height': 17,
#   'pix_area': 308},
#  'menzelinskoe_766': {'upper_left_x': 5782,
#   'upper_left_y': 5920,
#   'pol_width': 15,
#   'pol_height': 14,
#   'pix_area': 110},
#  'bavlinskoe_175': {'upper_left_x': 2536,
#   'upper_left_y': 947,
#   'pol_width': 45,
#   'pol_height': 30,
#   'pix_area': 883},
#  'agryzskoe_402': {'upper_left_x': 1056,
#   'upper_left_y': 3919,
#   'pol_width': 24,
#   'pol_height': 53,
#   'pix_area': 564},
#  'kyzyl-yulduzskoe_3097': {'upper_left_x': 6934,
#   'upper_left_y': 1746,
#   'pol_width': 21,
#   'pol_height': 13,
#   'pix_area': 190},
#  'bolgarskoe_389': {'upper_left_x': 4897,
#   'upper_left_y': 2947,
#   'pol_width': 9,
#   'pol_height': 7,
#   'pix_area': 44},
#  'menzelinskoe_740': {'upper_left_x': 5573,
#   'upper_left_y': 5188,
#   'pol_width': 10,
#   'pol_height': 10,
#   'pix_area': 63},
#  'bavlinskoe_155': {'upper_left_x': 2706,
#   'upper_left_y': 1064,
#   'pol_width': 10,
#   'pol_height': 4,
#   'pix_area': 24},
#  'kamskoe_723': {'upper_left_x': 1731,
#   'upper_left_y': 3228,
#   'pol_width': 22,
#   'pol_height': 13,
#   'pix_area': 201},
#  'menzelinskoe_3240': {'upper_left_x': 5435,
#   'upper_left_y': 7168,
#   'pol_width': 53,
#   'pol_height': 34,
#   'pix_area': 515},
#  'menzelinskoe_2754': {'upper_left_x': 3427,
#   'upper_left_y': 3784,
#   'pol_width': 9,
#   'pol_height': 18,
#   'pix_area': 86},
#  'bugulminskoe_247': {'upper_left_x': 4955,
#   'upper_left_y': 6361,
#   'pol_width': 47,
#   'pol_height': 28,
#   'pix_area': 673},
#  'kyzyl-yulduzskoe_1086': {'upper_left_x': 5159,
#   'upper_left_y': 5174,
#   'pol_width': 33,
#   'pol_height': 9,
#   'pix_area': 202},
#  'menzelinskoe_4254': {'upper_left_x': 3689,
#   'upper_left_y': 5991,
#   'pol_width': 11,
#   'pol_height': 8,
#   'pix_area': 68},
#  'bavlinskoe_18': {'upper_left_x': 78,
#   'upper_left_y': 244,
#   'pol_width': 59,
#   'pol_height': 29,
#   'pix_area': 778},
#  'bavlinskoe_403': {'upper_left_x': 1037,
#   'upper_left_y': 2668,
#   'pol_width': 8,
#   'pol_height': 11,
#   'pix_area': 61},
#  'aksubaevskoe_508': {'upper_left_x': 1947,
#   'upper_left_y': 4340,
#   'pol_width': 6,
#   'pol_height': 4,
#   'pix_area': 21},
#  'menzelinskoe_2937': {'upper_left_x': 5566,
#   'upper_left_y': 6876,
#   'pol_width': 30,
#   'pol_height': 37,
#   'pix_area': 623},
#  'aksubaevskoe_477': {'upper_left_x': 1725,
#   'upper_left_y': 3929,
#   'pol_width': 10,
#   'pol_height': 8,
#   'pix_area': 68},
#  'kaleykinskoe_332': {'upper_left_x': 5022,
#   'upper_left_y': 2742,
#   'pol_width': 17,
#   'pol_height': 14,
#   'pix_area': 155},
#  'bugulminskoe_318': {'upper_left_x': 4598,
#   'upper_left_y': 6122,
#   'pol_width': 19,
#   'pol_height': 20,
#   'pix_area': 238},
#  'bugulminskoe_328': {'upper_left_x': 4668,
#   'upper_left_y': 6280,
#   'pol_width': 18,
#   'pol_height': 19,
#   'pix_area': 202},
#  'menzelinskoe_1409': {'upper_left_x': 3732,
#   'upper_left_y': 3598,
#   'pol_width': 8,
#   'pol_height': 6,
#   'pix_area': 48},
#  'menzelinskoe_4220': {'upper_left_x': 3830,
#   'upper_left_y': 6365,
#   'pol_width': 22,
#   'pol_height': 16,
#   'pix_area': 301},
#  'menzelinskoe_750': {'upper_left_x': 5169,
#   'upper_left_y': 4680,
#   'pol_width': 80,
#   'pol_height': 61,
#   'pix_area': 462},
#  'kamskoe_25': {'upper_left_x': 5436,
#   'upper_left_y': 1052,
#   'pol_width': 49,
#   'pol_height': 57,
#   'pix_area': 918},
#  'bavlinskoe_160': {'upper_left_x': 2769,
#   'upper_left_y': 1138,
#   'pol_width': 15,
#   'pol_height': 60,
#   'pix_area': 424},
#  'kamskoe_3204': {'upper_left_x': 3617,
#   'upper_left_y': 137,
#   'pol_width': 21,
#   'pol_height': 13,
#   'pix_area': 190},
#  'kaleykinskoe_399': {'upper_left_x': 5186,
#   'upper_left_y': 2893,
#   'pol_width': 12,
#   'pol_height': 23,
#   'pix_area': 179},
#  'menzelinskoe_4139': {'upper_left_x': 3282,
#   'upper_left_y': 5949,
#   'pol_width': 15,
#   'pol_height': 11,
#   'pix_area': 136},
#  'menzelinskoe_4216': {'upper_left_x': 3210,
#   'upper_left_y': 5946,
#   'pol_width': 25,
#   'pol_height': 30,
#   'pix_area': 340},
#  'menzelinskoe_822': {'upper_left_x': 5375,
#   'upper_left_y': 5152,
#   'pol_width': 93,
#   'pol_height': 66,
#   'pix_area': 2928},
#  'bolgarskoe_67': {'upper_left_x': 1981,
#   'upper_left_y': 2313,
#   'pol_width': 11,
#   'pol_height': 7,
#   'pix_area': 60},
#  'menzelinskoe_688': {'upper_left_x': 6034,
#   'upper_left_y': 6288,
#   'pol_width': 59,
#   'pol_height': 37,
#   'pix_area': 1384},
#  'menzelinskoe_782': {'upper_left_x': 5753,
#   'upper_left_y': 5785,
#   'pol_width': 8,
#   'pol_height': 8,
#   'pix_area': 42},
#  'kaleykinskoe_385': {'upper_left_x': 4506,
#   'upper_left_y': 2769,
#   'pol_width': 7,
#   'pol_height': 3,
#   'pix_area': 15},
#  'kyzyl-yulduzskoe_1976': {'upper_left_x': 5299,
#   'upper_left_y': 5169,
#   'pol_width': 13,
#   'pol_height': 11,
#   'pix_area': 100},
#  'bolgarskoe_56': {'upper_left_x': 235,
#   'upper_left_y': 3344,
#   'pol_width': 18,
#   'pol_height': 61,
#   'pix_area': 422},
#  'menzelinskoe_4310': {'upper_left_x': 3126,
#   'upper_left_y': 1866,
#   'pol_width': 11,
#   'pol_height': 19,
#   'pix_area': 61},
#  'menzelinskoe_4223': {'upper_left_x': 3564,
#   'upper_left_y': 5980,
#   'pol_width': 60,
#   'pol_height': 43,
#   'pix_area': 1085},
#  'aksubaevskoe_485': {'upper_left_x': 2284,
#   'upper_left_y': 3093,
#   'pol_width': 31,
#   'pol_height': 21,
#   'pix_area': 297},
#  'kaleykinskoe_694': {'upper_left_x': 5270,
#   'upper_left_y': 2601,
#   'pol_width': 5,
#   'pol_height': 7,
#   'pix_area': 24},
#  'bavlinskoe_284': {'upper_left_x': 2691,
#   'upper_left_y': 1152,
#   'pol_width': 13,
#   'pol_height': 14,
#   'pix_area': 104},
#  'bavlinskoe_170': {'upper_left_x': 2995,
#   'upper_left_y': 1141,
#   'pol_width': 23,
#   'pol_height': 34,
#   'pix_area': 433},
#  'menzelinskoe_3043': {'upper_left_x': 2861,
#   'upper_left_y': 4125,
#   'pol_width': 24,
#   'pol_height': 26,
#   'pix_area': 310},
#  'menzelinskoe_3331': {'upper_left_x': 5380,
#   'upper_left_y': 7147,
#   'pol_width': 32,
#   'pol_height': 22,
#   'pix_area': 174},
#  'kamskoe_1304': {'upper_left_x': 1921,
#   'upper_left_y': 3729,
#   'pol_width': 9,
#   'pol_height': 9,
#   'pix_area': 66},
#  'kamskoe_3759': {'upper_left_x': 1440,
#   'upper_left_y': 3133,
#   'pol_width': 32,
#   'pol_height': 25,
#   'pix_area': 418},
#  'menzelinskoe_810': {'upper_left_x': 5315,
#   'upper_left_y': 4813,
#   'pol_width': 52,
#   'pol_height': 21,
#   'pix_area': 678},
#  'mamadyshskoe_369': {'upper_left_x': 2638,
#   'upper_left_y': 2196,
#   'pol_width': 13,
#   'pol_height': 14,
#   'pix_area': 113},
#  'kaleykinskoe_461': {'upper_left_x': 4204,
#   'upper_left_y': 2949,
#   'pol_width': 5,
#   'pol_height': 3,
#   'pix_area': 15},
#  'bavlinskoe_228': {'upper_left_x': 2630,
#   'upper_left_y': 889,
#   'pol_width': 12,
#   'pol_height': 16,
#   'pix_area': 124},
#  'menzelinskoe_743': {'upper_left_x': 5809,
#   'upper_left_y': 5918,
#   'pol_width': 16,
#   'pol_height': 16,
#   'pix_area': 133},
#  'kyzyl-yulduzskoe_2798': {'upper_left_x': 4744,
#   'upper_left_y': 4811,
#   'pol_width': 30,
#   'pol_height': 10,
#   'pix_area': 145},
#  'kyzyl-yulduzskoe_2302': {'upper_left_x': 4336,
#   'upper_left_y': 6476,
#   'pol_width': 25,
#   'pol_height': 23,
#   'pix_area': 436},
#  'menzelinskoe_4176': {'upper_left_x': 3864,
#   'upper_left_y': 6417,
#   'pol_width': 55,
#   'pol_height': 50,
#   'pix_area': 1186},
#  'elabuzhskoe_665': {'upper_left_x': 8263,
#   'upper_left_y': 272,
#   'pol_width': 53,
#   'pol_height': 60,
#   'pix_area': 1106},
#  'bolgarskoe_6': {'upper_left_x': 2287,
#   'upper_left_y': 1992,
#   'pol_width': 34,
#   'pol_height': 32,
#   'pix_area': 463},
#  'bavlinskoe_347': {'upper_left_x': 2952,
#   'upper_left_y': 213,
#   'pol_width': 4,
#   'pol_height': 10,
#   'pix_area': 31},
#  'kamskoe_1963': {'upper_left_x': 1843,
#   'upper_left_y': 3557,
#   'pol_width': 56,
#   'pol_height': 14,
#   'pix_area': 479},
#  'menzelinskoe_3951': {'upper_left_x': 5748,
#   'upper_left_y': 6779,
#   'pol_width': 25,
#   'pol_height': 34,
#   'pix_area': 285},
#  'kamskoe_654': {'upper_left_x': 1877,
#   'upper_left_y': 3500,
#   'pol_width': 24,
#   'pol_height': 27,
#   'pix_area': 325},
#  'kamskoe_2706': {'upper_left_x': 1841,
#   'upper_left_y': 3102,
#   'pol_width': 26,
#   'pol_height': 18,
#   'pix_area': 261},
#  'kamskoe_0': {'upper_left_x': 4455,
#   'upper_left_y': 50,
#   'pol_width': 11,
#   'pol_height': 11,
#   'pix_area': 74},
#  'bavlinskoe_283': {'upper_left_x': 2731,
#   'upper_left_y': 1146,
#   'pol_width': 28,
#   'pol_height': 63,
#   'pix_area': 831},
#  'bavlinskoe_119': {'upper_left_x': 3019,
#   'upper_left_y': 37,
#   'pol_width': 22,
#   'pol_height': 22,
#   'pix_area': 215},
#  'kamskoe_3081': {'upper_left_x': 1906,
#   'upper_left_y': 3573,
#   'pol_width': 31,
#   'pol_height': 26,
#   'pix_area': 385},
#  'mamadyshskoe_420': {'upper_left_x': 2770,
#   'upper_left_y': 2294,
#   'pol_width': 8,
#   'pol_height': 34,
#   'pix_area': 180},
#  'mamadyshskoe_712': {'upper_left_x': 2193,
#   'upper_left_y': 2520,
#   'pol_width': 7,
#   'pol_height': 14,
#   'pix_area': 61},
#  'aksubaevskoe_515': {'upper_left_x': 1953,
#   'upper_left_y': 3440,
#   'pol_width': 32,
#   'pol_height': 62,
#   'pix_area': 687},
#  'bugulminskoe_199': {'upper_left_x': 4633,
#   'upper_left_y': 6201,
#   'pol_width': 25,
#   'pol_height': 22,
#   'pix_area': 299},
#  'bugulminskoe_305': {'upper_left_x': 4569,
#   'upper_left_y': 6162,
#   'pol_width': 60,
#   'pol_height': 48,
#   'pix_area': 1657},
#  'elabuzhskoe_209': {'upper_left_x': 5277,
#   'upper_left_y': 1496,
#   'pol_width': 12,
#   'pol_height': 50,
#   'pix_area': 341},
#  'bugulminskoe_225': {'upper_left_x': 4630,
#   'upper_left_y': 6109,
#   'pol_width': 50,
#   'pol_height': 46,
#   'pix_area': 1071},
#  'kaleykinskoe_924': {'upper_left_x': 4436,
#   'upper_left_y': 3029,
#   'pol_width': 14,
#   'pol_height': 20,
#   'pix_area': 200},
#  'menzelinskoe_2847': {'upper_left_x': 5260,
#   'upper_left_y': 7153,
#   'pol_width': 18,
#   'pol_height': 16,
#   'pix_area': 76},
#  'mamadyshskoe_941': {'upper_left_x': 2859,
#   'upper_left_y': 2380,
#   'pol_width': 22,
#   'pol_height': 25,
#   'pix_area': 304},
#  'kyzyl-yulduzskoe_2364': {'upper_left_x': 5194,
#   'upper_left_y': 5108,
#   'pol_width': 24,
#   'pol_height': 27,
#   'pix_area': 325},
#  'kyzyl-yulduzskoe_654': {'upper_left_x': 4779,
#   'upper_left_y': 4969,
#   'pol_width': 22,
#   'pol_height': 13,
#   'pix_area': 171},
#  'menzelinskoe_3947': {'upper_left_x': 5291,
#   'upper_left_y': 7547,
#   'pol_width': 13,
#   'pol_height': 16,
#   'pix_area': 125},
#  'bolgarskoe_91': {'upper_left_x': 1749,
#   'upper_left_y': 2234,
#   'pol_width': 35,
#   'pol_height': 33,
#   'pix_area': 612},
#  'mamadyshskoe_1325': {'upper_left_x': 98,
#   'upper_left_y': 1936,
#   'pol_width': 25,
#   'pol_height': 9,
#   'pix_area': 163},
#  'bugulminskoe_135': {'upper_left_x': 4771,
#   'upper_left_y': 5328,
#   'pol_width': 63,
#   'pol_height': 78,
#   'pix_area': 1708},
#  'mamadyshskoe_1108': {'upper_left_x': 3882,
#   'upper_left_y': 6180,
#   'pol_width': 37,
#   'pol_height': 35,
#   'pix_area': 577},
#  'kamskoe_2950': {'upper_left_x': 1751,
#   'upper_left_y': 4784,
#   'pol_width': 16,
#   'pol_height': 11,
#   'pix_area': 96},
#  'kaleykinskoe_709': {'upper_left_x': 4358,
#   'upper_left_y': 1697,
#   'pol_width': 3,
#   'pol_height': 3,
#   'pix_area': 7},
#  'kyzyl-yulduzskoe_579': {'upper_left_x': 6984,
#   'upper_left_y': 4979,
#   'pol_width': 41,
#   'pol_height': 8,
#   'pix_area': 221},
#  'kamskoe_1327': {'upper_left_x': 1755,
#   'upper_left_y': 3665,
#   'pol_width': 29,
#   'pol_height': 19,
#   'pix_area': 282},
#  'mamadyshskoe_772': {'upper_left_x': 3009,
#   'upper_left_y': 3553,
#   'pol_width': 25,
#   'pol_height': 30,
#   'pix_area': 381},
#  'kamskoe_402': {'upper_left_x': 1904,
#   'upper_left_y': 3547,
#   'pol_width': 5,
#   'pol_height': 26,
#   'pix_area': 78},
#  'menzelinskoe_294': {'upper_left_x': 5215,
#   'upper_left_y': 6597,
#   'pol_width': 24,
#   'pol_height': 28,
#   'pix_area': 436},
#  'menzelinskoe_1976': {'upper_left_x': 5064,
#   'upper_left_y': 7515,
#   'pol_width': 4,
#   'pol_height': 5,
#   'pix_area': 16},
#  'menzelinskoe_4117': {'upper_left_x': 4279,
#   'upper_left_y': 5952,
#   'pol_width': 27,
#   'pol_height': 13,
#   'pix_area': 211},
#  'menzelinskoe_2629': {'upper_left_x': 5517,
#   'upper_left_y': 6980,
#   'pol_width': 25,
#   'pol_height': 21,
#   'pix_area': 158},
#  'bavlinskoe_114': {'upper_left_x': 2817,
#   'upper_left_y': 165,
#   'pol_width': 11,
#   'pol_height': 21,
#   'pix_area': 137},
#  'kaleykinskoe_539': {'upper_left_x': 4611,
#   'upper_left_y': 2674,
#   'pol_width': 4,
#   'pol_height': 2,
#   'pix_area': 7},
#  'kamskoe_812': {'upper_left_x': 2914,
#   'upper_left_y': 3105,
#   'pol_width': 17,
#   'pol_height': 24,
#   'pix_area': 147},
#  'elabuzhskoe_68': {'upper_left_x': 5185,
#   'upper_left_y': 2191,
#   'pol_width': 12,
#   'pol_height': 32,
#   'pix_area': 167},
#  'kamskoe_2170': {'upper_left_x': 3785,
#   'upper_left_y': 1158,
#   'pol_width': 18,
#   'pol_height': 14,
#   'pix_area': 130},
#  'kyzyl-yulduzskoe_2899': {'upper_left_x': 5211,
#   'upper_left_y': 5121,
#   'pol_width': 17,
#   'pol_height': 34,
#   'pix_area': 302},
#  'bavlinskoe_150': {'upper_left_x': 2738,
#   'upper_left_y': 1123,
#   'pol_width': 8,
#   'pol_height': 21,
#   'pix_area': 103},
#  'kamskoe_815': {'upper_left_x': 2998,
#   'upper_left_y': 2414,
#   'pol_width': 14,
#   'pol_height': 13,
#   'pix_area': 105},
#  'bugulminskoe_286': {'upper_left_x': 4743,
#   'upper_left_y': 6284,
#   'pol_width': 23,
#   'pol_height': 40,
#   'pix_area': 606},
#  'kamskoe_611': {'upper_left_x': 4146,
#   'upper_left_y': 2491,
#   'pol_width': 32,
#   'pol_height': 66,
#   'pix_area': 1140},
#  'agryzskoe_548': {'upper_left_x': 3293,
#   'upper_left_y': 5634,
#   'pol_width': 4,
#   'pol_height': 6,
#   'pix_area': 17},
#  'mamadyshskoe_434': {'upper_left_x': 2238,
#   'upper_left_y': 2803,
#   'pol_width': 12,
#   'pol_height': 6,
#   'pix_area': 58},
#  'kamskoe_17': {'upper_left_x': 5672,
#   'upper_left_y': 1078,
#   'pol_width': 17,
#   'pol_height': 19,
#   'pix_area': 143},
#  'menzelinskoe_2139': {'upper_left_x': 5062,
#   'upper_left_y': 6074,
#   'pol_width': 8,
#   'pol_height': 8,
#   'pix_area': 21},
#  'menzelinskoe_287': {'upper_left_x': 5202,
#   'upper_left_y': 7574,
#   'pol_width': 57,
#   'pol_height': 46,
#   'pix_area': 554},
#  'mamadyshskoe_1355': {'upper_left_x': 2673,
#   'upper_left_y': 2176,
#   'pol_width': 41,
#   'pol_height': 27,
#   'pix_area': 519},
#  'menzelinskoe_3504': {'upper_left_x': 3646,
#   'upper_left_y': 2949,
#   'pol_width': 10,
#   'pol_height': 19,
#   'pix_area': 77},
#  'bavlinskoe_412': {'upper_left_x': 1289,
#   'upper_left_y': 2837,
#   'pol_width': 18,
#   'pol_height': 12,
#   'pix_area': 160},
#  'elabuzhskoe_492': {'upper_left_x': 5456,
#   'upper_left_y': 3088,
#   'pol_width': 16,
#   'pol_height': 27,
#   'pix_area': 371},
#  'aksubaevskoe_602': {'upper_left_x': 1477,
#   'upper_left_y': 2211,
#   'pol_width': 18,
#   'pol_height': 5,
#   'pix_area': 37},
#  'kamskoe_2521': {'upper_left_x': 1999,
#   'upper_left_y': 3441,
#   'pol_width': 5,
#   'pol_height': 6,
#   'pix_area': 25},
#  'bavlinskoe_181': {'upper_left_x': 2639,
#   'upper_left_y': 982,
#   'pol_width': 11,
#   'pol_height': 9,
#   'pix_area': 63},
#  'menzelinskoe_734': {'upper_left_x': 6092,
#   'upper_left_y': 6265,
#   'pol_width': 35,
#   'pol_height': 23,
#   'pix_area': 442},
#  'mamadyshskoe_528': {'upper_left_x': 2295,
#   'upper_left_y': 2905,
#   'pol_width': 30,
#   'pol_height': 12,
#   'pix_area': 309},
#  'mamadyshskoe_437': {'upper_left_x': 1895,
#   'upper_left_y': 2878,
#   'pol_width': 14,
#   'pol_height': 25,
#   'pix_area': 197},
#  'kamskoe_1224': {'upper_left_x': 3838,
#   'upper_left_y': 4296,
#   'pol_width': 19,
#   'pol_height': 10,
#   'pix_area': 61},
#  'kyzyl-yulduzskoe_2620': {'upper_left_x': 5281,
#   'upper_left_y': 5101,
#   'pol_width': 7,
#   'pol_height': 12,
#   'pix_area': 85},
#  'menzelinskoe_797': {'upper_left_x': 5922,
#   'upper_left_y': 6287,
#   'pol_width': 17,
#   'pol_height': 14,
#   'pix_area': 148},
#  'bugulminskoe_329': {'upper_left_x': 4626,
#   'upper_left_y': 6275,
#   'pol_width': 11,
#   'pol_height': 15,
#   'pix_area': 61},
#  'kaleykinskoe_676': {'upper_left_x': 4536,
#   'upper_left_y': 1754,
#   'pol_width': 16,
#   'pol_height': 16,
#   'pix_area': 102},
#  'menzelinskoe_4222': {'upper_left_x': 4713,
#   'upper_left_y': 6116,
#   'pol_width': 17,
#   'pol_height': 14,
#   'pix_area': 186},
#  'elabuzhskoe_427': {'upper_left_x': 826,
#   'upper_left_y': 1878,
#   'pol_width': 37,
#   'pol_height': 43,
#   'pix_area': 157},
#  'bavlinskoe_189': {'upper_left_x': 2618,
#   'upper_left_y': 869,
#   'pol_width': 9,
#   'pol_height': 8,
#   'pix_area': 46},
#  'bavlinskoe_200': {'upper_left_x': 2659,
#   'upper_left_y': 1031,
#   'pol_width': 12,
#   'pol_height': 26,
#   'pix_area': 137},
#  'bavlinskoe_214': {'upper_left_x': 2661,
#   'upper_left_y': 1027,
#   'pol_width': 24,
#   'pol_height': 21,
#   'pix_area': 234},
#  'menzelinskoe_4231': {'upper_left_x': 3497,
#   'upper_left_y': 6088,
#   'pol_width': 9,
#   'pol_height': 18,
#   'pix_area': 117},
#  'kamskoe_2974': {'upper_left_x': 4426,
#   'upper_left_y': 4219,
#   'pol_width': 35,
#   'pol_height': 23,
#   'pix_area': 318},
#  'kyzyl-yulduzskoe_536': {'upper_left_x': 6169,
#   'upper_left_y': 6153,
#   'pol_width': 35,
#   'pol_height': 40,
#   'pix_area': 475},
#  'bavlinskoe_380': {'upper_left_x': 197,
#   'upper_left_y': 916,
#   'pol_width': 20,
#   'pol_height': 27,
#   'pix_area': 335},
#  'menzelinskoe_3301': {'upper_left_x': 5479,
#   'upper_left_y': 6771,
#   'pol_width': 57,
#   'pol_height': 58,
#   'pix_area': 1921},
#  'menzelinskoe_4290': {'upper_left_x': 2511,
#   'upper_left_y': 2291,
#   'pol_width': 27,
#   'pol_height': 16,
#   'pix_area': 197},
#  'bolgarskoe_77': {'upper_left_x': 779,
#   'upper_left_y': 2568,
#   'pol_width': 36,
#   'pol_height': 18,
#   'pix_area': 391},
#  'kamskoe_1959': {'upper_left_x': 1880,
#   'upper_left_y': 3843,
#   'pol_width': 12,
#   'pol_height': 17,
#   'pix_area': 126},
#  'bavlinskoe_211': {'upper_left_x': 2933,
#   'upper_left_y': 1141,
#   'pol_width': 7,
#   'pol_height': 12,
#   'pix_area': 42},
#  'menzelinskoe_4211': {'upper_left_x': 3307,
#   'upper_left_y': 5880,
#   'pol_width': 11,
#   'pol_height': 5,
#   'pix_area': 45},
#  'kaleykinskoe_52': {'upper_left_x': 3972,
#   'upper_left_y': 2468,
#   'pol_width': 32,
#   'pol_height': 40,
#   'pix_area': 649},
#  'menzelinskoe_1665': {'upper_left_x': 3713,
#   'upper_left_y': 3491,
#   'pol_width': 11,
#   'pol_height': 20,
#   'pix_area': 56},
#  'agryzskoe_361': {'upper_left_x': 1543,
#   'upper_left_y': 3323,
#   'pol_width': 14,
#   'pol_height': 30,
#   'pix_area': 264},
#  'bavlinskoe_27': {'upper_left_x': 314,
#   'upper_left_y': 683,
#   'pol_width': 36,
#   'pol_height': 56,
#   'pix_area': 1026},
#  'mamadyshskoe_694': {'upper_left_x': 2674,
#   'upper_left_y': 2203,
#   'pol_width': 18,
#   'pol_height': 26,
#   'pix_area': 377},
#  'aksubaevskoe_501': {'upper_left_x': 1730,
#   'upper_left_y': 3732,
#   'pol_width': 37,
#   'pol_height': 35,
#   'pix_area': 473},
#  'menzelinskoe_4138': {'upper_left_x': 2167,
#   'upper_left_y': 6505,
#   'pol_width': 5,
#   'pol_height': 7,
#   'pix_area': 34},
#  'bolgarskoe_70': {'upper_left_x': 1964,
#   'upper_left_y': 2182,
#   'pol_width': 32,
#   'pol_height': 20,
#   'pix_area': 452},
#  'kyzyl-yulduzskoe_1029': {'upper_left_x': 5043,
#   'upper_left_y': 4864,
#   'pol_width': 14,
#   'pol_height': 9,
#   'pix_area': 61},
#  'agryzskoe_409': {'upper_left_x': 501,
#   'upper_left_y': 3389,
#   'pol_width': 16,
#   'pol_height': 26,
#   'pix_area': 166},
#  'menzelinskoe_3285': {'upper_left_x': 5022,
#   'upper_left_y': 7250,
#   'pol_width': 19,
#   'pol_height': 7,
#   'pix_area': 107},
#  'kyzyl-yulduzskoe_1001': {'upper_left_x': 4982,
#   'upper_left_y': 4947,
#   'pol_width': 11,
#   'pol_height': 14,
#   'pix_area': 119},
#  'kyzyl-yulduzskoe_3108': {'upper_left_x': 6694,
#   'upper_left_y': 751,
#   'pol_width': 19,
#   'pol_height': 23,
#   'pix_area': 418},
#  'kamskoe_24': {'upper_left_x': 4563,
#   'upper_left_y': 463,
#   'pol_width': 13,
#   'pol_height': 17,
#   'pix_area': 113},
#  'agryzskoe_514': {'upper_left_x': 3644,
#   'upper_left_y': 5119,
#   'pol_width': 7,
#   'pol_height': 23,
#   'pix_area': 111},
#  'kamskoe_860': {'upper_left_x': 1996,
#   'upper_left_y': 3341,
#   'pol_width': 18,
#   'pol_height': 11,
#   'pix_area': 121},
#  'menzelinskoe_4201': {'upper_left_x': 3855,
#   'upper_left_y': 6166,
#   'pol_width': 69,
#   'pol_height': 46,
#   'pix_area': 2018},
#  'kyzyl-yulduzskoe_2420': {'upper_left_x': 5099,
#   'upper_left_y': 4570,
#   'pol_width': 19,
#   'pol_height': 16,
#   'pix_area': 177},
#  'menzelinskoe_4294': {'upper_left_x': 2047,
#   'upper_left_y': 2289,
#   'pol_width': 9,
#   'pol_height': 9,
#   'pix_area': 41},
#  'menzelinskoe_3019': {'upper_left_x': 2922,
#   'upper_left_y': 4178,
#   'pol_width': 18,
#   'pol_height': 26,
#   'pix_area': 278},
#  'aksubaevskoe_478': {'upper_left_x': 1243,
#   'upper_left_y': 4520,
#   'pol_width': 141,
#   'pol_height': 79,
#   'pix_area': 2880},
#  'kaleykinskoe_54': {'upper_left_x': 4580,
#   'upper_left_y': 2060,
#   'pol_width': 28,
#   'pol_height': 30,
#   'pix_area': 383},
#  'elabuzhskoe_392': {'upper_left_x': 5387,
#   'upper_left_y': 3034,
#   'pol_width': 42,
#   'pol_height': 29,
#   'pix_area': 718},
#  'kyzyl-yulduzskoe_2617': {'upper_left_x': 5025,
#   'upper_left_y': 4834,
#   'pol_width': 9,
#   'pol_height': 9,
#   'pix_area': 73},
#  'bugulminskoe_297': {'upper_left_x': 4783,
#   'upper_left_y': 6291,
#   'pol_width': 32,
#   'pol_height': 30,
#   'pix_area': 607},
#  'kaleykinskoe_868': {'upper_left_x': 4567,
#   'upper_left_y': 2238,
#   'pol_width': 5,
#   'pol_height': 8,
#   'pix_area': 17},
#  'menzelinskoe_731': {'upper_left_x': 5151,
#   'upper_left_y': 4673,
#   'pol_width': 19,
#   'pol_height': 19,
#   'pix_area': 187},
#  'bavlinskoe_176': {'upper_left_x': 2628,
#   'upper_left_y': 966,
#   'pol_width': 20,
#   'pol_height': 26,
#   'pix_area': 192},
#  'kaleykinskoe_723': {'upper_left_x': 4534,
#   'upper_left_y': 2736,
#   'pol_width': 26,
#   'pol_height': 32,
#   'pix_area': 370},
#  'bavlinskoe_199': {'upper_left_x': 2664,
#   'upper_left_y': 1051,
#   'pol_width': 18,
#   'pol_height': 21,
#   'pix_area': 221},
#  'menzelinskoe_4422': {'upper_left_x': 5092,
#   'upper_left_y': 6298,
#   'pol_width': 24,
#   'pol_height': 48,
#   'pix_area': 612},
#  'menzelinskoe_4252': {'upper_left_x': 4046,
#   'upper_left_y': 5616,
#   'pol_width': 7,
#   'pol_height': 11,
#   'pix_area': 45},
#  'kyzyl-yulduzskoe_3721': {'upper_left_x': 2745,
#   'upper_left_y': 3141,
#   'pol_width': 18,
#   'pol_height': 20,
#   'pix_area': 126},
#  'menzelinskoe_702': {'upper_left_x': 5685,
#   'upper_left_y': 6234,
#   'pol_width': 15,
#   'pol_height': 18,
#   'pix_area': 126},
#  'menzelinskoe_2348': {'upper_left_x': 6371,
#   'upper_left_y': 7418,
#   'pol_width': 13,
#   'pol_height': 12,
#   'pix_area': 80},
#  'menzelinskoe_4215': {'upper_left_x': 3745,
#   'upper_left_y': 6137,
#   'pol_width': 8,
#   'pol_height': 14,
#   'pix_area': 47},
#  'kamskoe_2765': {'upper_left_x': 87,
#   'upper_left_y': 55,
#   'pol_width': 18,
#   'pol_height': 6,
#   'pix_area': 59},
#  'elabuzhskoe_417': {'upper_left_x': 1653,
#   'upper_left_y': 3907,
#   'pol_width': 34,
#   'pol_height': 34,
#   'pix_area': 542},
#  'aksubaevskoe_503': {'upper_left_x': 1313,
#   'upper_left_y': 4541,
#   'pol_width': 9,
#   'pol_height': 5,
#   'pix_area': 45},
#  'menzelinskoe_2693': {'upper_left_x': 3034,
#   'upper_left_y': 3312,
#   'pol_width': 10,
#   'pol_height': 13,
#   'pix_area': 140},
#  'aksubaevskoe_91': {'upper_left_x': 2155,
#   'upper_left_y': 2202,
#   'pol_width': 9,
#   'pol_height': 8,
#   'pix_area': 72},
#  'kamskoe_583': {'upper_left_x': 4360,
#   'upper_left_y': 4180,
#   'pol_width': 74,
#   'pol_height': 49,
#   'pix_area': 1398},
#  'kamskoe_2159': {'upper_left_x': 4120,
#   'upper_left_y': 2453,
#   'pol_width': 10,
#   'pol_height': 29,
#   'pix_area': 148},
#  'menzelinskoe_4592': {'upper_left_x': 5202,
#   'upper_left_y': 7294,
#   'pol_width': 40,
#   'pol_height': 69,
#   'pix_area': 606},
#  'kamskoe_628': {'upper_left_x': 3880,
#   'upper_left_y': 2910,
#   'pol_width': 72,
#   'pol_height': 34,
#   'pix_area': 866},
#  'bavlinskoe_109': {'upper_left_x': 2742,
#   'upper_left_y': 145,
#   'pol_width': 29,
#   'pol_height': 25,
#   'pix_area': 144},
#  'kamskoe_1705': {'upper_left_x': 1591,
#   'upper_left_y': 2890,
#   'pol_width': 26,
#   'pol_height': 107,
#   'pix_area': 1237},
#  'kyzyl-yulduzskoe_2599': {'upper_left_x': 4853,
#   'upper_left_y': 5042,
#   'pol_width': 27,
#   'pol_height': 19,
#   'pix_area': 366},
#  'bugulminskoe_131': {'upper_left_x': 4733,
#   'upper_left_y': 5191,
#   'pol_width': 25,
#   'pol_height': 29,
#   'pix_area': 350},
#  'kyzyl-yulduzskoe_3083': {'upper_left_x': 4279,
#   'upper_left_y': 6444,
#   'pol_width': 12,
#   'pol_height': 26,
#   'pix_area': 184},
#  'bavlinskoe_227': {'upper_left_x': 2387,
#   'upper_left_y': 1873,
#   'pol_width': 12,
#   'pol_height': 24,
#   'pix_area': 140},
#  'menzelinskoe_1782': {'upper_left_x': 5066,
#   'upper_left_y': 7515,
#   'pol_width': 4,
#   'pol_height': 5,
#   'pix_area': 16},
#  'bolgarskoe_93': {'upper_left_x': 1735,
#   'upper_left_y': 2223,
#   'pol_width': 21,
#   'pol_height': 13,
#   'pix_area': 195},
#  'agryzskoe_432': {'upper_left_x': 4512,
#   'upper_left_y': 6987,
#   'pol_width': 18,
#   'pol_height': 31,
#   'pix_area': 330},
#  'aksubaevskoe_298': {'upper_left_x': 1032,
#   'upper_left_y': 1347,
#   'pol_width': 12,
#   'pol_height': 8,
#   'pix_area': 59},
#  'menzelinskoe_796': {'upper_left_x': 5942,
#   'upper_left_y': 6268,
#   'pol_width': 34,
#   'pol_height': 34,
#   'pix_area': 731},
#  'kyzyl-yulduzskoe_3121': {'upper_left_x': 5987,
#   'upper_left_y': 1290,
#   'pol_width': 17,
#   'pol_height': 20,
#   'pix_area': 200},
#  'menzelinskoe_3532': {'upper_left_x': 3527,
#   'upper_left_y': 556,
#   'pol_width': 15,
#   'pol_height': 7,
#   'pix_area': 94},
#  'menzelinskoe_1038': {'upper_left_x': 5151,
#   'upper_left_y': 7543,
#   'pol_width': 75,
#   'pol_height': 85,
#   'pix_area': 3336},
#  'menzelinskoe_4094': {'upper_left_x': 2822,
#   'upper_left_y': 4009,
#   'pol_width': 7,
#   'pol_height': 8,
#   'pix_area': 34},
#  'menzelinskoe_4245': {'upper_left_x': 3249,
#   'upper_left_y': 5825,
#   'pol_width': 44,
#   'pol_height': 15,
#   'pix_area': 506},
#  'aksubaevskoe_518': {'upper_left_x': 1857,
#   'upper_left_y': 3779,
#   'pol_width': 9,
#   'pol_height': 40,
#   'pix_area': 157},
#  'menzelinskoe_1110': {'upper_left_x': 4007,
#   'upper_left_y': 2987,
#   'pol_width': 24,
#   'pol_height': 19,
#   'pix_area': 240},
#  'menzelinskoe_1147': {'upper_left_x': 3804,
#   'upper_left_y': 2990,
#   'pol_width': 13,
#   'pol_height': 12,
#   'pix_area': 111},
#  'bavlinskoe_404': {'upper_left_x': 1281,
#   'upper_left_y': 2854,
#   'pol_width': 9,
#   'pol_height': 10,
#   'pix_area': 79},
#  'menzelinskoe_2620': {'upper_left_x': 5349,
#   'upper_left_y': 6870,
#   'pol_width': 25,
#   'pol_height': 19,
#   'pix_area': 72},
#  'menzelinskoe_4317': {'upper_left_x': 1152,
#   'upper_left_y': 2915,
#   'pol_width': 7,
#   'pol_height': 11,
#   'pix_area': 73},
#  'bavlinskoe_98': {'upper_left_x': 2753,
#   'upper_left_y': 191,
#   'pol_width': 6,
#   'pol_height': 9,
#   'pix_area': 31},
#  'kaleykinskoe_86': {'upper_left_x': 4163,
#   'upper_left_y': 2961,
#   'pol_width': 10,
#   'pol_height': 23,
#   'pix_area': 138},
#  'bavlinskoe_261': {'upper_left_x': 2526,
#   'upper_left_y': 863,
#   'pol_width': 12,
#   'pol_height': 13,
#   'pix_area': 30},
#  'kamskoe_94': {'upper_left_x': 1780,
#   'upper_left_y': 3167,
#   'pol_width': 6,
#   'pol_height': 9,
#   'pix_area': 41},
#  'kyzyl-yulduzskoe_3103': {'upper_left_x': 6965,
#   'upper_left_y': 1729,
#   'pol_width': 20,
#   'pol_height': 3,
#   'pix_area': 73},
#  'agryzskoe_195': {'upper_left_x': 455,
#   'upper_left_y': 3391,
#   'pol_width': 38,
#   'pol_height': 23,
#   'pix_area': 372},
#  'elabuzhskoe_421': {'upper_left_x': 1564,
#   'upper_left_y': 2962,
#   'pol_width': 21,
#   'pol_height': 39,
#   'pix_area': 87},
#  'bavlinskoe_234': {'upper_left_x': 3003,
#   'upper_left_y': 1214,
#   'pol_width': 34,
#   'pol_height': 33,
#   'pix_area': 558},
#  'menzelinskoe_4271': {'upper_left_x': 2488,
#   'upper_left_y': 2212,
#   'pol_width': 25,
#   'pol_height': 16,
#   'pix_area': 229},
#  'bolgarskoe_90': {'upper_left_x': 1785,
#   'upper_left_y': 2215,
#   'pol_width': 43,
#   'pol_height': 25,
#   'pix_area': 492},
#  'agryzskoe_262': {'upper_left_x': 1553,
#   'upper_left_y': 3231,
#   'pol_width': 5,
#   'pol_height': 9,
#   'pix_area': 32},
#  'kaleykinskoe_490': {'upper_left_x': 4666,
#   'upper_left_y': 2717,
#   'pol_width': 2,
#   'pol_height': 3,
#   'pix_area': 7},
#  'elabuzhskoe_412': {'upper_left_x': 2507,
#   'upper_left_y': 3007,
#   'pol_width': 11,
#   'pol_height': 20,
#   'pix_area': 92},
#  'kyzyl-yulduzskoe_2092': {'upper_left_x': 7437,
#   'upper_left_y': 4062,
#   'pol_width': 10,
#   'pol_height': 29,
#   'pix_area': 148},
#  'bolgarskoe_48': {'upper_left_x': 1299,
#   'upper_left_y': 2195,
#   'pol_width': 25,
#   'pol_height': 21,
#   'pix_area': 398},
#  'menzelinskoe_772': {'upper_left_x': 5544,
#   'upper_left_y': 5222,
#   'pol_width': 16,
#   'pol_height': 14,
#   'pix_area': 117},
#  'kyzyl-yulduzskoe_1453': {'upper_left_x': 5091,
#   'upper_left_y': 5164,
#   'pol_width': 6,
#   'pol_height': 7,
#   'pix_area': 36},
#  'menzelinskoe_2114': {'upper_left_x': 5872,
#   'upper_left_y': 7485,
#   'pol_width': 35,
# ...
#   'pix_area': 467},
#  'kamskoe_3148': {'upper_left_x': 3199,
#   'upper_left_y': 1588,
#   'pol_width': 20,
#   'pol_height': 16,
#   'pix_area': 216},
#  'bolgarskoe_25': {'upper_left_x': 617,
#   'upper_left_y': 2507,
#   'pol_width': 7,
#   'pol_height': 9,
#   'pix_area': 38},
#  'bugulminskoe_205': {'upper_left_x': 4696,
#   'upper_left_y': 6190,
#   'pol_width': 8,
#   'pol_height': 4,
#   'pix_area': 16},
#  'mamadyshskoe_1425': {'upper_left_x': 2697,
#   'upper_left_y': 2282,
#   'pol_width': 26,
#   'pol_height': 31,
#   'pix_area': 402},
#  'bolgarskoe_438': {'upper_left_x': 4897,
#   'upper_left_y': 440,
#   'pol_width': 33,
#   'pol_height': 29,
#   'pix_area': 603},
#  'mamadyshskoe_627': {'upper_left_x': 2043,
#   'upper_left_y': 2443,
#   'pol_width': 13,
#   'pol_height': 22,
#   'pix_area': 229},
#  'menzelinskoe_4140': {'upper_left_x': 4576,
#   'upper_left_y': 6036,
#   'pol_width': 43,
#   'pol_height': 20,
#   'pix_area': 433},
#  'menzelinskoe_778': {'upper_left_x': 5740,
#   'upper_left_y': 6426,
#   'pol_width': 27,
#   'pol_height': 12,
#   'pix_area': 99},
#  'menzelinskoe_3539': {'upper_left_x': 3959,
#   'upper_left_y': 664,
#   'pol_width': 12,
#   'pol_height': 9,
#   'pix_area': 55},
#  'mamadyshskoe_1288': {'upper_left_x': 2684,
#   'upper_left_y': 2264,
#   'pol_width': 9,
#   'pol_height': 15,
#   'pix_area': 108},
#  'bugulminskoe_304': {'upper_left_x': 4492,
#   'upper_left_y': 5994,
#   'pol_width': 12,
#   'pol_height': 13,
#   'pix_area': 30},
#  'menzelinskoe_4174': {'upper_left_x': 3851,
#   'upper_left_y': 6441,
#   'pol_width': 62,
#   'pol_height': 36,
#   'pix_area': 677},
#  'elabuzhskoe_327': {'upper_left_x': 5179,
#   'upper_left_y': 2113,
#   'pol_width': 39,
#   'pol_height': 44,
#   'pix_area': 957},
#  'kyzyl-yulduzskoe_1308': {'upper_left_x': 4737,
#   'upper_left_y': 4774,
#   'pol_width': 20,
#   'pol_height': 7,
#   'pix_area': 114},
#  'menzelinskoe_855': {'upper_left_x': 5509,
#   'upper_left_y': 4675,
#   'pol_width': 17,
#   'pol_height': 18,
#   'pix_area': 174},
#  'bavlinskoe_177': {'upper_left_x': 3039,
#   'upper_left_y': 1292,
#   'pol_width': 29,
#   'pol_height': 23,
#   'pix_area': 305},
#  'menzelinskoe_4136': {'upper_left_x': 4454,
#   'upper_left_y': 6291,
#   'pol_width': 6,
#   'pol_height': 4,
#   'pix_area': 12},
#  'agryzskoe_539': {'upper_left_x': 3204,
#   'upper_left_y': 4914,
#   'pol_width': 46,
#   'pol_height': 35,
#   'pix_area': 738},
#  'bavlinskoe_277': {'upper_left_x': 2556,
#   'upper_left_y': 743,
#   'pol_width': 16,
#   'pol_height': 20,
#   'pix_area': 142},
#  'aksubaevskoe_505': {'upper_left_x': 1683,
#   'upper_left_y': 3747,
#   'pol_width': 11,
#   'pol_height': 10,
#   'pix_area': 88},
#  'kyzyl-yulduzskoe_1434': {'upper_left_x': 5031,
#   'upper_left_y': 4460,
#   'pol_width': 89,
#   'pol_height': 55,
#   'pix_area': 2898},
#  'menzelinskoe_2958': {'upper_left_x': 5342,
#   'upper_left_y': 7181,
#   'pol_width': 24,
#   'pol_height': 19,
#   'pix_area': 143},
#  'isleytarskoe_36': {'upper_left_x': 2001,
#   'upper_left_y': 1369,
#   'pol_width': 8,
#   'pol_height': 9,
#   'pix_area': 60},
#  'kyzyl-yulduzskoe_1532': {'upper_left_x': 4628,
#   'upper_left_y': 4836,
#   'pol_width': 20,
#   'pol_height': 14,
#   'pix_area': 162},
#  'kamskoe_27': {'upper_left_x': 5548,
#   'upper_left_y': 512,
#   'pol_width': 28,
#   'pol_height': 28,
#   'pix_area': 356},
#  'aksubaevskoe_509': {'upper_left_x': 1347,
#   'upper_left_y': 4384,
#   'pol_width': 22,
#   'pol_height': 7,
#   'pix_area': 159},
#  'mamadyshskoe_620': {'upper_left_x': 3721,
#   'upper_left_y': 1726,
#   'pol_width': 15,
#   'pol_height': 11,
#   'pix_area': 143},
#  'elabuzhskoe_768': {'upper_left_x': 5401,
#   'upper_left_y': 2855,
#   'pol_width': 17,
#   'pol_height': 23,
#   'pix_area': 163},
#  'kamskoe_2713': {'upper_left_x': 1774,
#   'upper_left_y': 3556,
#   'pol_width': 6,
#   'pol_height': 7,
#   'pix_area': 36},
#  'bavlinskoe_95': {'upper_left_x': 2767,
#   'upper_left_y': 61,
#   'pol_width': 25,
#   'pol_height': 29,
#   'pix_area': 350},
#  'mamadyshskoe_1326': {'upper_left_x': 99,
#   'upper_left_y': 2274,
#   'pol_width': 16,
#   'pol_height': 23,
#   'pix_area': 109},
#  'agryzskoe_413': {'upper_left_x': 1553,
#   'upper_left_y': 3323,
#   'pol_width': 19,
#   'pol_height': 33,
#   'pix_area': 392},
#  'menzelinskoe_1214': {'upper_left_x': 5429,
#   'upper_left_y': 6553,
#   'pol_width': 41,
#   'pol_height': 74,
#   'pix_area': 1836},
#  'menzelinskoe_4186': {'upper_left_x': 4755,
#   'upper_left_y': 6263,
#   'pol_width': 29,
#   'pol_height': 47,
#   'pix_area': 940},
#  'bugulminskoe_252': {'upper_left_x': 4934,
#   'upper_left_y': 6303,
#   'pol_width': 23,
#   'pol_height': 19,
#   'pix_area': 202},
#  'bavlinskoe_269': {'upper_left_x': 2593,
#   'upper_left_y': 1029,
#   'pol_width': 18,
#   'pol_height': 30,
#   'pix_area': 232},
#  'kyzyl-yulduzskoe_551': {'upper_left_x': 7132,
#   'upper_left_y': 5862,
#   'pol_width': 22,
#   'pol_height': 31,
#   'pix_area': 375},
#  'bolgarskoe_262': {'upper_left_x': 4996,
#   'upper_left_y': 393,
#   'pol_width': 52,
#   'pol_height': 23,
#   'pix_area': 658},
#  'kamskoe_2': {'upper_left_x': 5541,
#   'upper_left_y': 1273,
#   'pol_width': 13,
#   'pol_height': 12,
#   'pix_area': 104},
#  'kaleykinskoe_310': {'upper_left_x': 4698,
#   'upper_left_y': 2113,
#   'pol_width': 24,
#   'pol_height': 21,
#   'pix_area': 293},
#  'bugulminskoe_320': {'upper_left_x': 4522,
#   'upper_left_y': 5873,
#   'pol_width': 16,
#   'pol_height': 20,
#   'pix_area': 142},
#  'menzelinskoe_4403': {'upper_left_x': 5586,
#   'upper_left_y': 6694,
#   'pol_width': 14,
#   'pol_height': 29,
#   'pix_area': 221},
#  'menzelinskoe_4326': {'upper_left_x': 1217,
#   'upper_left_y': 2921,
#   'pol_width': 72,
#   'pol_height': 44,
#   'pix_area': 878},
#  'kamskoe_636': {'upper_left_x': 3862,
#   'upper_left_y': 2953,
#   'pol_width': 33,
#   'pol_height': 20,
#   'pix_area': 498},
#  'kamskoe_1355': {'upper_left_x': 1964,
#   'upper_left_y': 3492,
#   'pol_width': 7,
#   'pol_height': 12,
#   'pix_area': 85},
#  'kamskoe_856': {'upper_left_x': 1363,
#   'upper_left_y': 3214,
#   'pol_width': 37,
#   'pol_height': 19,
#   'pix_area': 315},
#  'kamskoe_3451': {'upper_left_x': 4200,
#   'upper_left_y': 2807,
#   'pol_width': 18,
#   'pol_height': 30,
#   'pix_area': 335},
#  'kyzyl-yulduzskoe_897': {'upper_left_x': 4928,
#   'upper_left_y': 4500,
#   'pol_width': 80,
#   'pol_height': 51,
#   'pix_area': 1395},
#  'mamadyshskoe_650': {'upper_left_x': 2671,
#   'upper_left_y': 2228,
#   'pol_width': 18,
#   'pol_height': 20,
#   'pix_area': 279},
#  'kamskoe_2116': {'upper_left_x': 4685,
#   'upper_left_y': 4852,
#   'pol_width': 19,
#   'pol_height': 26,
#   'pix_area': 202},
#  'mamadyshskoe_291': {'upper_left_x': 620,
#   'upper_left_y': 6219,
#   'pol_width': 33,
#   'pol_height': 20,
#   'pix_area': 498},
#  'bugulminskoe_277': {'upper_left_x': 4969,
#   'upper_left_y': 6344,
#   'pol_width': 34,
#   'pol_height': 33,
#   'pix_area': 558},
#  'kyzyl-yulduzskoe_3106': {'upper_left_x': 5899,
#   'upper_left_y': 1125,
#   'pol_width': 24,
#   'pol_height': 13,
#   'pix_area': 171},
#  'kyzyl-yulduzskoe_2257': {'upper_left_x': 5216,
#   'upper_left_y': 5181,
#   'pol_width': 13,
#   'pol_height': 28,
#   'pix_area': 185},
#  'kyzyl-yulduzskoe_3114': {'upper_left_x': 6551,
#   'upper_left_y': 922,
#   'pol_width': 22,
#   'pol_height': 10,
#   'pix_area': 168},
#  'kaleykinskoe_911': {'upper_left_x': 4616,
#   'upper_left_y': 2672,
#   'pol_width': 5,
#   'pol_height': 3,
#   'pix_area': 5},
#  'menzelinskoe_1647': {'upper_left_x': 3361,
#   'upper_left_y': 3167,
#   'pol_width': 9,
#   'pol_height': 8,
#   'pix_area': 74},
#  'kyzyl-yulduzskoe_2685': {'upper_left_x': 3404,
#   'upper_left_y': 1664,
#   'pol_width': 18,
#   'pol_height': 6,
#   'pix_area': 59},
#  'menzelinskoe_3541': {'upper_left_x': 3753,
#   'upper_left_y': 630,
#   'pol_width': 8,
#   'pol_height': 7,
#   'pix_area': 47},
#  'kamskoe_813': {'upper_left_x': 3046,
#   'upper_left_y': 2590,
#   'pol_width': 19,
#   'pol_height': 28,
#   'pix_area': 169},
#  'aksubaevskoe_493': {'upper_left_x': 2141,
#   'upper_left_y': 4085,
#   'pol_width': 17,
#   'pol_height': 37,
#   'pix_area': 495},
#  'menzelinskoe_3451': {'upper_left_x': 3847,
#   'upper_left_y': 3134,
#   'pol_width': 5,
#   'pol_height': 8,
#   'pix_area': 25},
#  'kyzyl-yulduzskoe_2717': {'upper_left_x': 5057,
#   'upper_left_y': 5018,
#   'pol_width': 15,
#   'pol_height': 17,
#   'pix_area': 167},
#  'kamskoe_1188': {'upper_left_x': 1557,
#   'upper_left_y': 3312,
#   'pol_width': 75,
#   'pol_height': 28,
#   'pix_area': 1123},
#  'elabuzhskoe_727': {'upper_left_x': 5370,
#   'upper_left_y': 3066,
#   'pol_width': 27,
#   'pol_height': 13,
#   'pix_area': 276},
#  'menzelinskoe_4093': {'upper_left_x': 3099,
#   'upper_left_y': 3490,
#   'pol_width': 9,
#   'pol_height': 7,
#   'pix_area': 55},
#  'menzelinskoe_1754': {'upper_left_x': 5313,
#   'upper_left_y': 7421,
#   'pol_width': 27,
#   'pol_height': 28,
#   'pix_area': 331},
#  'menzelinskoe_825': {'upper_left_x': 5959,
#   'upper_left_y': 6320,
#   'pol_width': 31,
#   'pol_height': 21,
#   'pix_area': 370},
#  'bavlinskoe_396': {'upper_left_x': 1203,
#   'upper_left_y': 2609,
#   'pol_width': 36,
#   'pol_height': 45,
#   'pix_area': 629},
#  'kamskoe_3208': {'upper_left_x': 3492,
#   'upper_left_y': 90,
#   'pol_width': 8,
#   'pol_height': 27,
#   'pix_area': 192},
#  'menzelinskoe_4142': {'upper_left_x': 4252,
#   'upper_left_y': 5456,
#   'pol_width': 19,
#   'pol_height': 5,
#   'pix_area': 69},
#  'kyzyl-yulduzskoe_3464': {'upper_left_x': 5316,
#   'upper_left_y': 5050,
#   'pol_width': 5,
#   'pol_height': 6,
#   'pix_area': 25},
#  'aksubaevskoe_521': {'upper_left_x': 1863,
#   'upper_left_y': 3889,
#   'pol_width': 27,
#   'pol_height': 17,
#   'pix_area': 199},
#  'menzelinskoe_4347': {'upper_left_x': 5085,
#   'upper_left_y': 7523,
#   'pol_width': 12,
#   'pol_height': 17,
#   'pix_area': 124},
#  'bavlinskoe_289': {'upper_left_x': 189,
#   'upper_left_y': 990,
#   'pol_width': 18,
#   'pol_height': 27,
#   'pix_area': 182},
#  'bavlinskoe_101': {'upper_left_x': 2855,
#   'upper_left_y': 147,
#   'pol_width': 12,
#   'pol_height': 5,
#   'pix_area': 26},
#  'menzelinskoe_777': {'upper_left_x': 5760,
#   'upper_left_y': 5806,
#   'pol_width': 23,
#   'pol_height': 19,
#   'pix_area': 174},
#  'bavlinskoe_185': {'upper_left_x': 2594,
#   'upper_left_y': 869,
#   'pol_width': 26,
#   'pol_height': 21,
#   'pix_area': 271},
#  'kyzyl-yulduzskoe_3538': {'upper_left_x': 1832,
#   'upper_left_y': 3422,
#   'pol_width': 15,
#   'pol_height': 12,
#   'pix_area': 92},
#  'aksubaevskoe_500': {'upper_left_x': 2139,
#   'upper_left_y': 3645,
#   'pol_width': 5,
#   'pol_height': 6,
#   'pix_area': 32},
#  'menzelinskoe_3232': {'upper_left_x': 4936,
#   'upper_left_y': 7312,
#   'pol_width': 14,
#   'pol_height': 14,
#   'pix_area': 104},
#  'bolgarskoe_12': {'upper_left_x': 515,
#   'upper_left_y': 2655,
#   'pol_width': 10,
#   'pol_height': 7,
#   'pix_area': 43},
#  'mamadyshskoe_33': {'upper_left_x': 2198,
#   'upper_left_y': 3698,
#   'pol_width': 7,
#   'pol_height': 6,
#   'pix_area': 38},
#  'bugulminskoe_299': {'upper_left_x': 4515,
#   'upper_left_y': 5992,
#   'pol_width': 12,
#   'pol_height': 15,
#   'pix_area': 151},
#  'agryzskoe_645': {'upper_left_x': 4370,
#   'upper_left_y': 3653,
#   'pol_width': 22,
#   'pol_height': 12,
#   'pix_area': 165},
#  'agryzskoe_42': {'upper_left_x': 892,
#   'upper_left_y': 3993,
#   'pol_width': 42,
#   'pol_height': 30,
#   'pix_area': 697},
#  'bugulminskoe_158': {'upper_left_x': 5006,
#   'upper_left_y': 5179,
#   'pol_width': 11,
#   'pol_height': 12,
#   'pix_area': 73},
#  'agryzskoe_428': {'upper_left_x': 3566,
#   'upper_left_y': 6005,
#   'pol_width': 30,
#   'pol_height': 25,
#   'pix_area': 341},
#  'agryzskoe_643': {'upper_left_x': 4707,
#   'upper_left_y': 3687,
#   'pol_width': 18,
#   'pol_height': 10,
#   'pix_area': 82},
#  'aksubaevskoe_461': {'upper_left_x': 1241,
#   'upper_left_y': 4445,
#   'pol_width': 8,
#   'pol_height': 55,
#   'pix_area': 360},
#  'menzelinskoe_4210': {'upper_left_x': 4658,
#   'upper_left_y': 6003,
#   'pol_width': 11,
#   'pol_height': 8,
#   'pix_area': 47},
#  'menzelinskoe_81': {'upper_left_x': 6512,
#   'upper_left_y': 7125,
#   'pol_width': 74,
#   'pol_height': 78,
#   'pix_area': 2671},
#  'mamadyshskoe_1333': {'upper_left_x': 52,
#   'upper_left_y': 2478,
#   'pol_width': 37,
#   'pol_height': 50,
#   'pix_area': 1017},
#  'mamadyshskoe_1493': {'upper_left_x': 779,
#   'upper_left_y': 6598,
#   'pol_width': 59,
#   'pol_height': 34,
#   'pix_area': 922},
#  'menzelinskoe_4253': {'upper_left_x': 3692,
#   'upper_left_y': 5995,
#   'pol_width': 20,
#   'pol_height': 28,
#   'pix_area': 308},
#  'kamskoe_2847': {'upper_left_x': 1642,
#   'upper_left_y': 3269,
#   'pol_width': 26,
#   'pol_height': 30,
#   'pix_area': 473},
#  'bugulminskoe_130': {'upper_left_x': 4719,
#   'upper_left_y': 5330,
#   'pol_width': 4,
#   'pol_height': 5,
#   'pix_area': 13},
#  'mamadyshskoe_267': {'upper_left_x': 969,
#   'upper_left_y': 5370,
#   'pol_width': 21,
#   'pol_height': 59,
#   'pix_area': 513},
#  'kamskoe_3548': {'upper_left_x': 1801,
#   'upper_left_y': 3742,
#   'pol_width': 18,
#   'pol_height': 34,
#   'pix_area': 212},
#  'menzelinskoe_4251': {'upper_left_x': 4383,
#   'upper_left_y': 6064,
#   'pol_width': 27,
#   'pol_height': 34,
#   'pix_area': 493},
#  'kaleykinskoe_934': {'upper_left_x': 3338,
#   'upper_left_y': 3806,
#   'pol_width': 9,
#   'pol_height': 6,
#   'pix_area': 48},
#  'kaleykinskoe_386': {'upper_left_x': 4180,
#   'upper_left_y': 1830,
#   'pol_width': 38,
#   'pol_height': 27,
#   'pix_area': 523},
#  'agryzskoe_426': {'upper_left_x': 4049,
#   'upper_left_y': 7715,
#   'pol_width': 19,
#   'pol_height': 49,
#   'pix_area': 693},
#  'menzelinskoe_3505': {'upper_left_x': 2431,
#   'upper_left_y': 3195,
#   'pol_width': 32,
#   'pol_height': 26,
#   'pix_area': 318},
#  'menzelinskoe_4151': {'upper_left_x': 3861,
#   'upper_left_y': 6100,
#   'pol_width': 35,
#   'pol_height': 44,
#   'pix_area': 833},
#  'kaleykinskoe_366': {'upper_left_x': 3579,
#   'upper_left_y': 2048,
#   'pol_width': 14,
#   'pol_height': 14,
#   'pix_area': 70},
#  'menzelinskoe_3248': {'upper_left_x': 5463,
#   'upper_left_y': 6977,
#   'pol_width': 28,
#   'pol_height': 26,
#   'pix_area': 154},
#  'menzelinskoe_742': {'upper_left_x': 5755,
#   'upper_left_y': 5962,
#   'pol_width': 14,
#   'pol_height': 16,
#   'pix_area': 118},
#  'kamskoe_1846': {'upper_left_x': 1559,
#   'upper_left_y': 3246,
#   'pol_width': 18,
#   'pol_height': 32,
#   'pix_area': 379},
#  'elabuzhskoe_195': {'upper_left_x': 5510,
#   'upper_left_y': 3340,
#   'pol_width': 42,
#   'pol_height': 20,
#   'pix_area': 377},
#  'bugulminskoe_282': {'upper_left_x': 4740,
#   'upper_left_y': 6226,
#   'pol_width': 14,
#   'pol_height': 12,
#   'pix_area': 79},
#  'bavlinskoe_413': {'upper_left_x': 2699,
#   'upper_left_y': 2211,
#   'pol_width': 12,
#   'pol_height': 24,
#   'pix_area': 163},
#  'kamskoe_3430': {'upper_left_x': 4272,
#   'upper_left_y': 2157,
#   'pol_width': 31,
#   'pol_height': 36,
#   'pix_area': 421},
#  'kaleykinskoe_75': {'upper_left_x': 4963,
#   'upper_left_y': 2501,
#   'pol_width': 81,
#   'pol_height': 82,
#   'pix_area': 2471},
#  'kamskoe_1211': {'upper_left_x': 5826,
#   'upper_left_y': 145,
#   'pol_width': 22,
#   'pol_height': 32,
#   'pix_area': 323},
#  'kamskoe_3537': {'upper_left_x': 2230,
#   'upper_left_y': 3326,
#   'pol_width': 8,
#   'pol_height': 18,
#   'pix_area': 79},
#  'bugulminskoe_294': {'upper_left_x': 4528,
#   'upper_left_y': 6023,
#   'pol_width': 5,
#   'pol_height': 7,
#   'pix_area': 21},
#  'agryzskoe_631': {'upper_left_x': 4327,
#   'upper_left_y': 3712,
#   'pol_width': 39,
#   'pol_height': 25,
#   'pix_area': 622},
#  'kyzyl-yulduzskoe_2566': {'upper_left_x': 5057,
#   'upper_left_y': 4991,
#   'pol_width': 20,
#   'pol_height': 33,
#   'pix_area': 356},
#  'menzelinskoe_3721': {'upper_left_x': 6507,
#   'upper_left_y': 7054,
#   'pol_width': 78,
#   'pol_height': 92,
#   'pix_area': 3160},
#  'mamadyshskoe_206': {'upper_left_x': 2052,
#   'upper_left_y': 2604,
#   'pol_width': 28,
#   'pol_height': 20,
#   'pix_area': 286},
#  'kamskoe_1001': {'upper_left_x': 2400,
#   'upper_left_y': 5600,
#   'pol_width': 43,
#   'pol_height': 12,
#   'pix_area': 319},
#  'kaleykinskoe_6': {'upper_left_x': 4655,
#   'upper_left_y': 3171,
#   'pol_width': 22,
#   'pol_height': 22,
#   'pix_area': 209},
#  'kamskoe_1460': {'upper_left_x': 1739,
#   'upper_left_y': 3382,
#   'pol_width': 20,
#   'pol_height': 33,
#   'pix_area': 356},
#  'kamskoe_3179': {'upper_left_x': 2392,
#   'upper_left_y': 5386,
#   'pol_width': 17,
#   'pol_height': 19,
#   'pix_area': 183},
#  'kyzyl-yulduzskoe_1950': {'upper_left_x': 5093,
#   'upper_left_y': 5271,
#   'pol_width': 19,
#   'pol_height': 9,
#   'pix_area': 92},
#  'bavlinskoe_253': {'upper_left_x': 2556,
#   'upper_left_y': 904,
#   'pol_width': 14,
#   'pol_height': 15,
#   'pix_area': 114}}

# %%
def pred_val(cl_json):
    imgarr=[]
    maskarr=[]
    for key in cl_json.keys():
        imgpath = '/home/user/data/projects/research-project/notebooks/Illarionova/Forestry_inventory/wv_inference/krasnoborsk/tmp/'\
            +key.split('_')[0]
        upper_left_x, upper_left_y, pol_width, pol_height = cl_json[key]['upper_left_x'], cl_json[key]['upper_left_y'],\
                                                            cl_json[key]['pol_width'], cl_json[key]['pol_height']
        img, mask = generator.get_img_mask_array(imgpath, upper_left_x, upper_left_y, pol_width, pol_height)
        imgarr.append(img)
        maskarr.append(mask)

    imgarr = np.asarray(imgarr)
    maskarr = np.asarray(maskarr)
    return imgarr, maskarr

img_linden, mask_linden = pred_val(generator.json_file_linden_val)
img_oak, mask_oak = pred_val(generator.json_file_oak_val)
pred_linden = model.predict(img_linden)
pred_oak = model.predict(img_oak)

# %%
len(generator.json_file_linden_train.keys())
# Out:
# 1899

# %%
pred_linden.shape, pred_oak.shape, mask_oak.shape
# Out:
# ((799, 64, 64, 2), (665, 64, 64, 2), (665, 64, 64, 2))

# %%
ind = 70
fig = plt.figure(figsize = (6,6))
a = fig.add_subplot(2, 2, 1)
imgplot = plt.imshow((pred_oak[ind,:,:,0]>0.5)*np.sum(mask_oak[ind],axis=-1))
a.set_title('pred')
a = fig.add_subplot(2, 2, 2)
imgplot = plt.imshow(mask_oak[ind,:,:,0])
a.set_title('mask')
# Out:
# Text(0.5,1,'mask')

# %%
correct_samples = 0
wrong_samples = 0
for ind in range(img_oak.shape[0]): # class 0 oak, class 1 linden
    if np.sum((pred_oak[ind,:,:,0]>0.5)*mask_oak[ind,:,:,0]) > np.sum(mask_oak[ind,:,:,0])*0.5:
        correct_samples += 1
    else:
        wrong_samples += 1
        
for ind in range(img_linden.shape[0]): # class 0 oak, class 1 linden
    if np.sum((pred_linden[ind,:,:,1]>0.5)*mask_linden[ind,:,:,1]) > np.sum(mask_linden[ind,:,:,1])*0.5:
        correct_samples += 1
    else:
        wrong_samples += 1

print(correct_samples / (correct_samples + wrong_samples))
# Out:
# 0.9316939890710383

# %%
correct_samples = 0
wrong_samples = 0
for ind in range(img_oak.shape[0]): # class 0 oak, class 1 linden
    if np.sum((pred_oak[ind,:,:,0]>0.5)*mask_oak[ind,:,:,0]) > np.sum(mask_oak[ind,:,:,0])*0.5:
        correct_samples += 1
    else:
        wrong_samples += 1
        
print(correct_samples / (correct_samples + wrong_samples))
# Out:
# 0.9669172932330827

# %%
correct_samples = 0
wrong_samples = 0
        
for ind in range(img_linden.shape[0]): # class 0 oak, class 1 linden
    if np.sum((pred_linden[ind,:,:,1]>0.5)*mask_linden[ind,:,:,1]) > np.sum(mask_linden[ind,:,:,1])*0.5:
        correct_samples += 1
    else:
        wrong_samples += 1

print(correct_samples / (correct_samples + wrong_samples))
# Out:
# 0.9023779724655819

# %% [markdown]
# ## F1

# %%
TP = 0
FP = 0
TN = 0
FN = 0
for ind in range(img_linden.shape[0]): # class 0 oak, class 1 linden
    if np.sum((pred_linden[ind,:,:,1]>0.5)*mask_linden[ind,:,:,1]) > np.sum(mask_linden[ind,:,:,1])*0.5:
        TP += 1
    else:
        FN += 1
        
for ind in range(img_oak.shape[0]): # class 0 oak, class 1 linden
    if np.sum((pred_oak[ind,:,:,0]>0.5)*mask_oak[ind,:,:,0]) > np.sum(mask_oak[ind,:,:,0])*0.5:
        TN += 1
    else:
        FP += 1

precision = TP / (TP + FP)
recall = TP / (TP + FN)
accuracy = (TP + TN) / (TP + TN + FP + FN) 
f1_cl = 2*((precision*recall)/(precision+recall))

f1_cl, accuracy
# Out:
# (0.8561946902654868, 0.8745173745173745)

# %%
TP = 0
FP = 0
TN = 0
FN = 0
for ind in range(img_linden.shape[0]): # class 0 oak, class 1 linden
    if np.sum((pred_linden[ind,:,:,1]>0.5)*mask_linden[ind,:,:,1]) > np.sum(mask_linden[ind,:,:,1])*0.5:
        TN += 1
    else:
        FP += 1
        
for ind in range(img_oak.shape[0]): # class 0 oak, class 1 linden
    if np.sum((pred_oak[ind,:,:,0]>0.5)*mask_oak[ind,:,:,0]) > np.sum(mask_oak[ind,:,:,0])*0.5:
        TP += 1
    else:
        FN += 1

precision = TP / (TP + FP)
recall = TP / (TP + FN)
accuracy = (TP + TN) / (TP + TN + FP + FN) 
f1_cl = 2*((precision*recall)/(precision+recall))

f1_cl, accuracy
# Out:
# (0.8886986301369864, 0.8745173745173745)

# %%
(0.875140607424072+0.9061707523245984)/2
# Out:
# 0.8906556798743352

# %%
(0.8955223880597014+0.9242298084929226)/2
# Out:
# 0.909876098276312

# %%
(0.861431870669746+0.900497512437811)/2
# Out:
# 0.8809646915537785

# %% [markdown]
# ***
# ***
#
# # Evaluation

# %%
for img, mask in generator.val_gen():
    break
pred = model.predict(img)

# %%
for num in range(1, 25):
    fig = plt.figure(figsize=(10, 10))
    a = fig.add_subplot(1, 5, 1)
    a.set_title('Image')
    imgplot = plt.imshow((img[num, :, :, 0:3] - np.min(img[num, :, :, 0:3]))/(np.max(img[num, :, :, 0:3]) 
                                                                           - np.min(img[num, :, :, 0:3])) )
    a = fig.add_subplot(1, 5, 2)
    a.set_title('Oak prediction')
    imgplot = plt.imshow(np.where(np.argmax(pred[num,:,:,:], axis=2)==0, 1, 0)*np.where(np.sum(mask[num,:,:,:], axis=2)>0, 1, 0)) #.imshow(pred[num,:,:,cl]>0.5) 
    a = fig.add_subplot(1, 5, 3)
    a.set_title('Oak GT')
    imgplot = plt.imshow(mask[num,:,:,0])
    a = fig.add_subplot(1, 5, 4)
    a.set_title('Linden prediction')
    imgplot = plt.imshow(np.where(np.argmax(pred[num,:,:,:], axis=2)==1, 1, 0)*np.where(np.sum(mask[num,:,:,:], axis=2)>0, 1, 0)) #.imshow(pred[num,:,:,cl]>0.5) 
    a = fig.add_subplot(1, 5, 5)
    a.set_title('Linden GT')
    imgplot = plt.imshow(mask[num,:,:,1])
