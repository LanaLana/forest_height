# %%
# %load_ext autoreload
# %autoreload 2
    
import os
import cv2
import sys
import copy
import json
import random
import rasterio
import numpy as np
import tifffile as tiff
from skimage.transform import rescale, resize

import matplotlib.pyplot as plt

from keras import backend as K
from keras.models import Model, model_from_json

from keras.optimizers import SGD, Adam, RMSprop
from keras.backend import categorical_crossentropy, binary_crossentropy
from segmentation_models import Unet, FPN

from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger, Callback

os.environ['CUDA_VISIBLE_DEVICES'] = "1"
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Segmentation Models: using `keras` framework.

# %%
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
sys.path.insert(0, '../')
from height_model_scripts.loss_functions import rmse
from height_model_scripts.metrics import F1_metric, RMSE, MAE, R2, MBE, F1_metric
from height_model_scripts.height_model_scripts import Generator
from height_model_scripts.save_pred import save_pred, tif2geojson

# %% [markdown]
# ### Split on test, train, validation

# %%
train_img_list = []
test_img_list = []
val_img_list = []

train_list_split = ['0_0', '0_1', '0_2',
               '1_0', '1_2',
               '2_0', '2_1', '2_3', '2_4', '2_5',
               '3_1', '3_2', '3_3',
               '4_1', '4_3', '4_4', '4_5',
               '5_1', '5_2', '5_3', '5_4',
               '6_0', '6_1', '6_2', '6_4',
               '7_0', '7_1', '7_2', '7_3', '7_4']
val_list_split = ['1_1', '2_2', '4_2', '6_3']

# krasnoborsk
for folder in os.listdir('/home/user/data/krasnoborsk/world_view/'):
    if 'tif' in folder or 'xml' in folder or folder == 'lines':
        continue
    for file_name in os.listdir('/home/user/data/krasnoborsk/world_view/{}'.format(folder)):
        tmp_ind = file_name.split('_')[0]+'_'+file_name.split('_')[1]
        if tmp_ind in train_list_split and '/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind) not in train_img_list:
            train_img_list += ['/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind)]
        elif tmp_ind in val_list_split and '/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind) not in val_img_list \
            and folder == '0':
            val_img_list += ['/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind)]

# Novoshinsk
dse_pathechs = ['0_0', '0_1', '0_2',
               '1_0', '1_1', '1_2', '1_3',
               '2_0', '2_1', '2_2', '2_3', '2_4', 
               '3_0', '3_1', '3_2', '3_3', '3_4',
               '4_0', '4_1', '4_3', '4_4',
               '5_3', '5_4',
               '6_2', '6_3', '6_4',
               '7_2', '7_3', '7_4',
               '8_2', '8_3', '8_4']

for file_ind in [0, 1, 7, 9]: 
    for patch_ind in dse_pathechs:
        i, j = patch_ind.split('_')
        if patch_ind +'_channel_0.tif' not in os.listdir('/home/user/data/krasnoborsk/Novoshinsk/{}'.format(file_ind)) \
            or patch_ind +'_class_606.tif' not in os.listdir('/home/user/data/krasnoborsk/Novoshinsk/{}'.format(file_ind)):
            continue
        if patch_ind in ['1_1', '2_2', '4_4']:
            test_img_list += ['/home/user/data/krasnoborsk/Novoshinsk/{}/{}'.format(file_ind, patch_ind)]
        else:
            train_img_list += ['/home/user/data/krasnoborsk/Novoshinsk/{}/{}'.format(file_ind, patch_ind)]

# %% [markdown]
# ## New model

# %%
batch_size=20 
num_channels=4

gdal_file_path = './'

generator = Generator(train_img_list, val_img_list, batch_size, num_channels, gdal_file_path=gdal_file_path)

generator.augm = True              # just geometric rotation is applied
generator.color_aug_prob = 1       # add color augm

generator.sharpen_flag = True     # flag to switch pansharpaning
generator.forest_mask = True       # add forest mask if it is provided

generator.lidar_coef = 5           # parameter for height resolution downsampling
generator.lidar_resolution = 1     # resolution of height data
generator.target_resolution = 1    # target resolution both for height and imagery
generator.clip_value = 40.         # the greatest height value 

generator.classifier_mode = 'regression'
generator.channels_list = ['channel_0.tif', 'channel_1.tif', 'channel_2.tif', 'channel_3.tif']

# %%
generator.write_gdalinfo_file()

# %% [markdown]
# ## Save generator parametrs

# %%
generator_state = copy.deepcopy(generator.__dict__)
del generator_state['data_gdal']
del generator_state['img_prob']

nb_name = 'regr_rgb_pan_nir_wv.ipynb'

save_file = nb_name.split('.')[0] + '.json'
with open(save_file, 'w') as f:
    json.dump(generator_state, f)

# %% [markdown]
# ## Check outputs

# %%
# check output
img_tmp, mask_tmp = generator.get_img_mask_array(train_img_list[0])

fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow(img_tmp[:,:,:3])
a.set_title('img')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow(mask_tmp[:,:,0])
a.set_title('lidar')
# Out:
# Text(0.5,1,'lidar')

# %%
generator.augm = False
generator.full_img = True
img_tmp, mask_tmp = generator.get_img_mask_array(train_img_list[2])
generator.full_img = False
generator.augm = True   

fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow(img_tmp[:,:,:3])
a.set_title('img')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow(mask_tmp[:,:,0])
a.set_title('lidar')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5,1,'lidar')

# %% [markdown]
# ## Set model

# %%
model = Unet(backbone_name='inceptionresnetv2', input_shape=(None, None, num_channels), 
                  encoder_weights=None, activation='sigmoid')
loss =  rmse
opt = RMSprop(lr=0.001)
metrics=[loss]
model.compile(optimizer=opt, loss=loss, metrics=metrics)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_applications/imagenet_utils.py:279: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 4 input channels.
#   str(input_shape[-1]) + ' input channels.')

# %%
model_name = 'regr_rgb_pan_nir_wv'
save_dir = '/home/user/data/example/data/Forestry_inventory/Height_model_paper/'

# csv logger
log_filename = os.path.join(save_dir, '{}.csv'.format(model_name))
csv_logger = CSVLogger(log_filename, separator=',', append='True')

callbacks=[
    ReduceLROnPlateau(patience=4,min_lr=1e-9,verbose=1,mode='min'), #pat 7
    ModelCheckpoint(save_dir + '{}.h5'.format(model_name),save_best_only=True,verbose=1),
    ModelCheckpoint(save_dir + '{}.hdf5'.format(model_name),save_best_only=True,verbose=1, save_weights_only=True),
    csv_logger
]

# %%
history=model.fit_generator(generator.train_gen(),epochs=25, #35, 25 20
                           steps_per_epoch=200,#200,
                           validation_data=generator.val_gen(),  #(valid_imgarr,valid_maskarr),
                           callbacks=callbacks, validation_steps=100)#30
# Out:
# Epoch 1/25
# 200/200 [==============================] - 180s 901ms/step - loss: 0.1446 - rmse: 0.1446 - val_loss: 0.2856 - val_rmse: 0.2856
#
# Epoch 00001: val_loss improved from inf to 0.28564, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.h5
#
# Epoch 00001: val_loss improved from inf to 0.28564, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.hdf5
# Epoch 2/25
# 200/200 [==============================] - 140s 699ms/step - loss: 0.1330 - rmse: 0.1330 - val_loss: 0.1324 - val_rmse: 0.1324
#
# Epoch 00002: val_loss improved from 0.28564 to 0.13241, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.h5
#
# Epoch 00002: val_loss improved from 0.28564 to 0.13241, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.hdf5
# Epoch 3/25
# 200/200 [==============================] - 141s 705ms/step - loss: 0.1272 - rmse: 0.1272 - val_loss: 0.1355 - val_rmse: 0.1355
#
# Epoch 00003: val_loss did not improve from 0.13241
#
# Epoch 00003: val_loss did not improve from 0.13241
# Epoch 4/25
# 200/200 [==============================] - 141s 704ms/step - loss: 0.1224 - rmse: 0.1224 - val_loss: 0.1510 - val_rmse: 0.1510
#
# Epoch 00004: val_loss did not improve from 0.13241
#
# Epoch 00004: val_loss did not improve from 0.13241
# Epoch 5/25
# 200/200 [==============================] - 141s 707ms/step - loss: 0.1224 - rmse: 0.1224 - val_loss: 0.1579 - val_rmse: 0.1579
#
# Epoch 00005: val_loss did not improve from 0.13241
#
# Epoch 00005: val_loss did not improve from 0.13241
# Epoch 6/25
# 200/200 [==============================] - 142s 708ms/step - loss: 0.1187 - rmse: 0.1187 - val_loss: 0.1098 - val_rmse: 0.1098
#
# Epoch 00006: val_loss improved from 0.13241 to 0.10977, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.h5
#
# Epoch 00006: val_loss improved from 0.13241 to 0.10977, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.hdf5
# Epoch 7/25
# 200/200 [==============================] - 141s 704ms/step - loss: 0.1168 - rmse: 0.1168 - val_loss: 0.1086 - val_rmse: 0.1086
#
# Epoch 00007: val_loss improved from 0.10977 to 0.10864, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.h5
#
# Epoch 00007: val_loss improved from 0.10977 to 0.10864, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.hdf5
# Epoch 8/25
# 200/200 [==============================] - 141s 703ms/step - loss: 0.1155 - rmse: 0.1155 - val_loss: 0.1519 - val_rmse: 0.1519
#
# Epoch 00008: val_loss did not improve from 0.10864
#
# Epoch 00008: val_loss did not improve from 0.10864
# Epoch 9/25
# 200/200 [==============================] - 140s 702ms/step - loss: 0.1137 - rmse: 0.1137 - val_loss: 0.1205 - val_rmse: 0.1205
#
# Epoch 00009: val_loss did not improve from 0.10864
#
# Epoch 00009: val_loss did not improve from 0.10864
# Epoch 10/25
# 200/200 [==============================] - 141s 705ms/step - loss: 0.1125 - rmse: 0.1125 - val_loss: 0.1355 - val_rmse: 0.1355
#
# Epoch 00010: val_loss did not improve from 0.10864
#
# Epoch 00010: val_loss did not improve from 0.10864
# Epoch 11/25
# 200/200 [==============================] - 142s 708ms/step - loss: 0.1113 - rmse: 0.1113 - val_loss: 0.1116 - val_rmse: 0.1116
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00011: val_loss did not improve from 0.10864
#
# Epoch 00011: val_loss did not improve from 0.10864
# Epoch 12/25
# 200/200 [==============================] - 141s 704ms/step - loss: 0.1064 - rmse: 0.1064 - val_loss: 0.1047 - val_rmse: 0.1047
#
# Epoch 00012: val_loss improved from 0.10864 to 0.10469, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.h5
#
# Epoch 00012: val_loss improved from 0.10864 to 0.10469, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.hdf5
# Epoch 13/25
# 200/200 [==============================] - 144s 718ms/step - loss: 0.1055 - rmse: 0.1055 - val_loss: 0.0986 - val_rmse: 0.0986
#
# Epoch 00013: val_loss improved from 0.10469 to 0.09863, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.h5
#
# Epoch 00013: val_loss improved from 0.10469 to 0.09863, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.hdf5
# Epoch 14/25
# 200/200 [==============================] - 143s 714ms/step - loss: 0.1042 - rmse: 0.1042 - val_loss: 0.0971 - val_rmse: 0.0971
#
# Epoch 00014: val_loss improved from 0.09863 to 0.09714, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.h5
#
# Epoch 00014: val_loss improved from 0.09863 to 0.09714, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.hdf5
# Epoch 15/25
# 200/200 [==============================] - 144s 719ms/step - loss: 0.1031 - rmse: 0.1031 - val_loss: 0.0972 - val_rmse: 0.0972
#
# Epoch 00015: val_loss did not improve from 0.09714
#
# Epoch 00015: val_loss did not improve from 0.09714
# Epoch 16/25
# 200/200 [==============================] - 144s 719ms/step - loss: 0.1031 - rmse: 0.1031 - val_loss: 0.0993 - val_rmse: 0.0993
#
# Epoch 00016: val_loss did not improve from 0.09714
#
# Epoch 00016: val_loss did not improve from 0.09714
# Epoch 17/25
# 200/200 [==============================] - 144s 720ms/step - loss: 0.1035 - rmse: 0.1035 - val_loss: 0.0956 - val_rmse: 0.0956
#
# Epoch 00017: val_loss improved from 0.09714 to 0.09562, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.h5
#
# Epoch 00017: val_loss improved from 0.09714 to 0.09562, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_pan_nir_wv.hdf5
# Epoch 18/25
# 200/200 [==============================] - 143s 717ms/step - loss: 0.1027 - rmse: 0.1027 - val_loss: 0.0968 - val_rmse: 0.0968
#
# Epoch 00018: val_loss did not improve from 0.09562
#
# Epoch 00018: val_loss did not improve from 0.09562
# Epoch 19/25
# 200/200 [==============================] - 144s 721ms/step - loss: 0.1027 - rmse: 0.1027 - val_loss: 0.0976 - val_rmse: 0.0976
#
# Epoch 00019: val_loss did not improve from 0.09562
#
# Epoch 00019: val_loss did not improve from 0.09562
# Epoch 20/25
# 200/200 [==============================] - 144s 718ms/step - loss: 0.1012 - rmse: 0.1012 - val_loss: 0.0959 - val_rmse: 0.0959
#
# Epoch 00020: val_loss did not improve from 0.09562
#
# Epoch 00020: val_loss did not improve from 0.09562
# Epoch 21/25
# 200/200 [==============================] - 144s 721ms/step - loss: 0.1016 - rmse: 0.1016 - val_loss: 0.0957 - val_rmse: 0.0957
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00021: val_loss did not improve from 0.09562
#
# Epoch 00021: val_loss did not improve from 0.09562
# Epoch 22/25
# 200/200 [==============================] - 144s 719ms/step - loss: 0.1020 - rmse: 0.1020 - val_loss: 0.0963 - val_rmse: 0.0963
#
# Epoch 00022: val_loss did not improve from 0.09562
#
# Epoch 00022: val_loss did not improve from 0.09562
# Epoch 23/25
# 200/200 [==============================] - 144s 722ms/step - loss: 0.1002 - rmse: 0.1002 - val_loss: 0.0963 - val_rmse: 0.0963
#
# Epoch 00023: val_loss did not improve from 0.09562
#
# Epoch 00023: val_loss did not improve from 0.09562
# Epoch 24/25
# 200/200 [==============================] - 144s 720ms/step - loss: 0.1011 - rmse: 0.1011 - val_loss: 0.0965 - val_rmse: 0.0965
#
# Epoch 00024: val_loss did not improve from 0.09562
#
# Epoch 00024: val_loss did not improve from 0.09562
# Epoch 25/25
# 200/200 [==============================] - 144s 722ms/step - loss: 0.1005 - rmse: 0.1005 - val_loss: 0.0978 - val_rmse: 0.0978
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 00025: val_loss did not improve from 0.09562
#
# Epoch 00025: val_loss did not improve from 0.09562

# %%
# serialize model to JSON without height
model_name += '_v1'
model_json = model.to_json()
with open(save_dir+"{}.json".format(model_name), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights(save_dir+"{}.h5".format(model_name))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model.load_weights(save_dir+"{}.h5".format(model_name))

# %% [markdown]
# ## Evaluation

# %%
generator.augm  = False
prediction, full_mask = generator.pred_img(model=model, img_path=val_img_list[0])
generator.augm  = True

# %%
fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow((prediction[:,:,0]*generator.clip_value).clip(0, generator.clip_value))
a.set_title('img')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow((full_mask[:,:,0]*generator.clip_value).clip(0, generator.clip_value))
a.set_title('lidar')
# Out:
# Text(0.5,1,'lidar')

# %%
print('RMSE', RMSE(prediction*generator.clip_value, full_mask*generator.clip_value))
print('MAE', MAE(prediction*generator.clip_value, full_mask*generator.clip_value))
# Out:
# RMSE 4.826
# MAE 2.905

# %%
# v1
generator.augm  = False
average_rmse = 0
average_mae = 0
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    cur_rmse = RMSE(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_mae = MAE(prediction*generator.clip_value, full_mask*generator.clip_value)
    average_rmse += cur_rmse
    average_mae += cur_mae
    print(ind, 'rmse: ', cur_rmse, ' mae: ', cur_mae)
generator.augm  = True

print('~~~~~~~~~~~~~~~~')
print('Average RMSE: ', round(average_rmse / len(val_img_list), 3))
print('Average MAE: ', round(average_mae / len(val_img_list), 3))
# Out:
# 0 rmse:  4.826  mae:  2.905
# 1 rmse:  4.26  mae:  3.197
# 2 rmse:  3.252  mae:  2.407
# 3 rmse:  4.32  mae:  3.266
# ~~~~~~~~~~~~~~~~
# Average RMSE:  4.164
# Average MAE:  2.944

# %%
generator.augm  = False
average_rmse = 0
average_mae = 0
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    cur_rmse = RMSE(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_mae = MAE(prediction*generator.clip_value, full_mask*generator.clip_value)
    average_rmse += cur_rmse
    average_mae += cur_mae
    print(ind, 'rmse: ', cur_rmse, ' mae: ', cur_mae)
generator.augm  = True

print('~~~~~~~~~~~~~~~~')
print('Average RMSE: ', round(average_rmse / len(val_img_list), 3))
print('Average MAE: ', round(average_mae / len(val_img_list), 3))
# Out:
# 0 rmse:  4.815  mae:  2.94
# 1 rmse:  4.384  mae:  3.278
# 2 rmse:  3.445  mae:  2.561
# 3 rmse:  4.51  mae:  3.437
# ~~~~~~~~~~~~~~~~
# Average RMSE:  4.289
# Average MAE:  3.054

# %%
generator.augm  = False
average_rmse = 0
average_mae = 0
average_r2 = 0
average_mean_bias = 0
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    cur_rmse = RMSE(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_mae = MAE(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_r2 = R2(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_mean_bias = MBE(prediction*generator.clip_value, full_mask*generator.clip_value)
    average_rmse += cur_rmse
    average_mae += cur_mae
    average_r2 += cur_r2
    average_mean_bias += cur_mean_bias
    print(ind, 'rmse: ', cur_rmse, ' mae: ', cur_mae,  ' r2: ', cur_r2,  ' mbe: ', cur_mean_bias, )

print('~~~~~~~~~~~~~~~~')
print('Average RMSE: ', round(average_rmse / len(val_img_list), 3))
print('Average MAE: ', round(average_mae / len(val_img_list), 3))
print('Average R2: ', round(average_r2 / len(val_img_list), 3))
print('Average mean bias: ', round(average_mean_bias / len(val_img_list), 3))
# Out:
# 0 rmse:  4.815  mae:  2.94  r2:  0.533  mbe:  -0.4001581497045913
# 1 rmse:  3.445  mae:  2.561  r2:  0.643  mbe:  -0.9955384169546421
# 2 rmse:  4.384  mae:  3.278  r2:  0.73  mbe:  0.02741897267584315
# 3 rmse:  4.51  mae:  3.437  r2:  0.348  mbe:  -1.835805273202542
# ~~~~~~~~~~~~~~~~
# Average RMSE:  4.288
# Average MAE:  3.054
# Average R2:  0.564
# Average mean bias:  -0.801

# %%
num_cl = 4
F1_score = np.zeros((num_cl))
class_names=['0-4', '4-10', '10-20', '>20']
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    
    prediction *= generator.clip_value
    full_mask *= generator.clip_value

    pred = np.zeros((1, prediction.shape[0], prediction.shape[1], num_cl))
    mask = np.zeros((1, full_mask.shape[0], full_mask.shape[1], num_cl)) 

    pred[:,:,:,0] = np.where(prediction[:,:,0]>0, 1, 0) * np.where(prediction[:,:,0]<4, 1, 0)
    mask[:,:,:,0] = np.where(full_mask[:,:,0]>0, 1, 0) * np.where(full_mask[:,:,0]<4, 1, 0)

    pred[:,:,:,1] = np.where(prediction[:,:,0]>=4, 1, 0) * np.where(prediction[:,:,0]<10, 1, 0)
    mask[:,:,:,1] = np.where(full_mask[:,:,0]>=4, 1, 0) * np.where(full_mask[:,:,0]<10, 1, 0)

    pred[:,:,:,2] = np.where(prediction[:,:,0]>=10, 1, 0) * np.where(prediction[:,:,0]<20, 1, 0)
    mask[:,:,:,2] = np.where(full_mask[:,:,0]>=10, 1, 0) * np.where(full_mask[:,:,0]<20, 1, 0)

    pred[:,:,:,3] = np.where(prediction[:,:,0]>=20, 1, 0)
    mask[:,:,:,3] = np.where(full_mask[:,:,0]>=20, 1, 0)

    F1_score += F1_metric(pred, mask, num_cl = num_cl, class_names=[])
# Out:
# 0 : precision  0.791  recall  0.63  f1  0.702
#
# 1 : precision  0.618  recall  0.523  f1  0.566
#
# 2 : precision  0.822  recall  0.914  f1  0.866
#
# 3 : precision  0.637  recall  0.561  f1  0.597
#
# 0 : precision  0.782  recall  0.671  f1  0.722
#
# 1 : precision  0.568  recall  0.492  f1  0.527
#
# 2 : precision  0.82  recall  0.887  f1  0.852
#
# 3 : precision  0.411  recall  0.309  f1  0.353
#
# 0 : precision  0.885  recall  0.837  f1  0.86
#
# 1 : precision  0.394  recall  0.355  f1  0.373
#
# 2 : precision  0.623  recall  0.716  f1  0.666
#
# 3 : precision  0.68  recall  0.593  f1  0.634
#
# 0 : precision  0.901  recall  0.218  f1  0.352
#
# 1 : precision  0.182  recall  0.06  f1  0.09
#
# 2 : precision  0.828  recall  0.701  f1  0.759
#
# 3 : precision  0.516  recall  0.771  f1  0.618

# %%
print(F1_score / len(val_img_list))
print(np.sum(F1_score / len(val_img_list))/num_cl)
# Out:
# [0.65892336 0.38942034 0.78584545 0.55041854]
# 0.5961519199182961

# %%
for img, mask in generator.val_gen():
    break
pred = model.predict(img)

for num in range(1, 10):
    fig = plt.figure(figsize=(7, 7))
    
    a = fig.add_subplot(1, 3, 1)
    a.set_title('Image')
    imgplot = plt.imshow(img[num,:,:,:3])
    
    cl=0
    a = fig.add_subplot(1, 3, 2)
    a.set_title('Prediction')
    imgplot = plt.imshow(pred[num, :, :,0]) #.imshow(pred[num,:,:,cl]>0.5) 
    a = fig.add_subplot(1, 3, 3)
    a.set_title('GT')
    imgplot = plt.imshow(mask[num, :, :,0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Save prediction

# %%
json_file = open(save_dir+"{}.json".format(model_name), 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights(save_dir+"{}.h5".format(model_name))

# %%
val_img_list
# Out:
# ['/home/user/data/krasnoborsk/world_view/0/6_3',
#  '/home/user/data/krasnoborsk/world_view/0/2_2',
#  '/home/user/data/krasnoborsk/world_view/0/4_2',
#  '/home/user/data/krasnoborsk/world_view/0/1_1']

# %%
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    save_pred(img_to_save=prediction[:,:,0]*generator.clip_value, save_dist='../images/tmp.tif', \
          info_img=img_path + '_channel_0.tif', crs=4326)
    tif2geojson(source_dir='../images/', tif_name='tmp', geojson_path='../images/tmp.geojson')
    break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-1549c91c15c8> in <module>()
#       1 for ind, img_path in enumerate(val_img_list):
# ----> 2     prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
#       3     save_pred(img_to_save=prediction[:,:,0]*generator.clip_value, save_dist='../images/tmp.tif',           info_img=img_path + '_channel_0.tif', crs=4326)
#       4     tif2geojson(source_dir='../images/', tif_name='tmp', geojson_path='../images/tmp.geojson')
#       5     break
#
# ~/data/projects/research-project/notebooks/Illarionova/Height_model/forest_inventory/forest_height/height_model_scripts/height_model_scripts.py in pred_img(self, model, img_path, num_classes)
#     436
#     437         self.full_img = True
# --> 438         img,mask = self.get_img_mask_array(img_path)
#     439         self.full_img = False
#     440
#
# ~/data/projects/research-project/notebooks/Illarionova/Height_model/forest_inventory/forest_height/height_model_scripts/height_model_scripts.py in get_img_mask_array(self, imgpath)
#     227             img, mask_tmp  = augmentation(img, mask, self.color_aug_prob)
#     228             if len(mask_tmp.shape)==2:
# --> 229                 mask[:,:,0]=mask_tmp
#     230             else:
#     231                 mask=mask_tmp
#
# ValueError: could not broadcast input array from shape (1918,2498) into shape (2498,1918)

# %% [markdown]
# tmp = tiff.imread('../images/tmp.tif')
