# %%
# %load_ext autoreload
# %autoreload 2
    
import os
import cv2
import sys
import copy
import json
import random
import rasterio
import numpy as np
import tifffile as tiff
from skimage.transform import rescale, resize

import matplotlib.pyplot as plt

from keras import backend as K
from keras.models import Model, model_from_json

from keras.optimizers import SGD, Adam, RMSprop
from keras.backend import categorical_crossentropy, binary_crossentropy
from segmentation_models import Unet, FPN

from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger, Callback

os.environ['CUDA_VISIBLE_DEVICES'] = "1"
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Segmentation Models: using `keras` framework.

# %%
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
sys.path.insert(0, '../')
from height_model_scripts.loss_functions import rmse
from height_model_scripts.metrics import F1_metric, RMSE, MAE, R2, MBE, F1_metric
from height_model_scripts.height_model_scripts import Generator
from height_model_scripts.save_pred import save_pred, tif2geojson

# %% [markdown]
# ### Split on test, train, validation

# %%
train_img_list = []
test_img_list = []
val_img_list = []

train_list_split = ['0_0', '0_1', '0_2',
               '1_0', '1_2',
               '2_0', '2_1', '2_3', '2_4', '2_5',
               '3_1', '3_2', '3_3',
               '4_1', '4_3', '4_4', '4_5',
               '5_1', '5_2', '5_3', '5_4',
               '6_0', '6_1', '6_2', '6_4',
               '7_0', '7_1', '7_2', '7_3', '7_4']
val_list_split = ['1_1', '2_2', '4_2', '6_3']

# krasnoborsk
for folder in os.listdir('/home/user/data/krasnoborsk/world_view/'):
    if 'tif' in folder or 'xml' in folder or folder == 'lines':
        continue
    for file_name in os.listdir('/home/user/data/krasnoborsk/world_view/{}'.format(folder)):
        tmp_ind = file_name.split('_')[0]+'_'+file_name.split('_')[1]
        if tmp_ind in train_list_split and '/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind) not in train_img_list:
            train_img_list += ['/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind)]
        elif tmp_ind in val_list_split and '/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind) not in val_img_list \
            and folder == '0':
            val_img_list += ['/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind)]

# Novoshinsk
dse_pathechs = ['0_0', '0_1', '0_2',
               '1_0', '1_1', '1_2', '1_3',
               '2_0', '2_1', '2_2', '2_3', '2_4', 
               '3_0', '3_1', '3_2', '3_3', '3_4',
               '4_0', '4_1', '4_3', '4_4',
               '5_3', '5_4',
               '6_2', '6_3', '6_4',
               '7_2', '7_3', '7_4',
               '8_2', '8_3', '8_4']

for file_ind in [0, 1, 7, 9]: 
    for patch_ind in dse_pathechs:
        i, j = patch_ind.split('_')
        if patch_ind +'_channel_0.tif' not in os.listdir('/home/user/data/krasnoborsk/Novoshinsk/{}'.format(file_ind)) \
            or patch_ind +'_class_606.tif' not in os.listdir('/home/user/data/krasnoborsk/Novoshinsk/{}'.format(file_ind)):
            continue
        if patch_ind in ['1_1', '2_2', '4_4']:
            test_img_list += ['/home/user/data/krasnoborsk/Novoshinsk/{}/{}'.format(file_ind, patch_ind)]
        else:
            train_img_list += ['/home/user/data/krasnoborsk/Novoshinsk/{}/{}'.format(file_ind, patch_ind)]

# %% [markdown]
# ## New model

# %%
batch_size=20 
num_channels=5

gdal_file_path = './'

generator = Generator(train_img_list, val_img_list, batch_size, num_channels, gdal_file_path=gdal_file_path)

generator.augm = True              # just geometric rotation is applied
generator.color_aug_prob = 1       # add color augm

generator.sharpen_flag = False     # flag to switch pansharpaning
generator.forest_mask = True       # add forest mask if it is provided
generator.arctic_dem = True
generator.arctic_stat = {'min':125, 'max':250}

generator.lidar_coef = 2.5           # parameter for height resolution downsampling
generator.lidar_resolution = 1     # resolution of height data
generator.target_resolution = 2    # target resolution both for height and imagery
generator.clip_value = 40.         # the greatest height value 

generator.classifier_mode = 'regression'
generator.channels_list = ['channel_0.tif', 'channel_1.tif', 'channel_2.tif', 'channel_3.tif']

# %%
generator.write_gdalinfo_file()

# %% [markdown]
# ## Save generator parametrs

# %%
generator_state = copy.deepcopy(generator.__dict__)
del generator_state['data_gdal']
del generator_state['img_prob']

save_file = 'regr_rgb_nir_wv_arctic.json'
with open(save_file, 'w') as f:
    json.dump(generator_state, f)

# %% [markdown]
# ## Check outputs

# %%
# check output
img_tmp, mask_tmp = generator.get_img_mask_array(train_img_list[0])

fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow(img_tmp[:,:,:3])
a.set_title('img')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow(mask_tmp[:,:,0])
a.set_title('lidar')
# Out:
# Text(0.5,1,'lidar')

# %%
generator.augm = False
generator.full_img = True
img_tmp, mask_tmp = generator.get_img_mask_array(train_img_list[2])
generator.full_img = False
generator.augm = True   

fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow(img_tmp[:,:,:3])
a.set_title('img')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow(mask_tmp[:,:,0])
a.set_title('lidar')
# Out:
# Text(0.5,1,'lidar')

# %% [markdown]
# ## Set model

# %%
model = Unet(backbone_name='inceptionresnetv2', input_shape=(None, None, num_channels), 
                  encoder_weights=None, activation='sigmoid')
loss =  rmse
opt = RMSprop(lr=0.001)
metrics=[loss]
model.compile(optimizer=opt, loss=loss, metrics=metrics)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_applications/imagenet_utils.py:279: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 5 input channels.
#   str(input_shape[-1]) + ' input channels.')

# %%
model_name = 'regr_rgb_nir_wv_arctic'
save_dir = '/home/user/data/example/data/Forestry_inventory/Height_model_paper/'

# csv logger
log_filename = os.path.join(save_dir, '{}.csv'.format(model_name))
csv_logger = CSVLogger(log_filename, separator=',', append='True')

callbacks=[
    ReduceLROnPlateau(patience=4,min_lr=1e-9,verbose=1,mode='min'), #pat 7
    ModelCheckpoint(save_dir + '{}.h5'.format(model_name),save_best_only=True,verbose=1),
    ModelCheckpoint(save_dir + '{}.hdf5'.format(model_name),save_best_only=True,verbose=1, save_weights_only=True),
    csv_logger
]

# %%
history=model.fit_generator(generator.train_gen(),epochs=25, #35, 25 20
                           steps_per_epoch=200,#200,
                           validation_data=generator.val_gen(),  #(valid_imgarr,valid_maskarr),
                           callbacks=callbacks, validation_steps=100)#30
# Out:
# Epoch 1/25
# 200/200 [==============================] - 179s 897ms/step - loss: 0.1457 - rmse: 0.1457 - val_loss: 0.1797 - val_rmse: 0.1797
#
# Epoch 00001: val_loss improved from inf to 0.17973, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00001: val_loss improved from inf to 0.17973, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 2/25
# 200/200 [==============================] - 139s 694ms/step - loss: 0.1327 - rmse: 0.1327 - val_loss: 0.1525 - val_rmse: 0.1525
#
# Epoch 00002: val_loss improved from 0.17973 to 0.15248, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00002: val_loss improved from 0.17973 to 0.15248, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 3/25
# 200/200 [==============================] - 144s 719ms/step - loss: 0.1277 - rmse: 0.1277 - val_loss: 0.1520 - val_rmse: 0.1520
#
# Epoch 00003: val_loss improved from 0.15248 to 0.15199, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00003: val_loss improved from 0.15248 to 0.15199, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 4/25
# 200/200 [==============================] - 145s 727ms/step - loss: 0.1234 - rmse: 0.1234 - val_loss: 0.1173 - val_rmse: 0.1173
#
# Epoch 00004: val_loss improved from 0.15199 to 0.11732, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00004: val_loss improved from 0.15199 to 0.11732, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 5/25
# 200/200 [==============================] - 144s 718ms/step - loss: 0.1213 - rmse: 0.1213 - val_loss: 0.1162 - val_rmse: 0.1162
#
# Epoch 00005: val_loss improved from 0.11732 to 0.11624, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00005: val_loss improved from 0.11732 to 0.11624, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 6/25
# 200/200 [==============================] - 143s 716ms/step - loss: 0.1189 - rmse: 0.1189 - val_loss: 0.1068 - val_rmse: 0.1068
#
# Epoch 00006: val_loss improved from 0.11624 to 0.10678, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00006: val_loss improved from 0.11624 to 0.10678, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 7/25
# 200/200 [==============================] - 142s 711ms/step - loss: 0.1184 - rmse: 0.1184 - val_loss: 0.1262 - val_rmse: 0.1262
#
# Epoch 00007: val_loss did not improve from 0.10678
#
# Epoch 00007: val_loss did not improve from 0.10678
# Epoch 8/25
# 200/200 [==============================] - 142s 712ms/step - loss: 0.1150 - rmse: 0.1150 - val_loss: 0.1203 - val_rmse: 0.1203
#
# Epoch 00008: val_loss did not improve from 0.10678
#
# Epoch 00008: val_loss did not improve from 0.10678
# Epoch 9/25
# 200/200 [==============================] - 141s 706ms/step - loss: 0.1138 - rmse: 0.1138 - val_loss: 0.1093 - val_rmse: 0.1093
#
# Epoch 00009: val_loss did not improve from 0.10678
#
# Epoch 00009: val_loss did not improve from 0.10678
# Epoch 10/25
# 200/200 [==============================] - 142s 708ms/step - loss: 0.1126 - rmse: 0.1126 - val_loss: 0.1107 - val_rmse: 0.1107
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00010: val_loss did not improve from 0.10678
#
# Epoch 00010: val_loss did not improve from 0.10678
# Epoch 11/25
# 200/200 [==============================] - 140s 698ms/step - loss: 0.1065 - rmse: 0.1065 - val_loss: 0.0986 - val_rmse: 0.0986
#
# Epoch 00011: val_loss improved from 0.10678 to 0.09862, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00011: val_loss improved from 0.10678 to 0.09862, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 12/25
# 200/200 [==============================] - 140s 701ms/step - loss: 0.1072 - rmse: 0.1072 - val_loss: 0.0971 - val_rmse: 0.0971
#
# Epoch 00012: val_loss improved from 0.09862 to 0.09713, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00012: val_loss improved from 0.09862 to 0.09713, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 13/25
# 200/200 [==============================] - 140s 700ms/step - loss: 0.1046 - rmse: 0.1046 - val_loss: 0.0979 - val_rmse: 0.0979
#
# Epoch 00013: val_loss did not improve from 0.09713
#
# Epoch 00013: val_loss did not improve from 0.09713
# Epoch 14/25
# 200/200 [==============================] - 140s 701ms/step - loss: 0.1040 - rmse: 0.1040 - val_loss: 0.0969 - val_rmse: 0.0969
#
# Epoch 00014: val_loss improved from 0.09713 to 0.09687, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00014: val_loss improved from 0.09713 to 0.09687, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 15/25
# 200/200 [==============================] - 140s 700ms/step - loss: 0.1033 - rmse: 0.1033 - val_loss: 0.0978 - val_rmse: 0.0978
#
# Epoch 00015: val_loss did not improve from 0.09687
#
# Epoch 00015: val_loss did not improve from 0.09687
# Epoch 16/25
# 200/200 [==============================] - 140s 701ms/step - loss: 0.1036 - rmse: 0.1036 - val_loss: 0.0966 - val_rmse: 0.0966
#
# Epoch 00016: val_loss improved from 0.09687 to 0.09664, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00016: val_loss improved from 0.09687 to 0.09664, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 17/25
# 200/200 [==============================] - 140s 700ms/step - loss: 0.1023 - rmse: 0.1023 - val_loss: 0.0976 - val_rmse: 0.0976
#
# Epoch 00017: val_loss did not improve from 0.09664
#
# Epoch 00017: val_loss did not improve from 0.09664
# Epoch 18/25
# 200/200 [==============================] - 140s 701ms/step - loss: 0.1024 - rmse: 0.1024 - val_loss: 0.0976 - val_rmse: 0.0976
#
# Epoch 00018: val_loss did not improve from 0.09664
#
# Epoch 00018: val_loss did not improve from 0.09664
# Epoch 19/25
# 200/200 [==============================] - 140s 702ms/step - loss: 0.1022 - rmse: 0.1022 - val_loss: 0.0956 - val_rmse: 0.0956
#
# Epoch 00019: val_loss improved from 0.09664 to 0.09562, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.h5
#
# Epoch 00019: val_loss improved from 0.09664 to 0.09562, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_nir_wv_arctic.hdf5
# Epoch 20/25
# 200/200 [==============================] - 140s 701ms/step - loss: 0.1021 - rmse: 0.1021 - val_loss: 0.0975 - val_rmse: 0.0975
#
# Epoch 00020: val_loss did not improve from 0.09562
#
# Epoch 00020: val_loss did not improve from 0.09562
# Epoch 21/25
# 200/200 [==============================] - 140s 702ms/step - loss: 0.1021 - rmse: 0.1021 - val_loss: 0.0967 - val_rmse: 0.0967
#
# Epoch 00021: val_loss did not improve from 0.09562
#
# Epoch 00021: val_loss did not improve from 0.09562
# Epoch 22/25
# 200/200 [==============================] - 140s 701ms/step - loss: 0.1015 - rmse: 0.1015 - val_loss: 0.0966 - val_rmse: 0.0966
#
# Epoch 00022: val_loss did not improve from 0.09562
#
# Epoch 00022: val_loss did not improve from 0.09562
# Epoch 23/25
# 200/200 [==============================] - 140s 701ms/step - loss: 0.1009 - rmse: 0.1009 - val_loss: 0.0965 - val_rmse: 0.0965
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00023: val_loss did not improve from 0.09562
#
# Epoch 00023: val_loss did not improve from 0.09562
# Epoch 24/25
# 186/200 [==========================>...] - ETA: 7s - loss: 0.1006 - rmse: 0.1006
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-7eb5dcb2eecf> in <module>()
#       2                            steps_per_epoch=200,#200,
#       3                            validation_data=generator.val_gen(),  #(valid_imgarr,valid_maskarr),
# ----> 4                            callbacks=callbacks, validation_steps=100)#30
#
# /opt/conda/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/conda/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /opt/conda/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# /opt/conda/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
model.load_weights(save_dir+"{}.h5".format(model_name))

# %% [markdown]
# ## Evaluation

# %%
generator.augm  = False
prediction, full_mask = generator.pred_img(model=model, img_path=val_img_list[0])
generator.augm  = True

# %%
fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow((prediction[:,:,0]*generator.clip_value).clip(0, generator.clip_value))
a.set_title('img')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow((full_mask[:,:,0]*generator.clip_value).clip(0, generator.clip_value))
a.set_title('lidar')
# Out:
# Text(0.5,1,'lidar')

# %%
print('RMSE', RMSE(prediction*generator.clip_value, full_mask*generator.clip_value))
print('MAE', MAE(prediction*generator.clip_value, full_mask*generator.clip_value))
# Out:
# RMSE 4.661
# MAE 3.013

# %%
generator.augm  = False
average_rmse = 0
average_mae = 0
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    cur_rmse = RMSE(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_mae = MAE(prediction*generator.clip_value, full_mask*generator.clip_value)
    average_rmse += cur_rmse
    average_mae += cur_mae
    print(ind, 'rmse: ', cur_rmse, ' mae: ', cur_mae)
generator.augm  = True

print('~~~~~~~~~~~~~~~~')
print('Average RMSE: ', round(average_rmse / len(val_img_list), 3))
print('Average MAE: ', round(average_mae / len(val_img_list), 3))
# Out:
# 0 rmse:  4.661  mae:  3.013
# 1 rmse:  3.166  mae:  2.301
# 2 rmse:  4.193  mae:  3.104
# 3 rmse:  4.146  mae:  3.104
# ~~~~~~~~~~~~~~~~
# Average RMSE:  4.042
# Average MAE:  2.88

# %%
generator.augm  = False
average_rmse = 0
average_mae = 0
average_r2 = 0
average_mean_bias = 0
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    cur_rmse = RMSE(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_mae = MAE(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_r2 = R2(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_mean_bias = MBE(prediction*generator.clip_value, full_mask*generator.clip_value)
    average_rmse += cur_rmse
    average_mae += cur_mae
    average_r2 += cur_r2
    average_mean_bias += cur_mean_bias
    print(ind, 'rmse: ', cur_rmse, ' mae: ', cur_mae,  ' r2: ', cur_r2,  ' mbe: ', cur_mean_bias, )

print('~~~~~~~~~~~~~~~~')
print('Average RMSE: ', round(average_rmse / len(val_img_list), 3))
print('Average MAE: ', round(average_mae / len(val_img_list), 3))
print('Average R2: ', round(average_r2 / len(val_img_list), 3))
print('Average mean bias: ', round(average_mean_bias / len(val_img_list), 3))
# Out:
# 0 rmse:  4.661  mae:  3.013  r2:  0.562  mbe:  0.48380061643522554
# 1 rmse:  3.166  mae:  2.301  r2:  0.699  mbe:  -0.14594443171920463
# 2 rmse:  4.193  mae:  3.104  r2:  0.753  mbe:  -0.190998866509542
# 3 rmse:  4.146  mae:  3.104  r2:  0.451  mbe:  -0.6755229211614988
# ~~~~~~~~~~~~~~~~
# Average RMSE:  4.042
# Average MAE:  2.88
# Average R2:  0.616
# Average mean bias:  -0.132

# %%
num_cl = 4
F1_score = np.zeros((num_cl))
class_names=['0-4', '4-10', '10-20', '>20']
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    
    prediction *= generator.clip_value
    full_mask *= generator.clip_value

    pred = np.zeros((1, prediction.shape[0], prediction.shape[1], num_cl))
    mask = np.zeros((1, full_mask.shape[0], full_mask.shape[1], num_cl)) 

    pred[:,:,:,0] = np.where(prediction[:,:,0]>0, 1, 0) * np.where(prediction[:,:,0]<4, 1, 0)
    mask[:,:,:,0] = np.where(full_mask[:,:,0]>0, 1, 0) * np.where(full_mask[:,:,0]<4, 1, 0)

    pred[:,:,:,1] = np.where(prediction[:,:,0]>=4, 1, 0) * np.where(prediction[:,:,0]<10, 1, 0)
    mask[:,:,:,1] = np.where(full_mask[:,:,0]>=4, 1, 0) * np.where(full_mask[:,:,0]<10, 1, 0)

    pred[:,:,:,2] = np.where(prediction[:,:,0]>=10, 1, 0) * np.where(prediction[:,:,0]<20, 1, 0)
    mask[:,:,:,2] = np.where(full_mask[:,:,0]>=10, 1, 0) * np.where(full_mask[:,:,0]<20, 1, 0)

    pred[:,:,:,3] = np.where(prediction[:,:,0]>=20, 1, 0)
    mask[:,:,:,3] = np.where(full_mask[:,:,0]>=20, 1, 0)

    F1_score += F1_metric(pred, mask, num_cl = num_cl, class_names=[])
# Out:
# 0 : precision  0.703  recall  0.677  f1  0.69
#
# 1 : precision  0.586  recall  0.432  f1  0.497
#
# 2 : precision  0.772  recall  0.957  f1  0.855
#
# 3 : precision  0.754  recall  0.266  f1  0.393
#
# 0 : precision  0.757  recall  0.739  f1  0.748
#
# 1 : precision  0.585  recall  0.479  f1  0.527
#
# 2 : precision  0.816  recall  0.922  f1  0.866
#
# 3 : precision  0.531  recall  0.163  f1  0.249
#
# 0 : precision  0.878  recall  0.812  f1  0.844
#
# 1 : precision  0.431  recall  0.303  f1  0.356
#
# 2 : precision  0.623  recall  0.799  f1  0.7
#
# 3 : precision  0.715  recall  0.555  f1  0.625
#
# 0 : precision  0.903  recall  0.351  f1  0.506
#
# 1 : precision  0.266  recall  0.076  f1  0.118
#
# 2 : precision  0.77  recall  0.88  f1  0.821
#
# 3 : precision  0.633  recall  0.495  f1  0.556

# %%
print(F1_score / len(val_img_list))
print(np.sum(F1_score / len(val_img_list))/num_cl)
# Out:
# [0.69695938 0.37453313 0.81035833 0.45590034]
# 0.5844377939714416

# %% [markdown]
# # Save prediction

# %%
json_file = open(save_dir+"{}.json".format(model_name), 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights(save_dir+"{}.h5".format(model_name))

# %%
val_img_list
# Out:
# ['/home/user/data/krasnoborsk/world_view/0/6_3',
#  '/home/user/data/krasnoborsk/world_view/0/2_2',
#  '/home/user/data/krasnoborsk/world_view/0/4_2',
#  '/home/user/data/krasnoborsk/world_view/0/1_1']

# %%
generator.augm  = False
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    height_name = '/home/user/data/krasnoborsk/world_view/0/height_6_3.tif'
    save_pred(img_to_save=prediction[:,:,0]*generator.clip_value, save_dist='../images/tmp.tif', \
          info_img=height_name, crs=4326)
    tif2geojson(source_dir='../images/', tif_name='tmp', geojson_path='../images/tmp.geojson')
    break
generator.augm  = True
# Out:
# 1918 2498 (1249, 959)

# %%
tmp = tiff.imread('../images/tmp.tif')

# %%
tiff.imshow(tmp.clip(0, 40))
# Out:
# (<Figure size 988.8x604.8 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa0bc4bb908>,
#  <matplotlib.image.AxesImage at 0x7fa0bc531358>)

# %%
tmp = tiff.imread(height_name)
tmp.shape
# Out:
# (2498, 1918)
