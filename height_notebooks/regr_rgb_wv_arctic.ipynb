# %%
# %load_ext autoreload
# %autoreload 2
    
import os
import cv2
import sys
import copy
import json
import random
import rasterio
import numpy as np
import tifffile as tiff
from skimage.transform import rescale, resize

import matplotlib.pyplot as plt

from keras import backend as K
from keras.models import Model, model_from_json

from keras.optimizers import SGD, Adam, RMSprop
from keras.backend import categorical_crossentropy, binary_crossentropy
from segmentation_models import Unet, FPN

from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger, Callback

os.environ['CUDA_VISIBLE_DEVICES'] = "1"
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Segmentation Models: using `keras` framework.

# %%
K.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
sys.path.insert(0, '../')
from height_model_scripts.loss_functions import rmse
from height_model_scripts.metrics import F1_metric, RMSE, MAE, R2, MBE, F1_metric
from height_model_scripts.height_model_scripts import Generator
from height_model_scripts.save_pred import save_pred, tif2geojson

# %% [markdown]
# ### Split on test, train, validation

# %%
train_img_list = []
test_img_list = []
val_img_list = []

train_list_split = ['0_0', '0_1', '0_2',
               '1_0', '1_2',
               '2_0', '2_1', '2_3', '2_4', '2_5',
               '3_1', '3_2', '3_3',
               '4_1', '4_3', '4_4', '4_5',
               '5_1', '5_2', '5_3', '5_4',
               '6_0', '6_1', '6_2', '6_4',
               '7_0', '7_1', '7_2', '7_3', '7_4']
val_list_split = ['1_1', '2_2', '4_2', '6_3']

# krasnoborsk
for folder in os.listdir('/home/user/data/krasnoborsk/world_view/'):
    if 'tif' in folder or 'xml' in folder or folder == 'lines':
        continue
    for file_name in os.listdir('/home/user/data/krasnoborsk/world_view/{}'.format(folder)):
        tmp_ind = file_name.split('_')[0]+'_'+file_name.split('_')[1]
        if tmp_ind in train_list_split and '/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind) not in train_img_list:
            train_img_list += ['/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind)]
        elif tmp_ind in val_list_split and '/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind) not in val_img_list \
            and folder == '0':
            val_img_list += ['/home/user/data/krasnoborsk/world_view/{}/{}'.format(folder, tmp_ind)]

# Novoshinsk
dse_pathechs = ['0_0', '0_1', '0_2',
               '1_0', '1_1', '1_2', '1_3',
               '2_0', '2_1', '2_2', '2_3', '2_4', 
               '3_0', '3_1', '3_2', '3_3', '3_4',
               '4_0', '4_1', '4_3', '4_4',
               '5_3', '5_4',
               '6_2', '6_3', '6_4',
               '7_2', '7_3', '7_4',
               '8_2', '8_3', '8_4']

for file_ind in [0, 1, 7, 9]: 
    for patch_ind in dse_pathechs:
        i, j = patch_ind.split('_')
        if patch_ind +'_channel_0.tif' not in os.listdir('/home/user/data/krasnoborsk/Novoshinsk/{}'.format(file_ind)) \
            or patch_ind +'_class_606.tif' not in os.listdir('/home/user/data/krasnoborsk/Novoshinsk/{}'.format(file_ind)):
            continue
        if patch_ind in ['1_1', '2_2', '4_4']:
            test_img_list += ['/home/user/data/krasnoborsk/Novoshinsk/{}/{}'.format(file_ind, patch_ind)]
        else:
            train_img_list += ['/home/user/data/krasnoborsk/Novoshinsk/{}/{}'.format(file_ind, patch_ind)]

# %% [markdown]
# ## New model

# %%
batch_size=20 
num_channels=4

gdal_file_path = './'

generator = Generator(train_img_list, val_img_list, batch_size, num_channels, gdal_file_path=gdal_file_path)

generator.augm = False              # just geometric rotation is applied
generator.color_aug_prob = 1       # add color augm

generator.sharpen_flag = False     # flag to switch pansharpaning
generator.forest_mask = True       # add forest mask if it is provided
generator.arctic_dem = True
generator.arctic_stat = {'min':125, 'max':250}

generator.lidar_coef = 2.5           # parameter for height resolution downsampling
generator.lidar_resolution = 1     # resolution of height data
generator.target_resolution = 2    # target resolution both for height and imagery
generator.clip_value = 40.         # the greatest height value 

generator.classifier_mode = 'regression'
generator.channels_list = ['channel_0.tif', 'channel_1.tif', 'channel_2.tif']

# %%
generator.write_gdalinfo_file()

# %% [markdown]
# ## Save generator parametrs

# %%
generator_state = copy.deepcopy(generator.__dict__)
del generator_state['data_gdal']
del generator_state['img_prob']

nb_name = 'regr_rgb_wv_arctic.ipynb'

save_file = nb_name.split('.')[0] + '.json'
with open(save_file, 'w') as f:
    json.dump(generator_state, f)

# %% [markdown]
# ## Check outputs

# %%
# check output
img_tmp, mask_tmp = generator.get_img_mask_array(train_img_list[0])

fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow(img_tmp[:,:,:3])
a.set_title('img')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow(mask_tmp[:,:,0])
a.set_title('lidar')
# Out:
# Text(0.5,1,'lidar')

# %%
generator.augm = False
generator.full_img = True
img_tmp, mask_tmp = generator.get_img_mask_array(train_img_list[2])
generator.full_img = False
generator.augm = True   

fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow(img_tmp[:,:,:3])
a.set_title('img')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow(mask_tmp[:,:,0])
a.set_title('lidar')
# Out:
# Text(0.5,1,'lidar')

# %% [markdown]
# ## Set model

# %%
model = Unet(backbone_name='inceptionresnetv2', input_shape=(None, None, num_channels), 
                  encoder_weights=None, activation='sigmoid')
loss =  rmse
opt = RMSprop(lr=0.001)
metrics=[loss]
model.compile(optimizer=opt, loss=loss, metrics=metrics)
# Out:
# /opt/conda/lib/python3.6/site-packages/keras_applications/imagenet_utils.py:279: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 4 input channels.
#   str(input_shape[-1]) + ' input channels.')

# %%
model_name = 'regr_rgb_wv_arctic'
save_dir = '/home/user/data/example/data/Forestry_inventory/Height_model_paper/'

# csv logger
log_filename = os.path.join(save_dir, '{}.csv'.format(model_name))
csv_logger = CSVLogger(log_filename, separator=',', append='True')

callbacks=[
    ReduceLROnPlateau(patience=4,min_lr=1e-9,verbose=1,mode='min'), #pat 7
    ModelCheckpoint(save_dir + '{}.h5'.format(model_name),save_best_only=True,verbose=1),
    ModelCheckpoint(save_dir + '{}.hdf5'.format(model_name),save_best_only=True,verbose=1, save_weights_only=True),
    csv_logger
]

# %%
history=model.fit_generator(generator.train_gen(),epochs=25, #35, 25 20
                           steps_per_epoch=200,#200,
                           validation_data=generator.val_gen(),  #(valid_imgarr,valid_maskarr),
                           callbacks=callbacks, validation_steps=100)#30
# Out:
# Epoch 1/25
# 200/200 [==============================] - 161s 803ms/step - loss: 0.1437 - rmse: 0.1437 - val_loss: 0.1489 - val_rmse: 0.1489
#
# Epoch 00001: val_loss improved from inf to 0.14890, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00001: val_loss improved from inf to 0.14890, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5
# Epoch 2/25
# 200/200 [==============================] - 129s 647ms/step - loss: 0.1280 - rmse: 0.1280 - val_loss: 0.1212 - val_rmse: 0.1212
#
# Epoch 00002: val_loss improved from 0.14890 to 0.12123, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00002: val_loss improved from 0.14890 to 0.12123, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5
# Epoch 3/25
# 200/200 [==============================] - 130s 649ms/step - loss: 0.1243 - rmse: 0.1243 - val_loss: 0.1207 - val_rmse: 0.1207
#
# Epoch 00003: val_loss improved from 0.12123 to 0.12071, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00003: val_loss improved from 0.12123 to 0.12071, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5
# Epoch 4/25
# 200/200 [==============================] - 131s 655ms/step - loss: 0.1201 - rmse: 0.1201 - val_loss: 0.1554 - val_rmse: 0.1554
#
# Epoch 00004: val_loss did not improve from 0.12071
#
# Epoch 00004: val_loss did not improve from 0.12071
# Epoch 5/25
# 200/200 [==============================] - 130s 650ms/step - loss: 0.1171 - rmse: 0.1171 - val_loss: 0.1249 - val_rmse: 0.1249
#
# Epoch 00005: val_loss did not improve from 0.12071
#
# Epoch 00005: val_loss did not improve from 0.12071
# Epoch 6/25
# 200/200 [==============================] - 129s 646ms/step - loss: 0.1142 - rmse: 0.1142 - val_loss: 0.1447 - val_rmse: 0.1447
#
# Epoch 00006: val_loss did not improve from 0.12071
#
# Epoch 00006: val_loss did not improve from 0.12071
# Epoch 7/25
# 200/200 [==============================] - 130s 649ms/step - loss: 0.1112 - rmse: 0.1112 - val_loss: 0.0993 - val_rmse: 0.0993
#
# Epoch 00007: val_loss improved from 0.12071 to 0.09931, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00007: val_loss improved from 0.12071 to 0.09931, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5
# Epoch 8/25
# 200/200 [==============================] - 129s 647ms/step - loss: 0.1088 - rmse: 0.1088 - val_loss: 0.1024 - val_rmse: 0.1024
#
# Epoch 00008: val_loss did not improve from 0.09931
#
# Epoch 00008: val_loss did not improve from 0.09931
# Epoch 9/25
# 200/200 [==============================] - 130s 648ms/step - loss: 0.1056 - rmse: 0.1056 - val_loss: 0.1029 - val_rmse: 0.1029
#
# Epoch 00009: val_loss did not improve from 0.09931
#
# Epoch 00009: val_loss did not improve from 0.09931
# Epoch 10/25
# 200/200 [==============================] - 129s 644ms/step - loss: 0.1052 - rmse: 0.1052 - val_loss: 0.1082 - val_rmse: 0.1082
#
# Epoch 00010: val_loss did not improve from 0.09931
#
# Epoch 00010: val_loss did not improve from 0.09931
# Epoch 11/25
# 200/200 [==============================] - 129s 647ms/step - loss: 0.1030 - rmse: 0.1030 - val_loss: 0.1010 - val_rmse: 0.1010
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00011: val_loss did not improve from 0.09931
#
# Epoch 00011: val_loss did not improve from 0.09931
# Epoch 12/25
# 200/200 [==============================] - 129s 646ms/step - loss: 0.0951 - rmse: 0.0951 - val_loss: 0.0896 - val_rmse: 0.0896
#
# Epoch 00012: val_loss improved from 0.09931 to 0.08961, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00012: val_loss improved from 0.09931 to 0.08961, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5
# Epoch 13/25
# 200/200 [==============================] - 129s 644ms/step - loss: 0.0943 - rmse: 0.0943 - val_loss: 0.0882 - val_rmse: 0.0882
#
# Epoch 00013: val_loss improved from 0.08961 to 0.08819, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00013: val_loss improved from 0.08961 to 0.08819, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5
# Epoch 14/25
# 200/200 [==============================] - 129s 645ms/step - loss: 0.0932 - rmse: 0.0932 - val_loss: 0.0889 - val_rmse: 0.0889
#
# Epoch 00014: val_loss did not improve from 0.08819
#
# Epoch 00014: val_loss did not improve from 0.08819
# Epoch 15/25
# 200/200 [==============================] - 130s 648ms/step - loss: 0.0924 - rmse: 0.0924 - val_loss: 0.0882 - val_rmse: 0.0882
#
# Epoch 00015: val_loss did not improve from 0.08819
#
# Epoch 00015: val_loss did not improve from 0.08819
# Epoch 16/25
# 200/200 [==============================] - 130s 648ms/step - loss: 0.0929 - rmse: 0.0929 - val_loss: 0.0883 - val_rmse: 0.0883
#
# Epoch 00016: val_loss did not improve from 0.08819
#
# Epoch 00016: val_loss did not improve from 0.08819
# Epoch 17/25
# 200/200 [==============================] - 130s 649ms/step - loss: 0.0919 - rmse: 0.0919 - val_loss: 0.0874 - val_rmse: 0.0874
#
# Epoch 00017: val_loss improved from 0.08819 to 0.08737, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00017: val_loss improved from 0.08819 to 0.08737, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5
# Epoch 18/25
# 200/200 [==============================] - 129s 647ms/step - loss: 0.0915 - rmse: 0.0915 - val_loss: 0.0870 - val_rmse: 0.0870
#
# Epoch 00018: val_loss improved from 0.08737 to 0.08699, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00018: val_loss improved from 0.08737 to 0.08699, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5
# Epoch 19/25
# 200/200 [==============================] - 129s 645ms/step - loss: 0.0909 - rmse: 0.0909 - val_loss: 0.0864 - val_rmse: 0.0864
#
# Epoch 00019: val_loss improved from 0.08699 to 0.08642, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00019: val_loss improved from 0.08699 to 0.08642, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5
# Epoch 20/25
# 200/200 [==============================] - 129s 645ms/step - loss: 0.0903 - rmse: 0.0903 - val_loss: 0.0857 - val_rmse: 0.0857
#
# Epoch 00020: val_loss improved from 0.08642 to 0.08568, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00020: val_loss improved from 0.08642 to 0.08568, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5
# Epoch 21/25
# 200/200 [==============================] - 129s 646ms/step - loss: 0.0898 - rmse: 0.0898 - val_loss: 0.0861 - val_rmse: 0.0861
#
# Epoch 00021: val_loss did not improve from 0.08568
#
# Epoch 00021: val_loss did not improve from 0.08568
# Epoch 22/25
# 200/200 [==============================] - 130s 648ms/step - loss: 0.0888 - rmse: 0.0888 - val_loss: 0.0862 - val_rmse: 0.0862
#
# Epoch 00022: val_loss did not improve from 0.08568
#
# Epoch 00022: val_loss did not improve from 0.08568
# Epoch 23/25
# 200/200 [==============================] - 129s 646ms/step - loss: 0.0885 - rmse: 0.0885 - val_loss: 0.0866 - val_rmse: 0.0866
#
# Epoch 00023: val_loss did not improve from 0.08568
#
# Epoch 00023: val_loss did not improve from 0.08568
# Epoch 24/25
# 200/200 [==============================] - 129s 646ms/step - loss: 0.0893 - rmse: 0.0893 - val_loss: 0.0864 - val_rmse: 0.0864
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00024: val_loss did not improve from 0.08568
#
# Epoch 00024: val_loss did not improve from 0.08568
# Epoch 25/25
# 200/200 [==============================] - 129s 646ms/step - loss: 0.0890 - rmse: 0.0890 - val_loss: 0.0856 - val_rmse: 0.0856
#
# Epoch 00025: val_loss improved from 0.08568 to 0.08565, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.h5
#
# Epoch 00025: val_loss improved from 0.08568 to 0.08565, saving model to /home/user/data/example/data/Forestry_inventory/Height_model_paper/regr_rgb_wv_arctic.hdf5

# %%
# serialize model to JSON without height
model_name += '_v1'
model_json = model.to_json()
with open(save_dir+"{}.json".format(model_name), "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights(save_dir+"{}.h5".format(model_name))
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model.load_weights(save_dir+"{}.h5".format(model_name))

# %% [markdown]
# ## Evaluation

# %%
generator.augm  = False
prediction, full_mask = generator.pred_img(model=model, img_path=val_img_list[0])
generator.augm  = True

# %%
fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow((prediction[:,:,0]*generator.clip_value).clip(0, generator.clip_value))
a.set_title('img')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow((full_mask[:,:,0]*generator.clip_value).clip(0, generator.clip_value))
a.set_title('lidar')
# Out:
# Text(0.5,1,'lidar')

# %%
print('RMSE', RMSE(prediction*generator.clip_value, full_mask*generator.clip_value))
print('MAE', MAE(prediction*generator.clip_value, full_mask*generator.clip_value))
# Out:
# RMSE 4.426
# MAE 2.601

# %%
generator.augm  = False
average_rmse = 0
average_mae = 0
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    cur_rmse = RMSE(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_mae = MAE(prediction*generator.clip_value, full_mask*generator.clip_value)
    average_rmse += cur_rmse
    average_mae += cur_mae
    print(ind, 'rmse: ', cur_rmse, ' mae: ', cur_mae)
generator.augm  = True

print('~~~~~~~~~~~~~~~~')
print('Average RMSE: ', round(average_rmse / len(val_img_list), 3))
print('Average MAE: ', round(average_mae / len(val_img_list), 3))
# Out:
# 0 rmse:  4.426  mae:  2.601
# 1 rmse:  2.954  mae:  2.162
# 2 rmse:  4.019  mae:  2.874
# 3 rmse:  4.069  mae:  3.06
# ~~~~~~~~~~~~~~~~
# Average RMSE:  3.867
# Average MAE:  2.674

# %%
generator.augm  = False
average_rmse = 0
average_mae = 0
average_r2 = 0
average_mean_bias = 0
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    cur_rmse = RMSE(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_mae = MAE(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_r2 = R2(prediction*generator.clip_value, full_mask*generator.clip_value)
    cur_mean_bias = MBE(prediction*generator.clip_value, full_mask*generator.clip_value)
    average_rmse += cur_rmse
    average_mae += cur_mae
    average_r2 += cur_r2
    average_mean_bias += cur_mean_bias
    print(ind, 'rmse: ', cur_rmse, ' mae: ', cur_mae,  ' r2: ', cur_r2,  ' mbe: ', cur_mean_bias, )
generator.augm  = True

print('~~~~~~~~~~~~~~~~')
print('Average RMSE: ', round(average_rmse / len(val_img_list), 3))
print('Average MAE: ', round(average_mae / len(val_img_list), 3))
print('Average R2: ', round(average_r2 / len(val_img_list), 3))
print('Average mean bias: ', round(average_mean_bias / len(val_img_list), 3))
# Out:
# 0 rmse:  4.426  mae:  2.601  r2:  0.605  mbe:  -0.6035727557330532
# 1 rmse:  2.954  mae:  2.162  r2:  0.738  mbe:  -0.007022571520497615
# 2 rmse:  4.019  mae:  2.874  r2:  0.773  mbe:  -0.7836597459596589
# 3 rmse:  4.069  mae:  3.06  r2:  0.471  mbe:  -1.1307449258778572
# ~~~~~~~~~~~~~~~~
# Average RMSE:  3.867
# Average MAE:  2.674
# Average R2:  0.647
# Average mean bias:  -0.631

# %%
generator.augm = False

# %%
num_cl = 4
F1_score = np.zeros((num_cl))
class_names=['0-4', '4-10', '10-20', '>20']
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    
    prediction *= generator.clip_value
    full_mask *= generator.clip_value

    pred = np.zeros((1, prediction.shape[0], prediction.shape[1], num_cl))
    mask = np.zeros((1, full_mask.shape[0], full_mask.shape[1], num_cl)) 

    pred[:,:,:,0] = np.where(prediction[:,:,0]>0, 1, 0) * np.where(prediction[:,:,0]<4, 1, 0)
    mask[:,:,:,0] = np.where(full_mask[:,:,0]>0, 1, 0) * np.where(full_mask[:,:,0]<4, 1, 0)

    pred[:,:,:,1] = np.where(prediction[:,:,0]>=4, 1, 0) * np.where(prediction[:,:,0]<10, 1, 0)
    mask[:,:,:,1] = np.where(full_mask[:,:,0]>=4, 1, 0) * np.where(full_mask[:,:,0]<10, 1, 0)

    pred[:,:,:,2] = np.where(prediction[:,:,0]>=10, 1, 0) * np.where(prediction[:,:,0]<20, 1, 0)
    mask[:,:,:,2] = np.where(full_mask[:,:,0]>=10, 1, 0) * np.where(full_mask[:,:,0]<20, 1, 0)

    pred[:,:,:,3] = np.where(prediction[:,:,0]>=20, 1, 0)
    mask[:,:,:,3] = np.where(full_mask[:,:,0]>=20, 1, 0)

    F1_score += F1_metric(pred, mask, num_cl = num_cl, class_names=[])
# Out:
# 0 : precision  0.885  recall  0.596  f1  0.712
#
# 1 : precision  0.662  recall  0.641  f1  0.651
#
# 2 : precision  0.823  recall  0.937  f1  0.877
#
# 3 : precision  0.696  recall  0.542  f1  0.609
#
# 0 : precision  0.879  recall  0.772  f1  0.822
#
# 1 : precision  0.629  recall  0.592  f1  0.61
#
# 2 : precision  0.833  recall  0.922  f1  0.875
#
# 3 : precision  0.564  recall  0.207  f1  0.303
#
# 0 : precision  0.926  recall  0.842  f1  0.882
#
# 1 : precision  0.556  recall  0.419  f1  0.478
#
# 2 : precision  0.668  recall  0.72  f1  0.693
#
# 3 : precision  0.681  recall  0.7  f1  0.69
#
# 0 : precision  0.887  recall  0.513  f1  0.65
#
# 1 : precision  0.336  recall  0.075  f1  0.122
#
# 2 : precision  0.803  recall  0.851  f1  0.826
#
# 3 : precision  0.637  recall  0.625  f1  0.631

# %%
print(F1_score / len(val_img_list))
print(np.sum(F1_score / len(val_img_list))/num_cl)
# Out:
# [0.76662668 0.46526197 0.8178553  0.55840566]
# 0.6520374006059841

# %%
fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow((prediction[:,:,0]>10) * (prediction[:,:,0]<20))
a.set_title('pred')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow((full_mask[:,:,0]>10) * (full_mask[:,:,0]<20))
a.set_title('mask')
a = fig.add_subplot(1, 6, 3)
imgplot = plt.imshow(((prediction[:,:,0]>10) * (prediction[:,:,0]<20))*((full_mask[:,:,0]>10) * (full_mask[:,:,0]<20)))
a.set_title('mask')
# Out:
# Text(0.5,1,'mask')

# %% [markdown]
# ## Save prediction

# %%
json_file = open(save_dir+"{}.json".format(model_name), 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)
model.load_weights(save_dir+"{}.h5".format(model_name))

# %%
val_img_list
# Out:
# ['/home/user/data/krasnoborsk/world_view/0/6_3',
#  '/home/user/data/krasnoborsk/world_view/0/2_2',
#  '/home/user/data/krasnoborsk/world_view/0/4_2',
#  '/home/user/data/krasnoborsk/world_view/0/1_1']

# %%
r = tiff.imread('/home/user/data/krasnoborsk/world_view/0/2_2_channel_1.tif')
height = tiff.imread('/home/user/data/krasnoborsk/world_view/0/height_2_2.tif')

# %%
fig = plt.figure(figsize = (25,25))
a = fig.add_subplot(1, 6, 1)
imgplot = plt.imshow(r)
a.set_title('img')
a = fig.add_subplot(1, 6, 2)
imgplot = plt.imshow(height)
a.set_title('lidar')
# Out:
# Text(0.5,1,'lidar')

# %%
generator.augm  = False
for ind, img_path in enumerate(val_img_list):
    prediction, full_mask = generator.pred_img(model=model, img_path=img_path)
    height_name = '/home/user/data/krasnoborsk/world_view/0/height_6_3.tif'
    save_pred(img_to_save=prediction[:,:,0]*generator.clip_value, save_dist='../images/tmp.tif', \
          info_img=height_name, crs=4326)
    tif2geojson(source_dir='../images/', tif_name='tmp', geojson_path='../images/tmp.geojson')
    break
generator.augm  = True
# Out:
# 1918 2498 (2498, 1918)

# %%
tmp = tiff.imread('../images/tmp.tif')

# %%
tiff.imshow(tmp.clip(0, 40))
# Out:
# (<Figure size 988.8x604.8 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa4b2f8c358>,
#  <matplotlib.image.AxesImage at 0x7fa4b308ddd8>)
